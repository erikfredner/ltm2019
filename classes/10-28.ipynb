# %% [markdown]
# # Making a document-term matrix quickly
# Let's say you already counted all of your words, and you want to drop the stopwords in your document-term matrix.
#
# We're going to walk through this one step at a time, again for *Harry Potter*.

# %%
import os

def absolute_paths(directory, txt_only = True):
    files = os.listdir(directory)
    absolute_paths = []
    
    for file in files:
        path = os.path.join(directory, file)
        absolute_paths.append(path)
    
    if txt_only is True:
        txts = []
        for x in absolute_paths:
            if str('.txt') in str(x):
                txts.append(x)
        return txts
    
    else:        
        return absolute_paths

# %%
# get harry potter paths using our absolute_paths function
hp_dir = '/Users/e/code/literarytextmining/corpora/harry_potter/texts'
hp_files = absolute_paths(hp_dir)
hp_files
# Out:
# ['/Users/e/code/literarytextmining/corpora/harry_potter/texts/5 Order of the Phoenix.txt',
#  '/Users/e/code/literarytextmining/corpora/harry_potter/texts/4 Goblet of Fire.txt',
#  '/Users/e/code/literarytextmining/corpora/harry_potter/texts/6 Half-Blood Prince.txt',
#  '/Users/e/code/literarytextmining/corpora/harry_potter/texts/1 Sorcerers Stone.txt',
#  '/Users/e/code/literarytextmining/corpora/harry_potter/texts/3 Prisoner of Azkaban.txt',
#  '/Users/e/code/literarytextmining/corpora/harry_potter/texts/7 Deathly Hallows.txt',
#  '/Users/e/code/literarytextmining/corpora/harry_potter/texts/2 Chamber of Secrets.txt']

# %%
import string
import re

def tokenize(text, keep_punct = False):
    if keep_punct is True:
        for punct in string.punctuation:
            text = text.replace(punct, ' ' + punct + ' ')
    else:
        for punct in string.punctuation:
            text = text.replace(punct, ' ')
    
    # this replaces *any* amount of whitespace with a single space using regular expressions
    text = re.sub('\s+', ' ', text)
    
    result = []
    
    for x in text.lower().split(' '):
        if x.isalpha():
            result.append(x)
    
    return result

# %%
test = tokenize(open(hp_files[0]).read())

# %%
test[:5]
# Out:
# ['chapter', 'one', 'dudley', 'demented', 'the']

# %%
def count_words(word_list):
    d = {}
    
    for word in word_list:
        if word not in d:
            d[word] = 1
        else:
            d[word] += 1
    
    return d

# %%
test_d = count_words(test)

# %%
test_d
# Out:
# {'chapter': 51,
#  'one': 511,
#  'dudley': 90,
#  'demented': 1,
#  'the': 11902,
#  'hottest': 1,
#  'day': 131,
#  'of': 5448,
#  'summer': 44,
#  'so': 705,
#  'far': 100,
#  'was': 3668,
#  'drawing': 26,
#  'to': 6452,
#  'a': 4967,
#  'close': 76,
#  'and': 6169,
#  'drowsy': 2,
#  'silence': 55,
#  'lay': 57,
#  'over': 582,
#  'large': 123,
#  'square': 21,
#  'houses': 19,
#  'privet': 24,
#  'drive': 32,
#  'cars': 10,
#  'that': 2395,
#  'were': 1001,
#  'usually': 27,
#  'gleaming': 17,
#  'stood': 117,
#  'dusty': 22,
#  'in': 3149,
#  'their': 596,
#  'drives': 1,
#  'lawns': 9,
#  'once': 252,
#  'emerald': 11,
#  'green': 69,
#  'parched': 2,
#  'yellowing': 3,
#  'use': 82,
#  'hosepipes': 1,
#  'had': 2422,
#  'been': 802,
#  'banned': 7,
#  'due': 11,
#  'drought': 2,
#  'deprived': 1,
#  'usual': 66,
#  'car': 15,
#  'washing': 1,
#  'lawn': 23,
#  'mowing': 1,
#  'pursuits': 1,
#  'inhabitants': 3,
#  'retreated': 8,
#  'into': 705,
#  'shade': 12,
#  'cool': 33,
#  'windows': 45,
#  'thrown': 23,
#  'wide': 50,
#  'hope': 52,
#  'tempting': 1,
#  'nonexistent': 3,
#  'breeze': 6,
#  'only': 302,
#  'person': 55,
#  'left': 215,
#  'outdoors': 1,
#  'teenage': 2,
#  'boy': 78,
#  'who': 712,
#  'lying': 63,
#  'flat': 18,
#  'on': 1755,
#  'his': 3328,
#  'back': 793,
#  'flower': 5,
#  'bed': 129,
#  'outside': 90,
#  'number': 59,
#  'four': 82,
#  'he': 4618,
#  'skinny': 5,
#  'black': 172,
#  'haired': 19,
#  'bespectacled': 2,
#  'pinched': 1,
#  'slightly': 150,
#  'unhealthy': 2,
#  'look': 297,
#  'someone': 69,
#  'has': 208,
#  'grown': 12,
#  'lot': 70,
#  'short': 49,
#  'space': 20,
#  'time': 416,
#  'jeans': 13,
#  'torn': 4,
#  'dirty': 21,
#  't': 36,
#  'shirt': 7,
#  'baggy': 2,
#  'faded': 9,
#  'soles': 2,
#  'trainers': 3,
#  'peeling': 4,
#  'away': 254,
#  'from': 1094,
#  'uppers': 1,
#  'harry': 3643,
#  'appearance': 14,
#  'did': 577,
#  'not': 1574,
#  'endear': 1,
#  'him': 1637,
#  'neighbors': 9,
#  'sort': 50,
#  'people': 236,
#  'thought': 310,
#  'scruffiness': 1,
#  'ought': 63,
#  'be': 1077,
#  'punishable': 1,
#  'by': 519,
#  'law': 14,
#  'but': 1156,
#  'as': 1808,
#  'hidden': 23,
#  'himself': 263,
#  'behind': 311,
#  'hydrangea': 2,
#  'bush': 3,
#  'this': 736,
#  'evening': 58,
#  'quite': 163,
#  'invisible': 20,
#  'passersby': 4,
#  'fact': 69,
#  'way': 257,
#  'would': 547,
#  'spotted': 14,
#  'if': 587,
#  'uncle': 116,
#  'vernon': 94,
#  'or': 384,
#  'aunt': 81,
#  'petunia': 67,
#  'stuck': 30,
#  'heads': 50,
#  'out': 1004,
#  'living': 21,
#  'room': 356,
#  'window': 115,
#  'looked': 545,
#  'straight': 63,
#  'down': 592,
#  'below': 50,
#  'whole': 76,
#  'congratulated': 1,
#  'idea': 88,
#  'hiding': 26,
#  'here': 329,
#  'perhaps': 54,
#  'very': 521,
#  'comfortable': 7,
#  'hot': 30,
#  'hard': 127,
#  'earth': 28,
#  'other': 266,
#  'hand': 276,
#  'nobody': 78,
#  'glaring': 12,
#  'at': 2192,
#  'grinding': 4,
#  'teeth': 25,
#  'loudly': 94,
#  'could': 635,
#  'hear': 143,
#  'news': 53,
#  'shooting': 13,
#  'nasty': 25,
#  'questions': 35,
#  'happened': 119,
#  'every': 158,
#  'tried': 87,
#  'sitting': 99,
#  'watching': 105,
#  'television': 5,
#  'with': 1594,
#  'almost': 94,
#  'though': 502,
#  'fluttered': 7,
#  'through': 350,
#  'open': 174,
#  'dursley': 7,
#  'suddenly': 50,
#  'spoke': 47,
#  'see': 431,
#  'stopped': 80,
#  'trying': 175,
#  'butt': 1,
#  'where': 264,
#  'is': 665,
#  'anyway': 88,
#  'know': 616,
#  'said': 3999,
#  'unconcernedly': 2,
#  'house': 144,
#  'grunted': 16,
#  'scathingly': 5,
#  'like': 527,
#  'what': 830,
#  'really': 243,
#  'up': 1040,
#  'normal': 25,
#  'cares': 7,
#  'got': 501,
#  'clue': 13,
#  'going': 392,
#  'doubt': 18,
#  'knows': 47,
#  'prime': 99,
#  'minister': 153,
#  'anything': 160,
#  'about': 600,
#  'our': 163,
#  'shh': 2,
#  'yes': 87,
#  'sorry': 60,
#  'dear': 53,
#  'dursleys': 28,
#  'fell': 108,
#  'silent': 43,
#  'listened': 11,
#  'jingle': 1,
#  'fruit': 1,
#  'bran': 1,
#  'breakfast': 32,
#  'cereal': 2,
#  'while': 172,
#  'watched': 75,
#  'mrs': 272,
#  'figg': 41,
#  'batty': 4,
#  'cat': 13,
#  'loving': 2,
#  'old': 134,
#  'lady': 11,
#  'nearby': 19,
#  'wisteria': 7,
#  'walk': 38,
#  'amble': 1,
#  'slowly': 93,
#  'past': 118,
#  'she': 1368,
#  'frowning': 32,
#  'muttering': 31,
#  'herself': 51,
#  'pleased': 40,
#  'concealed': 8,
#  'recently': 14,
#  'taken': 54,
#  'asking': 25,
#  'around': 556,
#  'for': 1335,
#  'tea': 28,
#  'whenever': 24,
#  'met': 45,
#  'street': 28,
#  'rounded': 10,
#  'corner': 80,
#  'vanished': 49,
#  'view': 26,
#  'before': 362,
#  'voice': 441,
#  'floated': 11,
#  'again': 552,
#  'fondly': 7,
#  'many': 110,
#  'little': 239,
#  'friends': 31,
#  'popular': 7,
#  'repressed': 2,
#  'snort': 5,
#  'difficulty': 13,
#  'astonishingly': 3,
#  'stupid': 57,
#  'son': 28,
#  'they': 1279,
#  'swallowed': 16,
#  'all': 1028,
#  'dim': 9,
#  'witted': 2,
#  'lies': 19,
#  'having': 81,
#  'different': 30,
#  'member': 14,
#  'gang': 14,
#  'night': 156,
#  'holidays': 23,
#  'knew': 212,
#  'perfectly': 30,
#  'well': 312,
#  'anywhere': 16,
#  'spent': 34,
#  'vandalizing': 1,
#  'play': 17,
#  'park': 7,
#  'smoking': 6,
#  'corners': 4,
#  'throwing': 29,
#  'stones': 4,
#  'passing': 25,
#  'children': 14,
#  'seen': 139,
#  'them': 1001,
#  'it': 2654,
#  'during': 67,
#  'walks': 1,
#  'whinging': 16,
#  'most': 119,
#  'wandering': 5,
#  'streets': 5,
#  'scavenging': 3,
#  'newspapers': 4,
#  'bins': 2,
#  'along': 135,
#  'opening': 10,
#  'notes': 29,
#  'music': 1,
#  'heralded': 1,
#  'seven': 31,
#  'reached': 81,
#  'ears': 63,
#  'stomach': 43,
#  'turned': 269,
#  'tonight': 39,
#  'after': 275,
#  'month': 28,
#  'waiting': 61,
#  'numbers': 6,
#  'stranded': 2,
#  'holidaymakers': 2,
#  'fill': 9,
#  'airports': 1,
#  'spanish': 2,
#  'baggage': 2,
#  'strike': 12,
#  'reaches': 1,
#  'its': 158,
#  'second': 124,
#  'week': 49,
#  'lifelong': 3,
#  'siesta': 1,
#  'i': 1690,
#  'snarled': 32,
#  'end': 172,
#  'sentence': 12,
#  'no': 411,
#  'matter': 67,
#  'seemed': 251,
#  'unclench': 1,
#  'surely': 17,
#  'have': 955,
#  'first': 235,
#  'item': 2,
#  'death': 160,
#  'destruction': 2,
#  'more': 492,
#  'important': 40,
#  'than': 332,
#  'let': 135,
#  'long': 248,
#  'slow': 17,
#  'breath': 64,
#  'stared': 89,
#  'brilliant': 11,
#  'blue': 40,
#  'sky': 35,
#  'same': 91,
#  'tension': 3,
#  'expectation': 2,
#  'temporary': 3,
#  'relief': 25,
#  'then': 584,
#  'mounting': 6,
#  'always': 108,
#  'growing': 28,
#  'insistent': 1,
#  'question': 44,
#  'why': 205,
#  'nothing': 154,
#  'yet': 125,
#  'kept': 77,
#  'listening': 43,
#  'just': 618,
#  'case': 52,
#  'there': 694,
#  'some': 246,
#  'small': 97,
#  'recognized': 26,
#  'muggles': 32,
#  'an': 544,
#  'unexplained': 1,
#  'disappearance': 2,
#  'strange': 17,
#  'accident': 10,
#  'followed': 87,
#  'southeast': 3,
#  'next': 138,
#  'door': 384,
#  'bellowed': 29,
#  'sprinklers': 1,
#  'three': 177,
#  'morning': 77,
#  'helicopter': 1,
#  'crashed': 3,
#  'field': 5,
#  'surrey': 3,
#  'famous': 9,
#  'divorce': 1,
#  'her': 1772,
#  'husband': 9,
#  'interested': 19,
#  'sordid': 2,
#  'affairs': 1,
#  'sniffed': 4,
#  'obsessively': 1,
#  'magazine': 23,
#  'bony': 4,
#  'hands': 137,
#  'closed': 74,
#  'eyes': 341,
#  'against': 165,
#  'now': 635,
#  'blazing': 4,
#  'newsreader': 1,
#  'finally': 45,
#  'bungy': 2,
#  'budgie': 1,
#  'found': 163,
#  'novel': 2,
#  'keeping': 33,
#  'lives': 10,
#  'five': 90,
#  'feathers': 7,
#  'barnsley': 1,
#  'learned': 16,
#  'water': 29,
#  'ski': 1,
#  'mary': 1,
#  'dorkins': 1,
#  'went': 122,
#  'find': 133,
#  'opened': 109,
#  'skiing': 4,
#  'budgerigars': 2,
#  'else': 88,
#  'worth': 19,
#  'hearing': 56,
#  'rolled': 22,
#  'cautiously': 9,
#  'onto': 145,
#  'front': 193,
#  'raised': 99,
#  'knees': 35,
#  'elbows': 3,
#  'preparing': 3,
#  'crawl': 2,
#  'under': 142,
#  'moved': 70,
#  'two': 262,
#  'inches': 22,
#  'when': 589,
#  'several': 92,
#  'things': 97,
#  'quick': 26,
#  'succession': 2,
#  'loud': 49,
#  'echoing': 16,
#  'crack': 27,
#  'broke': 36,
#  'sleepy': 5,
#  'gunshot': 2,
#  'streaked': 8,
#  'parked': 1,
#  'flew': 43,
#  'sight': 62,
#  'shriek': 12,
#  'oath': 1,
#  'sound': 78,
#  'breaking': 14,
#  'china': 4,
#  'came': 150,
#  'signal': 8,
#  'jumped': 34,
#  'feet': 189,
#  'pulling': 62,
#  'waistband': 3,
#  'thin': 42,
#  'wooden': 21,
#  'wand': 312,
#  'unsheathing': 1,
#  'sword': 4,
#  'draw': 15,
#  'full': 120,
#  'height': 12,
#  'top': 104,
#  'head': 376,
#  'collided': 8,
#  'resultant': 2,
#  'crash': 15,
#  'made': 241,
#  'scream': 16,
#  'even': 215,
#  'louder': 21,
#  'felt': 230,
#  'split': 21,
#  'streaming': 7,
#  'swayed': 13,
#  'focus': 4,
#  'spot': 22,
#  'source': 12,
#  'noise': 49,
#  'barely': 47,
#  'staggered': 8,
#  'upright': 11,
#  'purple': 33,
#  'tightly': 32,
#  'throat': 26,
#  'ear': 38,
#  'anyone': 77,
#  'sees': 3,
#  'off': 429,
#  'me': 604,
#  'gasped': 28,
#  'few': 185,
#  'seconds': 57,
#  'struggled': 14,
#  'sausage': 1,
#  'fingers': 46,
#  'right': 399,
#  'maintaining': 4,
#  'firm': 9,
#  'grip': 26,
#  'pain': 58,
#  'gave': 177,
#  'particularly': 25,
#  'throb': 3,
#  'yelped': 5,
#  'released': 9,
#  'received': 29,
#  'electric': 5,
#  'shock': 26,
#  'force': 28,
#  'surged': 4,
#  'nephew': 1,
#  'making': 69,
#  'impossible': 11,
#  'hold': 26,
#  'panting': 19,
#  'forward': 106,
#  'straightened': 13,
#  'sign': 51,
#  'caused': 30,
#  'cracking': 6,
#  'faces': 30,
#  'peering': 25,
#  'various': 13,
#  'stuffed': 11,
#  'hastily': 32,
#  'innocent': 13,
#  'shouted': 97,
#  'waving': 18,
#  'net': 1,
#  'curtains': 23,
#  'you': 2753,
#  'backfire': 1,
#  'turn': 59,
#  'continued': 72,
#  'grin': 17,
#  'horrible': 46,
#  'manic': 2,
#  'until': 90,
#  'curious': 11,
#  'disappeared': 32,
#  'became': 51,
#  'grimace': 2,
#  'rage': 25,
#  'beckoned': 8,
#  'toward': 268,
#  'steps': 51,
#  'closer': 30,
#  'taking': 89,
#  'care': 63,
#  'stop': 83,
#  'point': 75,
#  'which': 367,
#  'outstretched': 8,
#  'resume': 3,
#  'strangling': 2,
#  'devil': 1,
#  'do': 551,
#  'mean': 192,
#  'asked': 314,
#  'croaky': 2,
#  'trembled': 7,
#  'fury': 16,
#  'coldly': 25,
#  'looking': 496,
#  'still': 410,
#  'hoping': 21,
#  'racket': 4,
#  'starting': 27,
#  'pistol': 1,
#  'make': 152,
#  'firmly': 41,
#  'horsey': 2,
#  'face': 400,
#  'appeared': 74,
#  'beside': 100,
#  'livid': 6,
#  'lurking': 8,
#  'good': 227,
#  'doing': 145,
#  'resigned': 5,
#  'exchanged': 21,
#  'looks': 67,
#  'outrage': 4,
#  'changes': 6,
#  'clever': 13,
#  'want': 268,
#  'give': 124,
#  'any': 210,
#  'tosh': 1,
#  'your': 540,
#  'breathed': 16,
#  'lowered': 25,
#  'get': 354,
#  'goggled': 4,
#  'liar': 7,
#  'are': 519,
#  'those': 121,
#  'too': 322,
#  'lip': 14,
#  'read': 89,
#  'word': 62,
#  'owls': 37,
#  'bringing': 13,
#  'triumphant': 11,
#  'whisper': 24,
#  'we': 651,
#  'pestilential': 1,
#  'birds': 8,
#  'hesitated': 23,
#  'moment': 220,
#  'cost': 6,
#  'something': 275,
#  'tell': 259,
#  'truth': 37,
#  'possibly': 11,
#  'how': 321,
#  'bad': 65,
#  'admitting': 2,
#  'tonelessly': 2,
#  'believe': 77,
#  'forcefully': 11,
#  'funny': 35,
#  'temper': 30,
#  'rising': 29,
#  'call': 46,
#  'wheeled': 7,
#  'crossed': 25,
#  'stepped': 40,
#  'low': 67,
#  'garden': 8,
#  'wall': 96,
#  'striding': 13,
#  'trouble': 45,
#  'later': 86,
#  'pay': 14,
#  'price': 5,
#  'rudeness': 2,
#  'much': 283,
#  'pressing': 8,
#  'matters': 11,
#  'mind': 122,
#  'sure': 184,
#  'apparating': 1,
#  'disapparating': 1,
#  'exactly': 71,
#  'dobby': 43,
#  'elf': 61,
#  'air': 127,
#  'possible': 25,
#  'following': 33,
#  'occurred': 17,
#  'completely': 45,
#  'deserted': 18,
#  'become': 32,
#  'walked': 118,
#  'hardly': 32,
#  'aware': 26,
#  'route': 4,
#  'pounded': 5,
#  'these': 114,
#  'often': 33,
#  'lately': 7,
#  'carried': 17,
#  'favorite': 17,
#  'haunts': 1,
#  'automatically': 13,
#  'glanced': 54,
#  'shoulder': 89,
#  'magical': 94,
#  'near': 35,
#  'among': 27,
#  'dying': 14,
#  'begonias': 2,
#  'spoken': 9,
#  'contact': 23,
#  'feeling': 145,
#  'frustration': 8,
#  'peaked': 2,
#  'certainty': 1,
#  'leaked': 2,
#  'desperate': 17,
#  'tiniest': 4,
#  'world': 42,
#  'belonged': 6,
#  'simply': 40,
#  'overreacting': 1,
#  'ordinary': 9,
#  'noises': 18,
#  'inside': 160,
#  'dull': 20,
#  'sinking': 16,
#  'sensation': 14,
#  'hopelessness': 2,
#  'plagued': 1,
#  'tomorrow': 36,
#  'awoken': 3,
#  'alarm': 10,
#  'owl': 57,
#  'delivered': 5,
#  'daily': 44,
#  'prophet': 55,
#  'continuing': 17,
#  'take': 165,
#  'merely': 42,
#  'page': 34,
#  'aside': 29,
#  'days': 54,
#  'idiots': 8,
#  'ran': 48,
#  'paper': 35,
#  'realized': 51,
#  'voldemort': 155,
#  'headline': 6,
#  'kind': 70,
#  'cared': 10,
#  'lucky': 15,
#  'also': 62,
#  'carrying': 41,
#  'letters': 25,
#  'best': 60,
#  'ron': 1169,
#  'hermione': 1196,
#  'bring': 29,
#  'since': 67,
#  'dashed': 12,
#  'say': 225,
#  'obviously': 29,
#  'told': 229,
#  'go': 284,
#  'astray': 1,
#  'busy': 33,
#  'details': 12,
#  'fair': 10,
#  'amount': 11,
#  'everything': 76,
#  'bothered': 6,
#  'precise': 7,
#  'date': 21,
#  'scribbled': 8,
#  'expect': 44,
#  'seeing': 40,
#  'birthday': 4,
#  'card': 3,
#  'soon': 56,
#  'vague': 5,
#  'hints': 3,
#  'place': 146,
#  'presumably': 3,
#  'bear': 9,
#  'think': 420,
#  'pair': 44,
#  'fun': 15,
#  'burrow': 8,
#  'angry': 50,
#  'both': 125,
#  'presents': 7,
#  'honeydukes': 1,
#  'chocolates': 1,
#  'unopened': 1,
#  'regretted': 4,
#  'eating': 20,
#  'wilting': 1,
#  'salad': 1,
#  'provided': 2,
#  'dinner': 43,
#  'proved': 6,
#  'capable': 4,
#  'handling': 5,
#  'forgotten': 26,
#  'done': 101,
#  'entered': 59,
#  'graveyard': 8,
#  'cedric': 36,
#  'being': 138,
#  'murdered': 12,
#  'tied': 11,
#  'tombstone': 1,
#  'nearly': 57,
#  'killed': 25,
#  'sternly': 9,
#  'hundredth': 1,
#  'enough': 130,
#  'revisiting': 1,
#  'nightmares': 4,
#  'without': 136,
#  'dwelling': 3,
#  'waking': 2,
#  'moments': 26,
#  'magnolia': 12,
#  'crescent': 8,
#  'halfway': 41,
#  'passed': 100,
#  'narrow': 15,
#  'alleyway': 17,
#  'side': 118,
#  'garage': 2,
#  'clapped': 13,
#  'godfather': 16,
#  'sirius': 553,
#  'least': 69,
#  'understand': 78,
#  'admittedly': 4,
#  'empty': 73,
#  'proper': 6,
#  'contained': 8,
#  'words': 80,
#  'caution': 2,
#  'consolation': 2,
#  'instead': 57,
#  'tantalizing': 1,
#  'must': 153,
#  'frustrating': 2,
#  'nose': 81,
#  'clean': 17,
#  'will': 263,
#  'okay': 52,
#  'careful': 20,
#  'rash': 3,
#  'road': 18,
#  'headed': 22,
#  'darkening': 3,
#  'advised': 5,
#  'resisted': 5,
#  'temptation': 4,
#  'tie': 4,
#  'trunk': 46,
#  'broomstick': 14,
#  'set': 99,
#  'behavior': 12,
#  'considering': 9,
#  'frustrated': 4,
#  'reduced': 5,
#  'beds': 14,
#  'might': 202,
#  'lord': 59,
#  'nevertheless': 13,
#  'galling': 1,
#  'man': 91,
#  'served': 3,
#  'twelve': 31,
#  'years': 127,
#  'wizard': 101,
#  'prison': 6,
#  'azkaban': 47,
#  'escaped': 22,
#  'attempted': 28,
#  'commit': 1,
#  'murder': 10,
#  'convicted': 5,
#  'gone': 94,
#  'run': 49,
#  'stolen': 8,
#  'hippogriff': 5,
#  'vaulted': 3,
#  'locked': 18,
#  'gate': 3,
#  'across': 137,
#  'grass': 21,
#  'surrounding': 22,
#  'swings': 2,
#  'sank': 35,
#  'managed': 50,
#  'break': 28,
#  'coiled': 3,
#  'arm': 65,
#  'chain': 5,
#  'moodily': 4,
#  'ground': 79,
#  'able': 96,
#  'hide': 13,
#  'fresh': 21,
#  'meantime': 4,
#  'another': 164,
#  'restless': 5,
#  'disturbed': 5,
#  'because': 166,
#  'unsettling': 1,
#  'dreams': 33,
#  'dark': 227,
#  'corridors': 31,
#  'finishing': 6,
#  'dead': 64,
#  'ends': 7,
#  'doors': 77,
#  'supposed': 76,
#  'trapped': 13,
#  'awake': 16,
#  'scar': 75,
#  'forehead': 27,
#  'prickled': 2,
#  'uncomfortably': 9,
#  'fool': 7,
#  'interesting': 20,
#  'anymore': 37,
#  'hurting': 8,
#  'warned': 19,
#  'getting': 79,
#  'stronger': 4,
#  'probably': 42,
#  'remind': 10,
#  'regular': 10,
#  'irritation': 2,
#  'expected': 37,
#  'worry': 38,
#  'injustice': 4,
#  'welled': 1,
#  'wanted': 133,
#  'yell': 10,
#  'known': 37,
#  'reward': 4,
#  'solid': 11,
#  'weeks': 22,
#  'cut': 31,
#  'squatting': 2,
#  'dumbledore': 536,
#  'easily': 15,
#  'together': 97,
#  'inviting': 6,
#  'longer': 50,
#  'endure': 5,
#  'telling': 71,
#  'sit': 29,
#  'tight': 24,
#  'resist': 7,
#  'write': 24,
#  'returned': 55,
#  'furious': 24,
#  'thoughts': 25,
#  'whirled': 6,
#  'insides': 16,
#  'writhed': 2,
#  'anger': 35,
#  'sultry': 1,
#  'velvety': 1,
#  'smell': 17,
#  'warm': 19,
#  'dry': 12,
#  'grumble': 2,
#  'traffic': 3,
#  'beyond': 26,
#  'railings': 2,
#  'sat': 100,
#  'swing': 4,
#  'voices': 36,
#  'interrupted': 18,
#  'musings': 1,
#  'streetlamps': 8,
#  'roads': 2,
#  'casting': 12,
#  ...}

# %% [markdown]
# ## Looping through all of these to quickly make a DTM out of a directory of text files
# We're going to combine our functions to automatically output a DTM.

# %%
import pandas as pd

def make_dtm(directory, scaled = False):
    files = absolute_paths(directory)
    
    result = [] # empty list where I will append the dictionaries of word counts
    
    for file in files: # looping over the results
        text = open(file).read() # read in text file
        tokens = tokenize(text) # make tokens list
        d = count_words(tokens) # use count_words to create a dictionary
        
        if scaled is True:
            total_words = sum(list(d.values()))
            for key,value in d.items():
                d[key] = d[key] / total_words
        
        # os.path.split() returns the base path and the filename as a pair:
        d['_filename'] = os.path.split(file)[-1] # include the _ before filename in case the text contains "filename"
        result.append(d) # append the unscaled result
    
    return pd.DataFrame(result).set_index('_filename').sort_index()

# %%
df = make_dtm(hp_dir, scaled = False)

# %% [markdown]
# You could apply this exact same code to your corpus directory!

# %%
df
# Out:
#                                a  aaaaaaaaargh  aaaaaaaarrrrrgh  aaaaaaand  \
# _filename
# 1 Sorcerers Stone.txt       1066           NaN              NaN        NaN
# 2 Chamber of Secrets.txt    1879           NaN              NaN        NaN
# 3 Prisoner of Azkaban.txt   2222           NaN              NaN        NaN
# 4 Goblet of Fire.txt        3680           NaN              1.0        1.0
# 5 Order of the Phoenix.txt  4967           1.0              NaN        NaN
# 6 Half-Blood Prince.txt     3323           NaN              NaN        NaN
# 7 Deathly Hallows.txt       3604           NaN              NaN        NaN
#
#                             aaaaaand  aaaaahed  aaaaargh  aaaah  aaah  aargh  \
# _filename
# 1 Sorcerers Stone.txt            NaN       NaN       NaN    NaN   NaN    NaN
# 2 Chamber of Secrets.txt         NaN       NaN       NaN    NaN   NaN    NaN
# 3 Prisoner of Azkaban.txt        NaN       NaN       NaN    NaN   NaN    NaN
# 4 Goblet of Fire.txt             1.0       1.0       NaN    NaN   1.0    NaN
# 5 Order of the Phoenix.txt       NaN       NaN       1.0    1.0   NaN    2.0
# 6 Half-Blood Prince.txt          NaN       NaN       1.0    1.0   NaN    NaN
# 7 Deathly Hallows.txt            NaN       NaN       NaN    NaN   NaN    1.0
#
#                             ...  zograf  zombie  zone  zonko  zoo  zoological  \
# _filename                   ...
# 1 Sorcerers Stone.txt       ...     NaN     2.0   NaN    NaN  7.0         NaN
# 2 Chamber of Secrets.txt    ...     NaN     NaN   NaN    NaN  2.0         NaN
# 3 Prisoner of Azkaban.txt   ...     NaN     1.0   NaN    1.0  NaN         NaN
# 4 Goblet of Fire.txt        ...     1.0     NaN   NaN    NaN  NaN         1.0
# 5 Order of the Phoenix.txt  ...     NaN     NaN   1.0    NaN  NaN         NaN
# 6 Half-Blood Prince.txt     ...     NaN     NaN   NaN    NaN  NaN         NaN
# 7 Deathly Hallows.txt       ...     NaN     NaN   NaN    NaN  NaN         NaN
#
#                             zoom  zoomed  zooming  éclairs
# _filename
# 1 Sorcerers Stone.txt        1.0       1      2.0      1.0
# 2 Chamber of Secrets.txt     NaN       2      NaN      NaN
# 3 Prisoner of Azkaban.txt    NaN       9      3.0      NaN
# 4 Goblet of Fire.txt         4.0       9     12.0      NaN
# 5 Order of the Phoenix.txt   2.0      23      7.0      NaN
# 6 Half-Blood Prince.txt      NaN       7      2.0      1.0
# 7 Deathly Hallows.txt        1.0       6      5.0      NaN
#
# [7 rows x 19910 columns]

# %% [markdown]
# # Filtering our dataframe for "real" words
# Our functions counted 19,911 types in the *Harry Potter* books. But this includes some "words" that we're not really interested in like "aaaaaaaarrrrrgh."
#
# We can make our processing faster by dropping very rare words. To do this, we have to do a few things:

# %% [markdown]
# ## Dropping low-frequency words
# Even if a word were really interesting to us as readers, we can't do much with it computationally if it only appears once or twice in a corpus.
#
# To do this, one approach would be to sum all of the columns, and find out which ones appear below our cutoff.
#
# Let's say we only want to keep words that appear, on average, once per book. For that, we would want a minimum value of `7`:

# %%
word_sums = df.sum(min_count = 7)

# %%
word_sums[word_sums > 7]
# Out:
# a               20741.0
# able              385.0
# about            2455.0
# above             220.0
# absurd              9.0
# accept             41.0
# accepted           17.0
# accidentally       32.0
# accidents          18.0
# according          41.0
# across            548.0
# act                79.0
# acted              26.0
# acting             43.0
# actually          142.0
# add                32.0
# added             249.0
# addressed          36.0
# advice             36.0
# affect             13.0
# afford             17.0
# afraid            127.0
# after            1143.0
# afternoon          99.0
# afterward          29.0
# again            1932.0
# against           640.0
# age                93.0
# ages               61.0
# ago               221.0
#                  ...
# wrenched           48.0
# wrinkled           12.0
# wrist              38.0
# write              72.0
# writing            91.0
# written            77.0
# wrong             244.0
# wrote              65.0
# yawned             27.0
# yawning            24.0
# yeah              167.0
# year              533.0
# years             528.0
# yeh               286.0
# yell               44.0
# yelled            259.0
# yellow             73.0
# yellowish          19.0
# yer                91.0
# yes               337.0
# yesterday          39.0
# yet               460.0
# you             10838.0
# young             165.0
# younger            46.0
# youngest           19.0
# your             2042.0
# yours              74.0
# yourself          157.0
# zoomed             57.0
# Length: 2494, dtype: float64

# %%
word_sums2 = df.sum()

# %%
word_sums[df.sum() > 7]
# Out:
# a               0.148597
# able            0.002571
# about           0.017481
# above           0.001436
# absurd          0.000077
# accept          0.000251
# accepted        0.000137
# accidentally    0.000239
# accidents       0.000117
# according       0.000252
# across          0.003649
# act             0.000500
# acted           0.000181
# acting          0.000313
# actually        0.000808
# add             0.000241
# added           0.001653
# addressed       0.000285
# advice          0.000238
# affect          0.000110
# afford          0.000173
# afraid          0.000833
# after           0.007515
# afternoon       0.000751
# afterward       0.000185
# again           0.012539
# against         0.004194
# age             0.000608
# ages            0.000490
# ago             0.001459
#                   ...
# wrenched        0.000328
# wrinkled        0.000118
# wrist           0.000326
# write           0.000512
# writing         0.000648
# written         0.000592
# wrong           0.001755
# wrote           0.000465
# yawned          0.000209
# yawning         0.000168
# yeah            0.000945
# year            0.003891
# years           0.004020
# yeh             0.002786
# yell            0.000276
# yelled          0.001891
# yellow          0.000576
# yellowish       0.000169
# yer             0.001384
# yes             0.002426
# yesterday       0.000342
# yet             0.003147
# you             0.073671
# young           0.001085
# younger         0.000311
# youngest        0.000196
# your            0.013895
# yours           0.000553
# yourself        0.001113
# zoomed          0.000350
# Length: 2494, dtype: float64

# %%
word_sums2[df.sum() > 7]
# Out:
# a                 20741.0
# aback                31.0
# abandon              10.0
# abandoned            33.0
# abandoning           15.0
# abbott               16.0
# aberforth            71.0
# ability              23.0
# able                385.0
# about              2455.0
# above               220.0
# abroad               14.0
# abrupt               16.0
# abruptly             64.0
# absence              33.0
# absent               10.0
# absently             12.0
# absentmindedly       17.0
# absolute             10.0
# absolutely           30.0
# absorbed             10.0
# absurd                9.0
# abuse                 8.0
# accept               41.0
# accepted             17.0
# accepting             9.0
# access               10.0
# accident             36.0
# accidentally         32.0
# accidents            18.0
#                    ...
# yellowish            19.0
# yells                24.0
# yelp                  8.0
# yelped               13.0
# yer                  91.0
# yes                 337.0
# yesterday            39.0
# yet                 460.0
# yew                  11.0
# you               10838.0
# young               165.0
# younger              46.0
# youngest             19.0
# your               2042.0
# yours                74.0
# yourself            157.0
# yourselves           31.0
# youth                15.0
# yule                 14.0
# zabini               40.0
# zacharias            33.0
# zat                  14.0
# ze                   26.0
# zero                 11.0
# zey                   8.0
# zis                   8.0
# zoo                   9.0
# zoom                  8.0
# zoomed               57.0
# zooming              31.0
# Length: 6713, dtype: float64

# %%
word_sums = word_sums[word_sums.notnull()] # .notnull() drops all of the None values

# %%
len(word_sums)
# Out:
# 2494

# %% [markdown]
# ## How many are left?

# %%
len(word_sums[word_sums.notnull()])
# Out:
# 2494

# %% [markdown]
# There are only 2,494 words that appear more than once per book on average in *Harry Potter*. If we were to cut our dataframe down just for these words, we would be able to do almost *90% fewer computations* to analyze our data.
#
# We could change that `min_count` argument value to anything we wanted. Maybe we just want to get rid of words that appear 1 time? There are a lot of possible approaches you can make the case for, but this makes your data much more manageable, and (usually) much closer to what you want for your project.

# %% [markdown]
# # How do these words change over time?

# %% [markdown]
# The value of Pandas comes primarily from the fact that it allows us to easily slice, dice, and add new data to our results.
#
# Let's say we want to analyze how Rowling's use of these words changes over time. We'll start with a scaled data frame so that each book is given equal weight:

# %%
df = make_dtm(hp_dir, scaled = True)

# %% [markdown]
# First things first, let's cut this dataframe down to size using our new list of words that average one instance per book in our corpus.
#
# The `.index` method allows us to see all of the words:

# %%
word_sums.index
# Out:
# Index(['a', 'able', 'about', 'above', 'absurd', 'accept', 'accepted',
#        'accidentally', 'accidents', 'according',
#        ...
#        'yesterday', 'yet', 'you', 'young', 'younger', 'youngest', 'your',
#        'yours', 'yourself', 'zoomed'],
#       dtype='object', length=2494)

# %% [markdown]
# And we can use that list to filter our DataFrame!
#
# First, we need to set our `_filename` variable as our index (AKA our row names) so that we don't lose it:

# %%
df
# Out:
#                                    a  aaaaaaaaargh  aaaaaaaarrrrrgh  \
# _filename
# 1 Sorcerers Stone.txt       0.025712           NaN              NaN
# 2 Chamber of Secrets.txt    0.022353           NaN              NaN
# 3 Prisoner of Azkaban.txt   0.021197           NaN              NaN
# 4 Goblet of Fire.txt        0.019706           NaN         0.000005
# 5 Order of the Phoenix.txt  0.020075      0.000004              NaN
# 6 Half-Blood Prince.txt     0.020399           NaN              NaN
# 7 Deathly Hallows.txt       0.019155           NaN              NaN
#
#                             aaaaaaand  aaaaaand  aaaaahed  aaaaargh     aaaah  \
# _filename
# 1 Sorcerers Stone.txt             NaN       NaN       NaN       NaN       NaN
# 2 Chamber of Secrets.txt          NaN       NaN       NaN       NaN       NaN
# 3 Prisoner of Azkaban.txt         NaN       NaN       NaN       NaN       NaN
# 4 Goblet of Fire.txt         0.000005  0.000005  0.000005       NaN       NaN
# 5 Order of the Phoenix.txt        NaN       NaN       NaN  0.000004  0.000004
# 6 Half-Blood Prince.txt           NaN       NaN       NaN  0.000006  0.000006
# 7 Deathly Hallows.txt             NaN       NaN       NaN       NaN       NaN
#
#                                 aaah     aargh  ...    zograf    zombie  \
# _filename                                       ...
# 1 Sorcerers Stone.txt            NaN       NaN  ...       NaN  0.000048
# 2 Chamber of Secrets.txt         NaN       NaN  ...       NaN       NaN
# 3 Prisoner of Azkaban.txt        NaN       NaN  ...       NaN  0.000010
# 4 Goblet of Fire.txt        0.000005       NaN  ...  0.000005       NaN
# 5 Order of the Phoenix.txt       NaN  0.000008  ...       NaN       NaN
# 6 Half-Blood Prince.txt          NaN       NaN  ...       NaN       NaN
# 7 Deathly Hallows.txt            NaN  0.000005  ...       NaN       NaN
#
#                                 zone    zonko       zoo  zoological      zoom  \
# _filename
# 1 Sorcerers Stone.txt            NaN      NaN  0.000169         NaN  0.000024
# 2 Chamber of Secrets.txt         NaN      NaN  0.000024         NaN       NaN
# 3 Prisoner of Azkaban.txt        NaN  0.00001       NaN         NaN       NaN
# 4 Goblet of Fire.txt             NaN      NaN       NaN    0.000005  0.000021
# 5 Order of the Phoenix.txt  0.000004      NaN       NaN         NaN  0.000008
# 6 Half-Blood Prince.txt          NaN      NaN       NaN         NaN       NaN
# 7 Deathly Hallows.txt            NaN      NaN       NaN         NaN  0.000005
#
#                               zoomed   zooming   éclairs
# _filename
# 1 Sorcerers Stone.txt       0.000024  0.000048  0.000024
# 2 Chamber of Secrets.txt    0.000024       NaN       NaN
# 3 Prisoner of Azkaban.txt   0.000086  0.000029       NaN
# 4 Goblet of Fire.txt        0.000048  0.000064       NaN
# 5 Order of the Phoenix.txt  0.000093  0.000028       NaN
# 6 Half-Blood Prince.txt     0.000043  0.000012  0.000006
# 7 Deathly Hallows.txt       0.000032  0.000027       NaN
#
# [7 rows x 19910 columns]

# %% [markdown]
# Now we can use `word_list` to drop a bunch of columns:

# %%
valid_words = word_sums[word_sums.notnull()]

# %%
valid_words.index
# Out:
# Index(['a', 'able', 'about', 'above', 'absurd', 'accept', 'accepted',
#        'accidentally', 'accidents', 'according',
#        ...
#        'yesterday', 'yet', 'you', 'young', 'younger', 'youngest', 'your',
#        'yours', 'yourself', 'zoomed'],
#       dtype='object', length=2494)

# %%
df = df[valid_words.index]

# %%
df
# Out:
#                                    a      able     about     above    absurd  \
# _filename
# 1 Sorcerers Stone.txt       0.025712  0.000241  0.003184  0.000121  0.000024
# 2 Chamber of Secrets.txt    0.022353  0.000428  0.002332  0.000250  0.000012
# 3 Prisoner of Azkaban.txt   0.021197  0.000343  0.002471  0.000200  0.000010
# 4 Goblet of Fire.txt        0.019706  0.000278  0.002811  0.000246  0.000005
# 5 Order of the Phoenix.txt  0.020075  0.000388  0.002425  0.000243  0.000008
# 6 Half-Blood Prince.txt     0.020399  0.000503  0.002302  0.000153  0.000012
# 7 Deathly Hallows.txt       0.019155  0.000388  0.001956  0.000223  0.000005
#
#                               accept  accepted  accidentally  accidents  \
# _filename
# 1 Sorcerers Stone.txt       0.000024  0.000048      0.000024   0.000024
# 2 Chamber of Secrets.txt    0.000012  0.000012      0.000059   0.000012
# 3 Prisoner of Azkaban.txt   0.000019  0.000010      0.000057   0.000010
# 4 Goblet of Fire.txt        0.000043  0.000011      0.000037   0.000011
# 5 Order of the Phoenix.txt  0.000028  0.000012      0.000032   0.000032
# 6 Half-Blood Prince.txt     0.000055  0.000012      0.000012   0.000012
# 7 Deathly Hallows.txt       0.000069  0.000032      0.000016   0.000016
#
#                             according  ...  yesterday       yet       you  \
# _filename                              ...
# 1 Sorcerers Stone.txt        0.000024  ...   0.000121  0.000507  0.009913
# 2 Chamber of Secrets.txt     0.000024  ...   0.000059  0.000345  0.009815
# 3 Prisoner of Azkaban.txt    0.000019  ...   0.000038  0.000487  0.010551
# 4 Goblet of Fire.txt         0.000037  ...   0.000043  0.000386  0.009398
# 5 Order of the Phoenix.txt   0.000040  ...   0.000036  0.000505  0.011127
# 6 Half-Blood Prince.txt      0.000049  ...   0.000018  0.000430  0.012455
# 7 Deathly Hallows.txt        0.000058  ...   0.000027  0.000489  0.010412
#
#                                young   younger  youngest      your     yours  \
# _filename
# 1 Sorcerers Stone.txt       0.000169  0.000048  0.000096  0.002002  0.000145
# 2 Chamber of Secrets.txt    0.000095  0.000024  0.000024  0.001761  0.000048
# 3 Prisoner of Azkaban.txt   0.000086  0.000019  0.000019  0.001965  0.000076
# 4 Goblet of Fire.txt        0.000155  0.000043  0.000016  0.001826  0.000037
# 5 Order of the Phoenix.txt  0.000137  0.000008  0.000008  0.002183  0.000069
# 6 Half-Blood Prince.txt     0.000209  0.000074  0.000006  0.002314  0.000061
# 7 Deathly Hallows.txt       0.000234  0.000096  0.000027  0.001844  0.000117
#
#                             yourself    zoomed
# _filename
# 1 Sorcerers Stone.txt       0.000193  0.000024
# 2 Chamber of Secrets.txt    0.000095  0.000024
# 3 Prisoner of Azkaban.txt   0.000219  0.000086
# 4 Goblet of Fire.txt        0.000171  0.000048
# 5 Order of the Phoenix.txt  0.000146  0.000093
# 6 Half-Blood Prince.txt     0.000172  0.000043
# 7 Deathly Hallows.txt       0.000117  0.000032
#
# [7 rows x 2494 columns]

# %% [markdown]
# # Which words are the most frequent overall?
# There are multiple ways of approaching this question.
#
# Since we're using a scaled matrix, let's evaluate their frequencies as an average of each word's relative frequency over all of the books:

# %%
len(df) # len provides the number of rows in a dataframe
# Out:
# 7

# %% [markdown]
# We can use `len` in combination with `df.sum()` to easily create an average:

# %% [markdown]
# Let's look at what `df.sum()` outputs:

# %%
df.sum()[:3]
# Out:
# a        0.148597
# able     0.002571
# about    0.017481
# dtype: float64

# %%
df.sum()[-3:]
# Out:
# yours       0.000553
# yourself    0.001113
# zoomed      0.000350
# dtype: float64

# %%
df['a']
# Out:
# _filename
# 1 Sorcerers Stone.txt         0.025712
# 2 Chamber of Secrets.txt      0.022353
# 3 Prisoner of Azkaban.txt     0.021197
# 4 Goblet of Fire.txt          0.019706
# 5 Order of the Phoenix.txt    0.020075
# 6 Half-Blood Prince.txt       0.020399
# 7 Deathly Hallows.txt         0.019155
# Name: a, dtype: float64

# %% [markdown]
# So now we can use `df.sum()` and simply divide each value in the series by the `len` of df:

# %%
avg_freq = df.sum() / len(df)

# %%
avg_freq[:5]
# Out:
# a         0.021228
# able      0.000367
# about     0.002497
# above     0.000205
# absurd    0.000011
# dtype: float64

# %% [markdown]
# Our 25 most frequent words contain two character names ('harry', 'ron') along with other high-frequency words that are usually present in English-language documents:

# %%
avg_freq.sort_values(ascending=False)[:25]
# Out:
# the      0.050390
# and      0.026280
# to       0.025690
# a        0.021228
# of       0.020903
# he       0.019339
# harry    0.016008
# was      0.015512
# his      0.014060
# said     0.013590
# in       0.012398
# it       0.012019
# you      0.010524
# had      0.009809
# that     0.009180
# at       0.008438
# as       0.007308
# on       0.007186
# i        0.006993
# him      0.006619
# with     0.006328
# they     0.005794
# ron      0.005506
# for      0.005458
# but      0.005015
# dtype: float64

# %% [markdown]
# # Which words does Rowling use most differently over time?
# We can use these averages to compare the frequency of a word in a given text with its average frequency. That shows us whether a word is used more or less often than we would expect, if all of the words were distributed evenly across the books.
#
# Positive values indicate that the observation exceeded the average; negative values indicate that they fell below the average.
#
# The command is amazingly simple. Pandas matches the column names correctly for us:

# %%
df + 30
# Out:
#                                     a       able      about      above  \
# _filename
# 1 Sorcerers Stone.txt       30.025712  30.000241  30.003184  30.000121
# 2 Chamber of Secrets.txt    30.022353  30.000428  30.002332  30.000250
# 3 Prisoner of Azkaban.txt   30.021197  30.000343  30.002471  30.000200
# 4 Goblet of Fire.txt        30.019706  30.000278  30.002811  30.000246
# 5 Order of the Phoenix.txt  30.020075  30.000388  30.002425  30.000243
# 6 Half-Blood Prince.txt     30.020399  30.000503  30.002302  30.000153
# 7 Deathly Hallows.txt       30.019155  30.000388  30.001956  30.000223
#
#                                absurd     accept   accepted  accidentally  \
# _filename
# 1 Sorcerers Stone.txt       30.000024  30.000024  30.000048     30.000024
# 2 Chamber of Secrets.txt    30.000012  30.000012  30.000012     30.000059
# 3 Prisoner of Azkaban.txt   30.000010  30.000019  30.000010     30.000057
# 4 Goblet of Fire.txt        30.000005  30.000043  30.000011     30.000037
# 5 Order of the Phoenix.txt  30.000008  30.000028  30.000012     30.000032
# 6 Half-Blood Prince.txt     30.000012  30.000055  30.000012     30.000012
# 7 Deathly Hallows.txt       30.000005  30.000069  30.000032     30.000016
#
#                             accidents  according  ...  yesterday        yet  \
# _filename                                         ...
# 1 Sorcerers Stone.txt       30.000024  30.000024  ...  30.000121  30.000507
# 2 Chamber of Secrets.txt    30.000012  30.000024  ...  30.000059  30.000345
# 3 Prisoner of Azkaban.txt   30.000010  30.000019  ...  30.000038  30.000487
# 4 Goblet of Fire.txt        30.000011  30.000037  ...  30.000043  30.000386
# 5 Order of the Phoenix.txt  30.000032  30.000040  ...  30.000036  30.000505
# 6 Half-Blood Prince.txt     30.000012  30.000049  ...  30.000018  30.000430
# 7 Deathly Hallows.txt       30.000016  30.000058  ...  30.000027  30.000489
#
#                                   you      young    younger   youngest  \
# _filename
# 1 Sorcerers Stone.txt       30.009913  30.000169  30.000048  30.000096
# 2 Chamber of Secrets.txt    30.009815  30.000095  30.000024  30.000024
# 3 Prisoner of Azkaban.txt   30.010551  30.000086  30.000019  30.000019
# 4 Goblet of Fire.txt        30.009398  30.000155  30.000043  30.000016
# 5 Order of the Phoenix.txt  30.011127  30.000137  30.000008  30.000008
# 6 Half-Blood Prince.txt     30.012455  30.000209  30.000074  30.000006
# 7 Deathly Hallows.txt       30.010412  30.000234  30.000096  30.000027
#
#                                  your      yours   yourself     zoomed
# _filename
# 1 Sorcerers Stone.txt       30.002002  30.000145  30.000193  30.000024
# 2 Chamber of Secrets.txt    30.001761  30.000048  30.000095  30.000024
# 3 Prisoner of Azkaban.txt   30.001965  30.000076  30.000219  30.000086
# 4 Goblet of Fire.txt        30.001826  30.000037  30.000171  30.000048
# 5 Order of the Phoenix.txt  30.002183  30.000069  30.000146  30.000093
# 6 Half-Blood Prince.txt     30.002314  30.000061  30.000172  30.000043
# 7 Deathly Hallows.txt       30.001844  30.000117  30.000117  30.000032
#
# [7 rows x 2494 columns]

# %%
df - avg_freq
# Out:
#                                    a      able     about     above  \
# _filename
# 1 Sorcerers Stone.txt       0.004484 -0.000126  0.000687 -0.000085
# 2 Chamber of Secrets.txt    0.001125  0.000061 -0.000166  0.000045
# 3 Prisoner of Azkaban.txt  -0.000031 -0.000024 -0.000026 -0.000005
# 4 Goblet of Fire.txt       -0.001522 -0.000089  0.000314  0.000041
# 5 Order of the Phoenix.txt -0.001153  0.000021 -0.000072  0.000037
# 6 Half-Blood Prince.txt    -0.000830  0.000136 -0.000195 -0.000052
# 7 Deathly Hallows.txt      -0.002073  0.000021 -0.000541  0.000018
#
#                                   absurd    accept  accepted  accidentally  \
# _filename
# 1 Sorcerers Stone.txt       1.317925e-05 -0.000012  0.000029     -0.000010
# 2 Chamber of Secrets.txt    9.554399e-07 -0.000024 -0.000008      0.000025
# 3 Prisoner of Azkaban.txt  -1.401257e-06 -0.000017 -0.000010      0.000023
# 4 Goblet of Fire.txt       -5.586042e-06  0.000007 -0.000009      0.000003
# 5 Order of the Phoenix.txt -2.857611e-06 -0.000008 -0.000007     -0.000002
# 6 Half-Blood Prince.txt     1.336279e-06  0.000019 -0.000007     -0.000022
# 7 Deathly Hallows.txt      -5.626058e-06  0.000033  0.000012     -0.000018
#
#                                accidents  according  ...  yesterday       yet  \
# _filename                                            ...
# 1 Sorcerers Stone.txt       7.431419e-06  -0.000012  ...   0.000072  0.000057
# 2 Chamber of Secrets.txt   -4.792390e-06  -0.000012  ...   0.000011 -0.000105
# 3 Prisoner of Azkaban.txt  -7.149087e-06  -0.000017  ...  -0.000011  0.000037
# 4 Goblet of Fire.txt       -5.978947e-06   0.000001  ...  -0.000006 -0.000064
# 5 Order of the Phoenix.txt  1.564463e-05   0.000004  ...  -0.000013  0.000056
# 6 Half-Blood Prince.txt    -4.411551e-06   0.000013  ...  -0.000031 -0.000020
# 7 Deathly Hallows.txt      -7.440709e-07   0.000022  ...  -0.000022  0.000039
#
#                                  you         young   younger  youngest  \
# _filename
# 1 Sorcerers Stone.txt      -0.000611  1.382020e-05  0.000004  0.000068
# 2 Chamber of Secrets.txt   -0.000710 -5.985005e-05 -0.000021 -0.000004
# 3 Prisoner of Azkaban.txt   0.000027 -6.916392e-05 -0.000025 -0.000009
# 4 Goblet of Fire.txt       -0.001126  2.715052e-07 -0.000002 -0.000012
# 5 Order of the Phoenix.txt  0.000602 -1.760426e-05 -0.000036 -0.000020
# 6 Half-Blood Prince.txt     0.001931  5.369186e-05  0.000029 -0.000022
# 7 Deathly Hallows.txt      -0.000112  7.883466e-05  0.000051 -0.000001
#
#                                 your     yours  yourself    zoomed
# _filename
# 1 Sorcerers Stone.txt       0.000017  0.000066  0.000034 -0.000026
# 2 Chamber of Secrets.txt   -0.000224 -0.000031 -0.000064 -0.000026
# 3 Prisoner of Azkaban.txt  -0.000020 -0.000003  0.000060  0.000036
# 4 Goblet of Fire.txt       -0.000159 -0.000042  0.000012 -0.000002
# 5 Order of the Phoenix.txt  0.000198 -0.000010 -0.000014  0.000043
# 6 Half-Blood Prince.txt     0.000329 -0.000018  0.000013 -0.000007
# 7 Deathly Hallows.txt      -0.000141  0.000038 -0.000042 -0.000018
#
# [7 rows x 2494 columns]

# %% [markdown]
# Now we want to compute the *biggest* difference between the low value and the high value for each column:

# %%
df_scaled = df - avg_freq

# %% [markdown]
# We want to take the absolute value with `abs` to make sure that we're seeing the biggest change:

# %%
df_scaled.max()
# Out:
# a               0.004484
# able            0.000136
# about           0.000687
# above           0.000045
# absurd          0.000013
# accept          0.000033
# accepted        0.000029
# accidentally    0.000025
# accidents       0.000016
# according       0.000022
# across          0.000156
# act             0.000040
# acted           0.000027
# acting          0.000015
# actually        0.000075
# add             0.000049
# added           0.000063
# addressed       0.000056
# advice          0.000023
# affect          0.000022
# afford          0.000048
# afraid          0.000043
# after           0.000255
# afternoon       0.000086
# afterward       0.000032
# again           0.000440
# against         0.000193
# age             0.000026
# ages            0.000051
# ago             0.000038
#                   ...
# wrenched        0.000015
# wrinkled        0.000031
# wrist           0.000074
# write           0.000058
# writing         0.000122
# written         0.000084
# wrong           0.000039
# wrote           0.000088
# yawned          0.000018
# yawning         0.000024
# yeah            0.000144
# year            0.000229
# years           0.000415
# yeh             0.001001
# yell            0.000014
# yelled          0.000169
# yellow          0.000042
# yellowish       0.000048
# yer             0.000864
# yes             0.000256
# yesterday       0.000072
# yet             0.000057
# you             0.001931
# young           0.000079
# younger         0.000051
# youngest        0.000068
# your            0.000329
# yours           0.000066
# yourself        0.000060
# zoomed          0.000043
# Length: 2494, dtype: float64

# %%
(df_scaled.abs().max() - df_scaled.abs().min()).sort_values(ascending = False)
# Out:
# a             0.004453
# the           0.004183
# hermione      0.002822
# dumbledore    0.002802
# said          0.002736
# of            0.002503
# on            0.002491
# hagrid        0.002472
# i             0.002407
# they          0.002359
# her           0.002348
# ron           0.002307
# that          0.002290
# and           0.002234
# to            0.002147
# harry         0.002099
# uncle         0.001935
# he            0.001928
# dudley        0.001928
# you           0.001904
# black         0.001777
# not           0.001678
# vernon        0.001621
# it            0.001582
# wand          0.001546
# professor     0.001524
# very          0.001247
# she           0.001208
# all           0.001199
# mr            0.001147
#                 ...
# supply        0.000008
# crime         0.000008
# brushed       0.000008
# dozen         0.000008
# spots         0.000008
# tin           0.000008
# behave        0.000008
# sallow        0.000007
# greeting      0.000007
# occasions     0.000007
# slapping      0.000007
# splattered    0.000007
# sunny         0.000007
# gleamed       0.000007
# strangled     0.000007
# laden         0.000007
# swig          0.000007
# grunting      0.000007
# peace         0.000007
# sprinting     0.000006
# holes         0.000006
# mentioned     0.000006
# fading        0.000006
# enemies       0.000006
# windowsill    0.000006
# awkward       0.000006
# grunt         0.000005
# mouse         0.000005
# mystery       0.000005
# planned       0.000005
# Length: 2494, dtype: float64

# %% [markdown]
# So how do we read these results? Characters like Dumbledore, Dudley, and Sirius Black ('black') have some of the largest discrepancies between their smallest values and their largest values. Of course, at the top of this list we still see many of the highest frequency words because they have largest absolute amounts to gain or lose.
#
# At the bottom we see words that have almost no difference between their highest and lowest values, implying that they are used at very similar rates across all of the books.
#
# Indeed, let's look at 'awkward':

# %%
avg_freq['awkward']
# Out:
# 2.5798655897512307e-05

# %%
df['awkward']
# Out:
# _filename
# 1 Sorcerers Stone.txt         0.000024
# 2 Chamber of Secrets.txt      0.000024
# 3 Prisoner of Azkaban.txt     0.000029
# 4 Goblet of Fire.txt          0.000021
# 5 Order of the Phoenix.txt    0.000032
# 6 Half-Blood Prince.txt       0.000018
# 7 Deathly Hallows.txt         0.000032
# Name: awkward, dtype: float64

# %%
df_scaled['awkward']
# Out:
# _filename
# 1 Sorcerers Stone.txt        -0.000002
# 2 Chamber of Secrets.txt     -0.000002
# 3 Prisoner of Azkaban.txt     0.000003
# 4 Goblet of Fire.txt         -0.000004
# 5 Order of the Phoenix.txt    0.000007
# 6 Half-Blood Prince.txt      -0.000007
# 7 Deathly Hallows.txt         0.000006
# Name: awkward, dtype: float64

# %% [markdown]
# This is both a word with relatively few instances, and those instances are distributed similarly across the books.
#
# So this result is perhaps overdetermined by the differences in the frequencies of the words. How can we correct that?

# %% [markdown]
# # Observations and expectations
# We can try to account for this by looking at the number of observed values over the number of expected values: Which word furthest outperformed its average?

# %%
(df.abs().max() / avg_freq).sort_values(ascending=False)[:30]
# Out:
# dursley      5.868460
# prince       5.844709
# yer          5.366949
# platforms    5.302555
# chamber      5.296560
# spiders      5.161556
# sword        5.148417
# flavor       4.988612
# egg          4.823550
# hut          4.804517
# twins        4.733027
# toad         4.704410
# lots         4.535718
# gaunt        4.509343
# storm        4.420254
# bus          4.348360
# dudley       4.312980
# coat         4.290419
# shops        4.194387
# bronze       4.131053
# noses        4.109805
# goblin       4.093261
# car          4.044799
# gringotts    4.035403
# package      4.035296
# monster      3.993382
# lumpy        3.990766
# problems     3.976754
# bird         3.976557
# nick         3.943294
# dtype: float64

# %% [markdown]
# Now we're getting into the subject matter of the books! There are words that are much more frequent in certain books than they are throughout the rest of the series, like the Dursleys, the "prince" of book 6, the "chamber" of secrets, etc.
#
# Which words most seriously under-perform their averages?

# %%
(df.abs().min() / avg_freq).sort_values()[:30]
# Out:
# fudge       0.012596
# severus     0.035531
# points      0.035930
# tent        0.035993
# hospital    0.037188
# sir         0.037962
# field       0.038720
# class       0.042556
# upon        0.047986
# charlie     0.049545
# w           0.050747
# lily        0.052189
# bludger     0.053000
# bell        0.056057
# team        0.057067
# quaffle     0.058731
# twins       0.061349
# leaky       0.062511
# tom         0.062591
# envelope    0.064803
# norris      0.065580
# pomfrey     0.066955
# feast       0.068260
# package     0.068399
# classes     0.068458
# shop        0.068813
# james       0.071593
# goblin      0.072029
# lunch       0.074397
# among       0.077819
# dtype: float64

# %% [markdown]
# In this result, we see that there are words that are used much less than expected on average in certain books, like Cornelius Fudge ('fudge') who comes up very little in at least one book. Interesting! Let's see which ones:

# %%
(df / avg_freq)['fudge']
# Out:
# _filename
# 1 Sorcerers Stone.txt         0.057163
# 2 Chamber of Secrets.txt      0.479293
# 3 Prisoner of Azkaban.txt     2.283456
# 4 Goblet of Fire.txt          0.964502
# 5 Order of the Phoenix.txt    2.126429
# 6 Half-Blood Prince.txt       1.076561
# 7 Deathly Hallows.txt         0.012596
# Name: fudge, dtype: float64

# %% [markdown]
# So, if we can assume that most instances of 'fudge' refer to the character Cornelius Fudge, then we can see that *Azkaban* and *Phoenix* have a lot to do with him, where he shows up very little in others.

# %% [markdown]
# # Calculate type-token ratio with DTM
# Let's compare the type-token ratios of each of the books in our corpus. We're going to make a new DataFrame with unscaled counts:

# %%
df = make_dtm(hp_dir, scaled = False)

# %%
df
# Out:
#                                a  aaaaaaaaargh  aaaaaaaarrrrrgh  aaaaaaand  \
# _filename
# 1 Sorcerers Stone.txt       1066           NaN              NaN        NaN
# 2 Chamber of Secrets.txt    1879           NaN              NaN        NaN
# 3 Prisoner of Azkaban.txt   2222           NaN              NaN        NaN
# 4 Goblet of Fire.txt        3680           NaN              1.0        1.0
# 5 Order of the Phoenix.txt  4967           1.0              NaN        NaN
# 6 Half-Blood Prince.txt     3323           NaN              NaN        NaN
# 7 Deathly Hallows.txt       3604           NaN              NaN        NaN
#
#                             aaaaaand  aaaaahed  aaaaargh  aaaah  aaah  aargh  \
# _filename
# 1 Sorcerers Stone.txt            NaN       NaN       NaN    NaN   NaN    NaN
# 2 Chamber of Secrets.txt         NaN       NaN       NaN    NaN   NaN    NaN
# 3 Prisoner of Azkaban.txt        NaN       NaN       NaN    NaN   NaN    NaN
# 4 Goblet of Fire.txt             1.0       1.0       NaN    NaN   1.0    NaN
# 5 Order of the Phoenix.txt       NaN       NaN       1.0    1.0   NaN    2.0
# 6 Half-Blood Prince.txt          NaN       NaN       1.0    1.0   NaN    NaN
# 7 Deathly Hallows.txt            NaN       NaN       NaN    NaN   NaN    1.0
#
#                             ...  zograf  zombie  zone  zonko  zoo  zoological  \
# _filename                   ...
# 1 Sorcerers Stone.txt       ...     NaN     2.0   NaN    NaN  7.0         NaN
# 2 Chamber of Secrets.txt    ...     NaN     NaN   NaN    NaN  2.0         NaN
# 3 Prisoner of Azkaban.txt   ...     NaN     1.0   NaN    1.0  NaN         NaN
# 4 Goblet of Fire.txt        ...     1.0     NaN   NaN    NaN  NaN         1.0
# 5 Order of the Phoenix.txt  ...     NaN     NaN   1.0    NaN  NaN         NaN
# 6 Half-Blood Prince.txt     ...     NaN     NaN   NaN    NaN  NaN         NaN
# 7 Deathly Hallows.txt       ...     NaN     NaN   NaN    NaN  NaN         NaN
#
#                             zoom  zoomed  zooming  éclairs
# _filename
# 1 Sorcerers Stone.txt        1.0       1      2.0      1.0
# 2 Chamber of Secrets.txt     NaN       2      NaN      NaN
# 3 Prisoner of Azkaban.txt    NaN       9      3.0      NaN
# 4 Goblet of Fire.txt         4.0       9     12.0      NaN
# 5 Order of the Phoenix.txt   2.0      23      7.0      NaN
# 6 Half-Blood Prince.txt      NaN       7      2.0      1.0
# 7 Deathly Hallows.txt        1.0       6      5.0      NaN
#
# [7 rows x 19910 columns]

# %% [markdown]
# Let's get our sum of tokens. We have to ask Pandas to sum *across* the columns since we want all of the words in each book, which correspond with our rows:

# %%
tokens = df.sum(axis = 'columns')

# %%
tokens
# Out:
# _filename
# 1 Sorcerers Stone.txt          41459.0
# 2 Chamber of Secrets.txt       84059.0
# 3 Prisoner of Azkaban.txt     104825.0
# 4 Goblet of Fire.txt          186744.0
# 5 Order of the Phoenix.txt    247422.0
# 6 Half-Blood Prince.txt       162903.0
# 7 Deathly Hallows.txt         188150.0
# dtype: float64

# %% [markdown]
# To get our types, we need one more dataframe trick, `transpose`. Transpose, which is called with `df.T`, flips our dataframe such that our rows become columns, and our columns become rows.
#
# We want the total number of columns in each row that are not null (i.e. there is at least 1 instance of the word in the text.)

# %%
df.T.head()
# Out:
# _filename        1 Sorcerers Stone.txt  2 Chamber of Secrets.txt  \
# a                               1066.0                    1879.0
# aaaaaaaaargh                       NaN                       NaN
# aaaaaaaarrrrrgh                    NaN                       NaN
# aaaaaaand                          NaN                       NaN
# aaaaaand                           NaN                       NaN
#
# _filename        3 Prisoner of Azkaban.txt  4 Goblet of Fire.txt  \
# a                                   2222.0                3680.0
# aaaaaaaaargh                           NaN                   NaN
# aaaaaaaarrrrrgh                        NaN                   1.0
# aaaaaaand                              NaN                   1.0
# aaaaaand                               NaN                   1.0
#
# _filename        5 Order of the Phoenix.txt  6 Half-Blood Prince.txt  \
# a                                    4967.0                   3323.0
# aaaaaaaaargh                            1.0                      NaN
# aaaaaaaarrrrrgh                         NaN                      NaN
# aaaaaaand                               NaN                      NaN
# aaaaaand                                NaN                      NaN
#
# _filename        7 Deathly Hallows.txt
# a                               3604.0
# aaaaaaaaargh                       NaN
# aaaaaaaarrrrrgh                    NaN
# aaaaaaand                          NaN
# aaaaaand                           NaN

# %% [markdown]
# Now when we sum the number of values that are `notnull`, we get the result we want:

# %%
types = df.T.notnull().sum()

# %%
types
# Out:
# _filename
# 1 Sorcerers Stone.txt          4314
# 2 Chamber of Secrets.txt       6823
# 3 Prisoner of Azkaban.txt      7335
# 4 Goblet of Fire.txt          10054
# 5 Order of the Phoenix.txt    11760
# 6 Half-Blood Prince.txt       10017
# 7 Deathly Hallows.txt         10781
# dtype: int64

# %% [markdown]
# Rowling did not quite linearly increase the vocabulary she used over the series:

# %%
(tokens / types).sort_values()
# Out:
# _filename
# 1 Sorcerers Stone.txt          9.610338
# 2 Chamber of Secrets.txt      12.319947
# 3 Prisoner of Azkaban.txt     14.291070
# 6 Half-Blood Prince.txt       16.262653
# 7 Deathly Hallows.txt         17.451999
# 4 Goblet of Fire.txt          18.574100
# 5 Order of the Phoenix.txt    21.039286
# dtype: float64

# %% [markdown]
# # Using NLTK for high-frequency words
# Now we need to talk about which words *not* to count. It's easy to say why we shouldn't count typos. It becomes more complicated to talk about why we might not to count high-frequency words, also known as "stopwords."
#
# Why we want to skip them? Because their very frequency will override other signals we want to look at.
#
# But we certainly need to know which words these are. There are standard lists in some packages like NLTK, which stands for "Natural Language Toolkit."

# %% [markdown]
# To start, run the following commands:

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# This opens a new window, which will allow you to download NLTK data. The collection "book" should be sufficient for this class.

# %%
from nltk.corpus import stopwords

# %% [markdown]
# This will show you the beginning of the stopword list:

# %%
stopwords.words('english')[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %% [markdown]
# There are quite a few!

# %%
len(stopwords.words('english'))
# Out:
# 179

# %% [markdown]
# ## Skipping stopwords
# How would we use stopwords to determine which words to keep in our lists of words?
#
# This is one way using familiar techniques:

# %%
s = 'which words in this string will get cut if we filter it using the list of stopwords'
l = s.split(' ')
not_stops = []

for word in l:
    if word not in stopwords.words('english'):
        not_stops.append(word)
        
not_stops
# Out:
# ['words', 'string', 'get', 'cut', 'filter', 'using', 'list', 'stopwords']

# %% [markdown]
# We could also drop stopwords from our dataframe column if we wanted to:

# %%
columns_no_stops = []
for x in list(df.columns):
    if x not in stopwords.words('english'):
        columns_no_stops.append(x)

# %% [markdown]
# You can then pass Pandas a list of

# %%
df[columns_no_stops]
# Out:
#                             aaaaaaaaargh  aaaaaaaarrrrrgh  aaaaaaand  \
# _filename
# 1 Sorcerers Stone.txt                NaN              NaN        NaN
# 2 Chamber of Secrets.txt             NaN              NaN        NaN
# 3 Prisoner of Azkaban.txt            NaN              NaN        NaN
# 4 Goblet of Fire.txt                 NaN              1.0        1.0
# 5 Order of the Phoenix.txt           1.0              NaN        NaN
# 6 Half-Blood Prince.txt              NaN              NaN        NaN
# 7 Deathly Hallows.txt                NaN              NaN        NaN
#
#                             aaaaaand  aaaaahed  aaaaargh  aaaah  aaah  aargh  \
# _filename
# 1 Sorcerers Stone.txt            NaN       NaN       NaN    NaN   NaN    NaN
# 2 Chamber of Secrets.txt         NaN       NaN       NaN    NaN   NaN    NaN
# 3 Prisoner of Azkaban.txt        NaN       NaN       NaN    NaN   NaN    NaN
# 4 Goblet of Fire.txt             1.0       1.0       NaN    NaN   1.0    NaN
# 5 Order of the Phoenix.txt       NaN       NaN       1.0    1.0   NaN    2.0
# 6 Half-Blood Prince.txt          NaN       NaN       1.0    1.0   NaN    NaN
# 7 Deathly Hallows.txt            NaN       NaN       NaN    NaN   NaN    1.0
#
#                              ab  ...  zograf  zombie  zone  zonko  zoo  \
# _filename                        ...
# 1 Sorcerers Stone.txt       NaN  ...     NaN     2.0   NaN    NaN  7.0
# 2 Chamber of Secrets.txt    NaN  ...     NaN     NaN   NaN    NaN  2.0
# 3 Prisoner of Azkaban.txt   NaN  ...     NaN     1.0   NaN    1.0  NaN
# 4 Goblet of Fire.txt        NaN  ...     1.0     NaN   NaN    NaN  NaN
# 5 Order of the Phoenix.txt  1.0  ...     NaN     NaN   1.0    NaN  NaN
# 6 Half-Blood Prince.txt     NaN  ...     NaN     NaN   NaN    NaN  NaN
# 7 Deathly Hallows.txt       NaN  ...     NaN     NaN   NaN    NaN  NaN
#
#                             zoological  zoom  zoomed  zooming  éclairs
# _filename
# 1 Sorcerers Stone.txt              NaN   1.0       1      2.0      1.0
# 2 Chamber of Secrets.txt           NaN   NaN       2      NaN      NaN
# 3 Prisoner of Azkaban.txt          NaN   NaN       9      3.0      NaN
# 4 Goblet of Fire.txt               1.0   4.0       9     12.0      NaN
# 5 Order of the Phoenix.txt         NaN   2.0      23      7.0      NaN
# 6 Half-Blood Prince.txt            NaN   NaN       7      2.0      1.0
# 7 Deathly Hallows.txt              NaN   1.0       6      5.0      NaN
#
# [7 rows x 19774 columns]
