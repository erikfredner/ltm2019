# %% [markdown]
# # Comparing and contrasting groups of texts
# We know how to easily make document-term matrices containing the raw and scaled counts for each of our texts. We can use these DTMs to compare groups of our texts based on groups derived from the metadata we have associated with them.
#
# ## Importing `make_dtm`
#
# I have created a `.py` file containing all of our `make_dtm` functions that we can easily import. That way, we don't have to copy-paste all of that code in every time!
#
# To import it, we have to have the `make_dtm.py` file located in our working directory:

# %%
import os
os.getcwd() # which directory am I in? "cwd" stands for "current working directory"
# Out:
# '/Users/e/Library/Mobile Documents/com~apple~CloudDocs/PhD/ltm/notebooks'

# %%
'make_dtm.py' in os.listdir() # is the file in our list of files? we want this to be True
# Out:
# True

# %% [markdown]
# Now we can import `make_dtm`:

# %%
from make_dtm import * # this means, "from the file make_dtm, import everything." the * means 'everything'
# * is sometimes known as a wildcard operator

# %% [markdown]
# Using the syntax above, we import *all* of the functions in `make_dtm`, including the ones that it depends on like `absolute_paths`, etc.
#
# We can also call `help()` to read the documentation about our function:

# %%
help(make_dtm)
# Out:
# Help on function make_dtm in module make_dtm:
#
# make_dtm(directory, scaled=False, drop_below=None)
#     Makes a document-term matrix from a directory of .txt files.
#     `scaled` option scaled frequencies when set to True.
#     `drop_below` sets the rate of occurrence at which words will be dropped. Default is None. i.e. retain all words.

# %%
hp_dir = '/Users/e/code/literarytextmining/corpora/harry_potter/texts'
make_dtm(hp_dir)
# Out:
#                                a  aaaaaaaaaaaaaarrrrrrrrrrrrggggghhhhh  \
# filepath
# 1 Sorcerers Stone.txt       1079                                   NaN
# 2 Chamber of Secrets.txt    1901                                   NaN
# 3 Prisoner of Azkaban.txt   2248                                   1.0
# 4 Goblet of Fire.txt        3714                                   NaN
# 5 Order of the Phoenix.txt  5017                                   NaN
# 6 Half-Blood Prince.txt     3361                                   NaN
# 7 Deathly Hallows.txt       3645                                   NaN
#
#                             aaaaaaaaargh  aaaaaaaargh  aaaaaaaarrrrrgh  \
# filepath
# 1 Sorcerers Stone.txt                NaN          NaN              NaN
# 2 Chamber of Secrets.txt             NaN          NaN              NaN
# 3 Prisoner of Azkaban.txt            NaN          NaN              NaN
# 4 Goblet of Fire.txt                 NaN          NaN              1.0
# 5 Order of the Phoenix.txt           1.0          NaN              NaN
# 6 Half-Blood Prince.txt              NaN          1.0              NaN
# 7 Deathly Hallows.txt                NaN          NaN              NaN
#
#                             aaaaaaand  aaaaaaarrrgh  aaaaaah  aaaaaand  \
# filepath
# 1 Sorcerers Stone.txt             NaN           NaN      NaN       NaN
# 2 Chamber of Secrets.txt          NaN           NaN      NaN       NaN
# 3 Prisoner of Azkaban.txt         NaN           1.0      NaN       NaN
# 4 Goblet of Fire.txt              1.0           NaN      NaN       1.0
# 5 Order of the Phoenix.txt        NaN           NaN      1.0       NaN
# 6 Half-Blood Prince.txt           NaN           NaN      NaN       NaN
# 7 Deathly Hallows.txt             NaN           NaN      NaN       NaN
#
#                             aaaaah  ...  zombie  zone  zonko  zonkos  zoo  \
# filepath                            ...
# 1 Sorcerers Stone.txt          NaN  ...     2.0   NaN    NaN     NaN  7.0
# 2 Chamber of Secrets.txt       NaN  ...     NaN   NaN    NaN     NaN  2.0
# 3 Prisoner of Azkaban.txt      NaN  ...     1.0   NaN    1.0    10.0  NaN
# 4 Goblet of Fire.txt           1.0  ...     NaN   NaN    NaN     1.0  NaN
# 5 Order of the Phoenix.txt     NaN  ...     NaN   1.0    NaN     3.0  NaN
# 6 Half-Blood Prince.txt        NaN  ...     NaN   NaN    NaN     2.0  NaN
# 7 Deathly Hallows.txt          NaN  ...     NaN   NaN    NaN     NaN  NaN
#
#                             zoological  zoom  zoomed  zooming  éclairs
# filepath
# 1 Sorcerers Stone.txt              NaN   1.0       1      2.0      1.0
# 2 Chamber of Secrets.txt           NaN   NaN       2      NaN      NaN
# 3 Prisoner of Azkaban.txt          NaN   NaN       9      3.0      NaN
# 4 Goblet of Fire.txt               1.0   4.0       9     12.0      NaN
# 5 Order of the Phoenix.txt         NaN   2.0      23      7.0      NaN
# 6 Half-Blood Prince.txt            NaN   NaN       7      2.0      2.0
# 7 Deathly Hallows.txt              NaN   1.0       6      5.0      NaN
#
# [7 rows x 21186 columns]

# %% [markdown]
# I added one other option to let us drop rare words from our DTM as we make it:

# %%
df = make_dtm(hp_dir, scaled = True, drop_below=15)

# %% [markdown]
# `drop_below` gets rid of words that occur `n*` the lowest number of words in the corpus.
# As the lowest number of words is always one, this integer allows us to deal with both scaled and raw document-term matrices.

# %%
df.head()
# Out:
#                                    a      aaah     aback  abandoned  \
# filepath
# 1 Sorcerers Stone.txt       0.024407  0.000023  0.000023        NaN
# 2 Chamber of Secrets.txt    0.021229       NaN       NaN   0.000011
# 3 Prisoner of Azkaban.txt   0.020045       NaN  0.000018   0.000018
# 4 Goblet of Fire.txt        0.018758  0.000025  0.000035   0.000030
# 5 Order of the Phoenix.txt  0.019021  0.000004  0.000038   0.000034
#
#                             abandoning    abbott  aberforth   ability  \
# filepath
# 1 Sorcerers Stone.txt              NaN  0.000023        NaN       NaN
# 2 Chamber of Secrets.txt      0.000011       NaN        NaN       NaN
# 3 Prisoner of Azkaban.txt     0.000027  0.000009        NaN  0.000009
# 4 Goblet of Fire.txt          0.000015  0.000010   0.000010  0.000010
# 5 Order of the Phoenix.txt    0.000008  0.000027   0.000004  0.000023
#
#                                 able      abou  ...      yule    zabini  \
# filepath                                        ...
# 1 Sorcerers Stone.txt       0.000226  0.000068  ...       NaN  0.000023
# 2 Chamber of Secrets.txt    0.000402       NaN  ...       NaN       NaN
# 3 Prisoner of Azkaban.txt   0.000321  0.000053  ...       NaN       NaN
# 4 Goblet of Fire.txt        0.000263  0.000040  ...  0.000040       NaN
# 5 Order of the Phoenix.txt  0.000364  0.000076  ...  0.000019       NaN
#
#                             zacharias      zat        ze      zero    zonkos  \
# filepath
# 1 Sorcerers Stone.txt             NaN      NaN       NaN       NaN       NaN
# 2 Chamber of Secrets.txt          NaN      NaN       NaN  0.000011       NaN
# 3 Prisoner of Azkaban.txt         NaN      NaN       NaN  0.000027  0.000089
# 4 Goblet of Fire.txt              NaN  0.00002  0.000081  0.000015  0.000005
# 5 Order of the Phoenix.txt   0.000087      NaN       NaN  0.000011  0.000011
#
#                                  zoo    zoomed   zooming
# filepath
# 1 Sorcerers Stone.txt       0.000158  0.000023  0.000045
# 2 Chamber of Secrets.txt    0.000022  0.000022       NaN
# 3 Prisoner of Azkaban.txt        NaN  0.000080  0.000027
# 4 Goblet of Fire.txt             NaN  0.000045  0.000061
# 5 Order of the Phoenix.txt       NaN  0.000087  0.000027
#
# [5 rows x 6289 columns]

# %% [markdown]
# # Comparing differences between groups of texts
# There are a *ton* of different ways that we can calculate differences between groups of texts. Each of them serve specific functions, and some are more appropriate for specific use cases.
#
#
# ## Different ways of calculating distinctive words
# We're going to discuss three different ways of calculating **distinctive words**, by which I mean simply words that are used differently between two different texts or groups of texts.
#
# They are:
# 1. **Difference of means**: This analyzes the average difference per document between two groups. Mainly useful if you assume that your documents are broadly similar.
# 2. **Term-frequency `*` inverse document frequency**: This measure compares how rare words are in your corpus with how frequent they are in a particular document. Words that are rare in the corpus but frequent in an individual document are likely distinctive of that document. For example, `accio` would be common in *Harry Potter*, but absent in almost every other book. That makes it a distinctive word.
# 3. **Fisher's exact test**: This statistical test compares the total number of times a word was used and not used by two groups, which we'll call A and B. The test calculates the *odds* that group A would use that particular word as compared to group B. For example, a result could tell you that "the odds are 300 to 1 that `accio` was used by J.K. Rowling as opposed to a group of authors who are not J.K. Rowling." It also calculates the p-value, which measures the probability of obtaining that result if the null-hypothesis were correct. A low p-value indicates that we can reject the null-hypothesis. In our case, the null-hypothesis is that our groups use the words at exactly equal rates. Rejecting the null-hypothesis means that the groups of authors do use words at rates that are significantly different.
#
#
# ## Grouping texts
# In order to calculate the differences between two groups of texts, you need to have groups. These might be characteristics of the texts themselves (e.g. texts published before or after a certain date, texts with protagonists of specific genders), or they might have something to do with the characteristics of the authors (e.g. white vs. POC word usage).
#
# For these examples, we're going to look for political differences in State of the Union addresses by U.S. presidents between 1900 and 2019. Our groups are going to be the two major political parties, Democrats and Republicans.

# %%
meta = '/Users/e/code/literarytextmining/corpora/sotu_1900-2019/meta.csv'

# %%
# get the metadata
import pandas as pd
meta = pd.read_csv(meta)

# %%
meta.head()
# Out:
#    president  year            filepath       party
# 0   McKinley  1900   1900.McKinley.txt  Republican
# 1  Roosevelt  1901  1901.Roosevelt.txt  Republican
# 2  Roosevelt  1902  1902.Roosevelt.txt  Republican
# 3  Roosevelt  1903  1903.Roosevelt.txt  Republican
# 4  Roosevelt  1904  1904.Roosevelt.txt  Republican

# %%
meta.tail()
# Out:
#     president  year        filepath       party
# 114     Obama  2015  2015.Obama.txt    Democrat
# 115     Obama  2016  2016.Obama.txt    Democrat
# 116     Trump  2017  2017.Trump.txt  Republican
# 117     Trump  2018  2018.Trump.txt  Republican
# 118     Trump  2019  2019.Trump.txt  Republican

# %% [markdown]
# Now let's use our imported `make_dtm` function to get a data frame of the SOTUS:

# %%
sotus = '/Users/e/code/literarytextmining/corpora/sotu_1900-2019/texts'

# %%
df = make_dtm(sotus, scaled = True, drop_below=50)

# %%
df.head()
# Out:
#                            a   abandon  abandoned   abiding   ability  \
# filepath
# 1900.McKinley.txt   0.013367       NaN   0.000053  0.000053  0.000211
# 1901.Roosevelt.txt  0.013951  0.000051        NaN  0.000152  0.000254
# 1902.Roosevelt.txt  0.018451  0.000102        NaN       NaN  0.000204
# 1903.Roosevelt.txt  0.014483  0.000135   0.000067       NaN  0.000135
# 1904.Roosevelt.txt  0.014109  0.000057        NaN       NaN  0.000057
#
#                         able  abolished  abolition  abortion     about  ...  \
# filepath                                                                ...
# 1900.McKinley.txt   0.000159        NaN        NaN       NaN  0.000581  ...
# 1901.Roosevelt.txt  0.000558   0.000051        NaN       NaN  0.000203  ...
# 1902.Roosevelt.txt  0.000102        NaN        NaN       NaN  0.000510  ...
# 1903.Roosevelt.txt       NaN        NaN        NaN       NaN  0.000539  ...
# 1904.Roosevelt.txt  0.000343   0.000057   0.000057       NaN  0.000400  ...
#
#                     yield      york       you     young   younger      your  \
# filepath
# 1900.McKinley.txt     NaN       NaN  0.000581       NaN       NaN  0.000793
# 1901.Roosevelt.txt    NaN       NaN  0.000101       NaN  0.000051  0.000203
# 1902.Roosevelt.txt    NaN       NaN  0.000102  0.000306       NaN  0.000306
# 1903.Roosevelt.txt    NaN  0.000202  0.000135  0.000067       NaN  0.000202
# 1904.Roosevelt.txt    NaN  0.000114  0.000228  0.000171       NaN  0.000343
#
#                     yours     youth      zone     zones
# filepath
# 1900.McKinley.txt     NaN       NaN       NaN  0.000053
# 1901.Roosevelt.txt    NaN       NaN       NaN       NaN
# 1902.Roosevelt.txt    NaN       NaN       NaN       NaN
# 1903.Roosevelt.txt    NaN       NaN  0.000202       NaN
# 1904.Roosevelt.txt    NaN  0.000057  0.000114       NaN
#
# [5 rows x 4844 columns]

# %% [markdown]
# Since both data frames contain a `filepath` column, we can merge them easily:

# %%
meta.columns
# Out:
# Index(['president', 'year', 'filepath', 'party'], dtype='object')

# %%
sotu_df = pd.merge(df, meta, on='filepath')

# %%
sotu_df.head()
# Out:
#              filepath         a   abandon  abandoned   abiding   ability  \
# 0   1900.McKinley.txt  0.013367       NaN   0.000053  0.000053  0.000211
# 1  1901.Roosevelt.txt  0.013951  0.000051        NaN  0.000152  0.000254
# 2  1902.Roosevelt.txt  0.018451  0.000102        NaN       NaN  0.000204
# 3  1903.Roosevelt.txt  0.014483  0.000135   0.000067       NaN  0.000135
# 4  1904.Roosevelt.txt  0.014109  0.000057        NaN       NaN  0.000057
#
#        able  abolished  abolition  abortion  ...     young   younger  \
# 0  0.000159        NaN        NaN       NaN  ...       NaN       NaN
# 1  0.000558   0.000051        NaN       NaN  ...       NaN  0.000051
# 2  0.000102        NaN        NaN       NaN  ...  0.000306       NaN
# 3       NaN        NaN        NaN       NaN  ...  0.000067       NaN
# 4  0.000343   0.000057   0.000057       NaN  ...  0.000171       NaN
#
#        your  yours     youth      zone     zones  president_y  year_y  \
# 0  0.000793    NaN       NaN       NaN  0.000053     McKinley    1900
# 1  0.000203    NaN       NaN       NaN       NaN    Roosevelt    1901
# 2  0.000306    NaN       NaN       NaN       NaN    Roosevelt    1902
# 3  0.000202    NaN       NaN  0.000202       NaN    Roosevelt    1903
# 4  0.000343    NaN  0.000057  0.000114       NaN    Roosevelt    1904
#
#       party_y
# 0  Republican
# 1  Republican
# 2  Republican
# 3  Republican
# 4  Republican
#
# [5 rows x 4848 columns]

# %% [markdown]
# We're going to want to set `filepath` as our index (i.e. row names) so that we don't calculate on it by accident:

# %%
sotu_df.set_index('filepath', inplace=True)

# %%
sotu_df.head()
# Out:
#                            a   abandon  abandoned   abiding   ability  \
# filepath
# 1900.McKinley.txt   0.013367       NaN   0.000053  0.000053  0.000211
# 1901.Roosevelt.txt  0.013951  0.000051        NaN  0.000152  0.000254
# 1902.Roosevelt.txt  0.018451  0.000102        NaN       NaN  0.000204
# 1903.Roosevelt.txt  0.014483  0.000135   0.000067       NaN  0.000135
# 1904.Roosevelt.txt  0.014109  0.000057        NaN       NaN  0.000057
#
#                         able  abolished  abolition  abortion     about  ...  \
# filepath                                                                ...
# 1900.McKinley.txt   0.000159        NaN        NaN       NaN  0.000581  ...
# 1901.Roosevelt.txt  0.000558   0.000051        NaN       NaN  0.000203  ...
# 1902.Roosevelt.txt  0.000102        NaN        NaN       NaN  0.000510  ...
# 1903.Roosevelt.txt       NaN        NaN        NaN       NaN  0.000539  ...
# 1904.Roosevelt.txt  0.000343   0.000057   0.000057       NaN  0.000400  ...
#
#                        young   younger      your  yours     youth      zone  \
# filepath
# 1900.McKinley.txt        NaN       NaN  0.000793    NaN       NaN       NaN
# 1901.Roosevelt.txt       NaN  0.000051  0.000203    NaN       NaN       NaN
# 1902.Roosevelt.txt  0.000306       NaN  0.000306    NaN       NaN       NaN
# 1903.Roosevelt.txt  0.000067       NaN  0.000202    NaN       NaN  0.000202
# 1904.Roosevelt.txt  0.000171       NaN  0.000343    NaN  0.000057  0.000114
#
#                        zones  president_y  year_y     party_y
# filepath
# 1900.McKinley.txt   0.000053     McKinley    1900  Republican
# 1901.Roosevelt.txt       NaN    Roosevelt    1901  Republican
# 1902.Roosevelt.txt       NaN    Roosevelt    1902  Republican
# 1903.Roosevelt.txt       NaN    Roosevelt    1903  Republican
# 1904.Roosevelt.txt       NaN    Roosevelt    1904  Republican
#
# [5 rows x 4847 columns]

# %% [markdown]
# ## Merge results
#
# Notice that it adds three new columns: `president_y`, `year_y`, and `party_y`. Those `_y` get added from our metadata table because the dataframe *already* had columns for the words president, year, and party. Rather than overwriting the existing columns, Pandas infers that we want to have all of them together.
#
# We know that our words are everything up to, but not including, the last three columns from our metadata, it'll help us to save those for later so that we can only look at words:

# %%
words = sotu_df.columns[:-3] # everything from index 0 up to but not including the last 3

# %%
words
# Out:
# Index(['a', 'abandon', 'abandoned', 'abiding', 'ability', 'able', 'abolished',
#        'abolition', 'abortion', 'about',
#        ...
#        'yield', 'york', 'you', 'young', 'younger', 'your', 'yours', 'youth',
#        'zone', 'zones'],
#       dtype='object', length=4844)

# %% [markdown]
# # Grouping with Pandas
# There are quite a few ways we could group our data to check for differences.
#
# One easy way would be to create variables containing slices of the data frame:

# %%
sotu_df['party_y'].unique() # party_y holds our party metadata
# Out:
# array(['Republican', 'Democrat'], dtype=object)

# %%
Rs = sotu_df[sotu_df['party_y'] == 'Republican'][words] # this gets all of the rows where the party is republican

# %%
Ds = sotu_df[sotu_df['party_y'] == 'Democrat'][words] # ditto, but for democrats

# %%
Rs.head()
# Out:
#                            a   abandon  abandoned   abiding   ability  \
# filepath
# 1900.McKinley.txt   0.013367       NaN   0.000053  0.000053  0.000211
# 1901.Roosevelt.txt  0.013951  0.000051        NaN  0.000152  0.000254
# 1902.Roosevelt.txt  0.018451  0.000102        NaN       NaN  0.000204
# 1903.Roosevelt.txt  0.014483  0.000135   0.000067       NaN  0.000135
# 1904.Roosevelt.txt  0.014109  0.000057        NaN       NaN  0.000057
#
#                         able  abolished  abolition  abortion     about  ...  \
# filepath                                                                ...
# 1900.McKinley.txt   0.000159        NaN        NaN       NaN  0.000581  ...
# 1901.Roosevelt.txt  0.000558   0.000051        NaN       NaN  0.000203  ...
# 1902.Roosevelt.txt  0.000102        NaN        NaN       NaN  0.000510  ...
# 1903.Roosevelt.txt       NaN        NaN        NaN       NaN  0.000539  ...
# 1904.Roosevelt.txt  0.000343   0.000057   0.000057       NaN  0.000400  ...
#
#                     yield      york       you     young   younger      your  \
# filepath
# 1900.McKinley.txt     NaN       NaN  0.000581       NaN       NaN  0.000793
# 1901.Roosevelt.txt    NaN       NaN  0.000101       NaN  0.000051  0.000203
# 1902.Roosevelt.txt    NaN       NaN  0.000102  0.000306       NaN  0.000306
# 1903.Roosevelt.txt    NaN  0.000202  0.000135  0.000067       NaN  0.000202
# 1904.Roosevelt.txt    NaN  0.000114  0.000228  0.000171       NaN  0.000343
#
#                     yours     youth      zone     zones
# filepath
# 1900.McKinley.txt     NaN       NaN       NaN  0.000053
# 1901.Roosevelt.txt    NaN       NaN       NaN       NaN
# 1902.Roosevelt.txt    NaN       NaN       NaN       NaN
# 1903.Roosevelt.txt    NaN       NaN  0.000202       NaN
# 1904.Roosevelt.txt    NaN  0.000057  0.000114       NaN
#
# [5 rows x 4844 columns]

# %%
Ds.head()
# Out:
#                         a  abandon  abandoned  abiding  ability      able  \
# filepath
# 1913.Wilson.txt  0.010937      NaN        NaN  0.00028      NaN       NaN
# 1914.Wilson.txt  0.014499      NaN        NaN  0.00022      NaN  0.000439
# 1915.Wilson.txt  0.012451      NaN        NaN      NaN  0.00013  0.000130
# 1916.Wilson.txt  0.012224      NaN        NaN      NaN      NaN       NaN
# 1917.Wilson.txt  0.009909      NaN        NaN      NaN      NaN  0.000254
#
#                  abolished  abolition  abortion     about  ...     yield  \
# filepath                                                   ...
# 1913.Wilson.txt        NaN        NaN       NaN  0.000841  ...       NaN
# 1914.Wilson.txt        NaN        NaN       NaN  0.000220  ...  0.000220
# 1915.Wilson.txt        NaN        NaN       NaN  0.000908  ...  0.000389
# 1916.Wilson.txt        NaN        NaN       NaN       NaN  ...       NaN
# 1917.Wilson.txt        NaN        NaN       NaN  0.001016  ...       NaN
#
#                  york       you     young   younger      your  yours  youth  \
# filepath
# 1913.Wilson.txt   NaN  0.002804       NaN       NaN  0.001122    NaN    NaN
# 1914.Wilson.txt   NaN  0.001098  0.000659       NaN  0.000439    NaN    NaN
# 1915.Wilson.txt   NaN  0.002464  0.000130  0.000259  0.001167    NaN    NaN
# 1916.Wilson.txt   NaN  0.003761       NaN       NaN  0.000940    NaN    NaN
# 1917.Wilson.txt   NaN  0.001778       NaN       NaN  0.000254    NaN    NaN
#
#                  zone  zones
# filepath
# 1913.Wilson.txt   NaN    NaN
# 1914.Wilson.txt   NaN    NaN
# 1915.Wilson.txt   NaN    NaN
# 1916.Wilson.txt   NaN    NaN
# 1917.Wilson.txt   NaN    NaN
#
# [5 rows x 4844 columns]

# %% [markdown]
# So, we used our metadata to group our data frame into Republicans and Democrats. Now, we can compare these two matrices:

# %% [markdown]
# ## Difference of means
# First, we're going to compare the differences between the parties' states of the union by comparing the differences between the mean rates at which they use certain words.
#
# This is a simple but useful technique. It shows us which words appear more often on average in a given group's texts.
#
# You calculate all of the mean values for every word in each party (`Ds.mean()`), then subtract the means of the other party (`Rs.mean()`) from each of those values.
#
# So, more positive values are mentioned more often on average in Democratic texts, whereas negative values would be mentioned more often in Republican texts. The advantage of this method is that it *cancels out* some of the similarities between the groups among very common words. The words closest to zero are used most similarly in both groups.

# %%
Ds.head()
# Out:
#                         a  abandon  abandoned  abiding  ability      able  \
# filepath
# 1913.Wilson.txt  0.010937      NaN        NaN  0.00028      NaN       NaN
# 1914.Wilson.txt  0.014499      NaN        NaN  0.00022      NaN  0.000439
# 1915.Wilson.txt  0.012451      NaN        NaN      NaN  0.00013  0.000130
# 1916.Wilson.txt  0.012224      NaN        NaN      NaN      NaN       NaN
# 1917.Wilson.txt  0.009909      NaN        NaN      NaN      NaN  0.000254
#
#                  abolished  abolition  abortion     about  ...     yield  \
# filepath                                                   ...
# 1913.Wilson.txt        NaN        NaN       NaN  0.000841  ...       NaN
# 1914.Wilson.txt        NaN        NaN       NaN  0.000220  ...  0.000220
# 1915.Wilson.txt        NaN        NaN       NaN  0.000908  ...  0.000389
# 1916.Wilson.txt        NaN        NaN       NaN       NaN  ...       NaN
# 1917.Wilson.txt        NaN        NaN       NaN  0.001016  ...       NaN
#
#                  york       you     young   younger      your  yours  youth  \
# filepath
# 1913.Wilson.txt   NaN  0.002804       NaN       NaN  0.001122    NaN    NaN
# 1914.Wilson.txt   NaN  0.001098  0.000659       NaN  0.000439    NaN    NaN
# 1915.Wilson.txt   NaN  0.002464  0.000130  0.000259  0.001167    NaN    NaN
# 1916.Wilson.txt   NaN  0.003761       NaN       NaN  0.000940    NaN    NaN
# 1917.Wilson.txt   NaN  0.001778       NaN       NaN  0.000254    NaN    NaN
#
#                  zone  zones
# filepath
# 1913.Wilson.txt   NaN    NaN
# 1914.Wilson.txt   NaN    NaN
# 1915.Wilson.txt   NaN    NaN
# 1916.Wilson.txt   NaN    NaN
# 1917.Wilson.txt   NaN    NaN
#
# [5 rows x 4844 columns]

# %%
Ds.mean()[:5] # again, these are vectors so this calculates the mean of every column, i.e. word
# Out:
# a            0.016366
# abandon      0.000247
# abandoned    0.000202
# abiding      0.000235
# ability      0.000343
# dtype: float64

# %%
diff_means = Ds.mean() - Rs.mean()

# %% [markdown]
# Now, there are words that will appear in one group but not the other. When you try to subtract a number from a number that does not exist, Pandas returns `NaN`. Since we're looking to compare and contrast these groups, we'll drop the `NaN` results:

# %%
diff_means[diff_means.isna()]
# Out:
# abortion          NaN
# addicted          NaN
# addiction         NaN
# advocated         NaN
# applaud           NaN
# appreciation      NaN
# autocracy         NaN
# award             NaN
# baghdad           NaN
# biden             NaN
# bosnia            NaN
# brady             NaN
# cheney            NaN
# colored           NaN
# commissioners     NaN
# comparatively     NaN
# competitiveness   NaN
# convicted         NaN
# etc               NaN
# exposition        NaN
# filipinos         NaN
# fisheries         NaN
# friction          NaN
# gramm             NaN
# gratifying        NaN
# hague             NaN
# hitler            NaN
# hoarding          NaN
# hollings          NaN
# incident          NaN
# internet          NaN
# investigate       NaN
# iraqis            NaN
# isil              NaN
# isis              NaN
# kremlin           NaN
# lebanon           NaN
# legislature       NaN
# megan             NaN
# multiplied        NaN
# municipal         NaN
# nam               NaN
# nazis             NaN
# parcel            NaN
# protective        NaN
# qaida             NaN
# rudman            NaN
# serviceable       NaN
# seventies         NaN
# shoals            NaN
# tight             NaN
# unborn            NaN
# undesirable       NaN
# viet              NaN
# wool              NaN
# dtype: float64

# %%
diff_means.dropna(inplace=True)

# %%
diff_means.sort_values() # more negative values are more Republican; more positive values are more Democratic
# Out:
# the            -0.005448
# applause       -0.004546
# of             -0.003290
# is             -0.002014
# in             -0.001891
# iraq           -0.001443
# be             -0.001298
# barrels        -0.001281
# saddam         -0.001275
# a              -0.001225
# terrorists     -0.001140
# iraqi          -0.001127
# government     -0.001111
# has            -0.001082
# hussein        -0.000985
# federal        -0.000904
# been           -0.000899
# qaeda          -0.000898
# terror         -0.000807
# by             -0.000755
# mayor          -0.000593
# audience       -0.000592
# such           -0.000587
# america        -0.000575
# al             -0.000562
# an             -0.000561
# earmarks       -0.000552
# law            -0.000546
# states         -0.000533
# under          -0.000521
#                   ...
# who             0.000687
# japanese        0.000723
# planes          0.000744
# but             0.000759
# salt            0.000768
# s               0.000790
# all             0.000807
# it              0.000875
# respectfully    0.000875
# do              0.000879
# have            0.000889
# floating        0.000904
# battleships     0.000904
# destitution     0.000937
# their           0.000948
# vietnam         0.000948
# world           0.000958
# they            0.000985
# axis            0.001056
# rulers          0.001079
# or              0.001200
# war             0.001220
# suggestions     0.001257
# t               0.001652
# cruisers        0.001681
# i               0.001903
# to              0.002277
# our             0.002600
# that            0.003048
# we              0.005401
# Length: 4789, dtype: float64

# %% [markdown]
# And which words are used most similarly among the two groups?

# %%
# what is the smallest value greater than 0?
mn = diff_means[diff_means > 0].min()

# %%
mn
# Out:
# 1.8705293707184378e-08

# %%
diff_means[diff_means==mn]
# Out:
# refused    1.870529e-08
# dtype: float64

# %% [markdown]
# So now that we know that `refused` is the word closest to 0, we can use `get_loc` on the index to find the numerical position of the words closest to zero:

# %%
diff_means.sort_values(inplace=True) # make sure sort is consistent

# %%
diff_means.index.get_loc('refused')
# Out:
# 1570

# %%
diff_means[1560:1580] # let's see the words around refused
# Out:
# turned       -5.362892e-07
# penalty      -4.611454e-07
# at           -4.054953e-07
# remained     -3.925947e-07
# knows        -3.763799e-07
# offensive    -3.409084e-07
# places       -2.980729e-07
# different    -1.171362e-07
# numerous     -7.731823e-08
# earlier      -1.564578e-08
# refused       1.870529e-08
# sensible      1.879756e-07
# defined       2.488349e-07
# needless      2.541267e-07
# commanders    2.653964e-07
# protected     3.557504e-07
# variety       3.759861e-07
# industry      3.862119e-07
# map           3.946424e-07
# believes      4.317738e-07
# dtype: float64

# %% [markdown]
# Again, these very low values are used at the most *consistent* rates between groups, on average.

# %% [markdown]
# # Term-Frequency `*` Inverse-Document Frequency
# TF-IDF is a technique commonly used in information retrieval, including Google's page-ranking algorithm.
#
# It compares the scaled frequency of a term in a document over a log-scaled number given by the number of documents in the corpus divided by the number of *documents in which the target word appears*.
#
# TF-IDF is said to be a measure of "term specificity," i.e. how specific is this term to this document?
#
# This is based on two assumptions:
# 1. If a word is relatively frequent in all documents, and frequenty in one particular document, it probably isn't that distinctive of that one document.
# 2. But if a word is relatively infrequent in all documents, and relatively frequenty in one document, it may well be distinctive of that document.

# %% [markdown]
# ## Term-Frequency
# <center><img src="https://latex.codecogs.com/png.latex?TF = \frac{n_w}{n_d}"></center>
#
# We already know how to calculate this; we have been referring to it as the scaled frequency.
#
# Where:
# * *Nw* is the number of times a given word *w* appears in a document.
# * *Nd* is the number of words in that document.
#
# Term frequencies are exactly the same values we already have calculated in our scaled DTMs, e.g.

# %%
sotu_df['jobs'].dropna()[:10]
# Out:
# filepath
# 1940.Roosevelt.txt     0.000622
# 1941.Roosevelt.txt     0.000300
# 1944.Roosevelt.txt     0.000261
# 1945.Roosevelt.txt     0.001706
# 1946.Truman.txt        0.000183
# 1948.Truman.txt        0.000589
# 1949.Truman.txt        0.000294
# 1951.Truman.txt        0.000500
# 1952.Truman.txt        0.000559
# 1955.Eisenhower.txt    0.000274
# Name: jobs, dtype: float64

# %% [markdown]
# #### IDF: Inverse Document Frequency
#
# <center><img src="https://latex.codecogs.com/png.latex?IDF = \log \left( \frac{c_d}{i_d} \right)"></center>
#
# Where:
# * <img src="https://latex.codecogs.com/png.latex?{c_d}"> is the count of documents in the corpus.
# * <img src="https://latex.codecogs.com/png.latex?{i_d}"> = is the number of documents in which that word appears.
#
# Calculating this requires answering three questions:
# 1. How many documents are there in the corpus?
# 2. How many documents does the word appear in?
# 3. What is the `log` of the number of documents divided by the number of documents in which the word appears?

# %%
# 1. How many documents are there? We can get that by counting the number of rows in our DTM. One row per document:
n_docs = len(sotu_df)
n_docs
# Out:
# 119

# %%
# 2. How many documents does the word appear in?
# We can get that by finding out how many documents have a non-zero value:
(sotu_df['jobs'] > 0)[:5]
# Out:
# filepath
# 1900.McKinley.txt     False
# 1901.Roosevelt.txt    False
# 1902.Roosevelt.txt    False
# 1903.Roosevelt.txt    False
# 1904.Roosevelt.txt    False
# Name: jobs, dtype: bool

# %%
# We can then use that True/False vector to filter our data frame
sotu_df[sotu_df['jobs'] > 0].head()
# Out:
#                            a   abandon  abandoned  abiding   ability  \
# filepath
# 1940.Roosevelt.txt  0.016791  0.000311        NaN      NaN       NaN
# 1941.Roosevelt.txt  0.015315       NaN        NaN   0.0003  0.000601
# 1944.Roosevelt.txt  0.017778       NaN        NaN      NaN       NaN
# 1945.Roosevelt.txt  0.013161       NaN        NaN      NaN  0.000487
# 1946.Truman.txt     0.013168       NaN        NaN      NaN  0.000110
#
#                         able  abolished  abolition  abortion     about  ...  \
# filepath                                                                ...
# 1940.Roosevelt.txt  0.000311        NaN        NaN       NaN  0.000622  ...
# 1941.Roosevelt.txt  0.000601        NaN        NaN       NaN  0.000601  ...
# 1944.Roosevelt.txt  0.000523        NaN        NaN       NaN  0.000784  ...
# 1945.Roosevelt.txt  0.000731        NaN        NaN       NaN  0.000609  ...
# 1946.Truman.txt     0.000147        NaN        NaN       NaN  0.001724  ...
#
#                        young  younger      your  yours     youth      zone  \
# filepath
# 1940.Roosevelt.txt       NaN      NaN  0.000311    NaN  0.000933       NaN
# 1941.Roosevelt.txt       NaN      NaN  0.000601    NaN  0.000300       NaN
# 1944.Roosevelt.txt  0.000261      NaN       NaN    NaN       NaN       NaN
# 1945.Roosevelt.txt  0.000366      NaN       NaN    NaN       NaN  0.000122
# 1946.Truman.txt     0.000037      NaN       NaN    NaN       NaN  0.000073
#
#                        zones  president_y  year_y   party_y
# filepath
# 1940.Roosevelt.txt       NaN    Roosevelt    1940  Democrat
# 1941.Roosevelt.txt       NaN    Roosevelt    1941  Democrat
# 1944.Roosevelt.txt       NaN    Roosevelt    1944  Democrat
# 1945.Roosevelt.txt       NaN    Roosevelt    1945  Democrat
# 1946.Truman.txt     0.000037       Truman    1946  Democrat
#
# [5 rows x 4847 columns]

# %%
# And then we can calculate the number of documents containing the target word like so:
# How many rows (documents) exist where there are more than zero instances of the word "jobs"?
len(sotu_df[sotu_df['jobs'] > 0])
# Out:
# 68

# %%
n_docs_with_word = len(sotu_df[sotu_df['jobs'] > 0])

# %%
# 3. Log-scale the inverse frequency.
# We can have the computer do this for us:
import numpy as np
idf = np.log(n_docs/n_docs_with_word)

# %%
idf
# Out:
# 0.5596157879354227

# %% [markdown]
# Now we multiply every one of our term-frequencies by our inverse-document frequency:

# %%
(sotu_df['jobs'] * idf).sort_values(ascending = True)[:20]
# Out:
# filepath
# 1956.Eisenhower.txt    0.000067
# 1946.Truman.txt        0.000103
# 1959.Eisenhower.txt    0.000114
# 1957.Eisenhower.txt    0.000134
# 1944.Roosevelt.txt     0.000146
# 1955.Eisenhower.txt    0.000154
# 1986.Reagan.txt        0.000157
# 1967.Johnson.txt       0.000157
# 1949.Truman.txt        0.000164
# 1941.Roosevelt.txt     0.000168
# 2007.Bush.txt          0.000200
# 2003.Bush.txt          0.000208
# 1966.Johnson.txt       0.000212
# 1989.Bush.txt          0.000229
# 1971.Nixon.txt         0.000247
# 2001.Bush.txt          0.000258
# 1951.Truman.txt        0.000280
# 1987.Reagan.txt        0.000288
# 1990.Bush.txt          0.000290
# 1999.Clinton.txt       0.000296
# Name: jobs, dtype: float64

# %% [markdown]
# Obama talks about "jobs" both more often than other presidents, and in a way that is especially distinctive because not all presidents' State of the Union messages address "jobs."

# %% [markdown]
# ## TF`*`IDF function
# We should put all of this into a function so we can get tf`*`idf for every word in any DTM:

# %%
def tf_idf(dtm):
    '''This function expects a scaled-frequency document-term matrix with an index of text names, and words as columns.
    It calculates tf*idf for every column (i.e. every word).'''
    dtm_tfidf = pd.DataFrame() # initialize empty dataframe to store results
    
    for word in dtm.columns: # for every word in our corpus
        # 1. tf: just the scaled frequency of our word
        tf_series = dtm[word]
        
        # 2. idf
        num_docs = len(dtm)
        num_docs_with_word=len(dtm[dtm[word]>0])
        idf=np.log(num_docs/num_docs_with_word)
        
        # 3. tf * idf
        tfidf_series = tf_series * idf
        
        # 4. Add the result to our dataframe
        dtm_tfidf[word]=tfidf_series
    
    return dtm_tfidf # 5. Return our new dataframe

# %%
sotu_tfidf = tf_idf(sotu_df[words]) # I call my original dataframe for the columns [words] because we don't want metadata
# this takes about 60 seconds to run on my laptop

# %%
sotu_tfidf
# Out:
#                       a   abandon  abandoned   abiding   ability      able  \
# filepath
# 1900.McKinley.txt   0.0       NaN   0.000089  0.000092  0.000106  0.000039
# 1901.Roosevelt.txt  0.0  0.000067        NaN  0.000264  0.000127  0.000138
# 1902.Roosevelt.txt  0.0  0.000134        NaN       NaN  0.000102  0.000025
# 1903.Roosevelt.txt  0.0  0.000177   0.000114       NaN  0.000068       NaN
# 1904.Roosevelt.txt  0.0  0.000075        NaN       NaN  0.000029  0.000084
# 1905.Roosevelt.txt  0.0       NaN        NaN  0.000069  0.000060  0.000147
# 1906.Roosevelt.txt  0.0  0.000056        NaN  0.000147  0.000043  0.000073
# 1907.Roosevelt.txt  0.0       NaN        NaN  0.000127  0.000147  0.000072
# 1908.Roosevelt.txt  0.0  0.000203        NaN  0.000089  0.000026  0.000165
# 1909.Taft.txt       0.0       NaN        NaN       NaN  0.000181  0.000018
# 1910.Taft.txt       0.0       NaN        NaN  0.000271  0.000078  0.000077
# 1911.Taft.txt       0.0  0.000056   0.000072       NaN  0.000085  0.000094
# 1912.Taft.txt       0.0       NaN   0.000067       NaN  0.000080  0.000049
# 1913.Wilson.txt     0.0       NaN        NaN  0.000486       NaN       NaN
# 1914.Wilson.txt     0.0       NaN        NaN  0.000381       NaN  0.000108
# 1915.Wilson.txt     0.0       NaN        NaN       NaN  0.000065  0.000032
# 1916.Wilson.txt     0.0       NaN        NaN       NaN       NaN       NaN
# 1917.Wilson.txt     0.0       NaN        NaN       NaN       NaN  0.000063
# 1918.Wilson.txt     0.0       NaN        NaN       NaN       NaN  0.000135
# 1919.Wilson.txt     0.0       NaN   0.000354       NaN       NaN  0.000052
# 1920.Wilson.txt     0.0       NaN        NaN       NaN       NaN  0.000091
# 1921.Harding.txt    0.0       NaN        NaN       NaN  0.000089       NaN
# 1922.Harding.txt    0.0       NaN        NaN       NaN       NaN  0.000086
# 1923.Coolidge.txt   0.0  0.000196   0.000252       NaN       NaN  0.000037
# 1924.Coolidge.txt   0.0  0.000378   0.000243  0.000250  0.000145  0.000035
# 1925.Coolidge.txt   0.0       NaN   0.000156  0.000161  0.000093  0.000160
# 1926.Coolidge.txt   0.0       NaN        NaN       NaN  0.000147  0.000024
# 1927.Coolidge.txt   0.0       NaN   0.000193  0.000199  0.000230  0.000028
# 1928.Coolidge.txt   0.0       NaN   0.000211       NaN  0.000126  0.000123
# 1929.Hoover.txt     0.0       NaN        NaN       NaN       NaN  0.000023
# ...                 ...       ...        ...       ...       ...       ...
# 1990.Bush.txt       0.0       NaN        NaN       NaN       NaN       NaN
# 1991.Bush.txt       0.0  0.000340        NaN       NaN       NaN  0.000064
# 1992.Bush.txt       0.0       NaN        NaN       NaN       NaN  0.000051
# 1993.Clinton.txt    0.0       NaN        NaN  0.000246       NaN  0.000105
# 1994.Clinton.txt    0.0       NaN   0.000225  0.000461  0.000067  0.000066
# 1995.Clinton.txt    0.0       NaN        NaN       NaN  0.000107  0.000053
# 1996.Clinton.txt    0.0  0.000413   0.000266       NaN  0.000158  0.000116
# 1997.Clinton.txt    0.0       NaN        NaN       NaN  0.000221  0.000253
# 1998.Clinton.txt    0.0       NaN        NaN       NaN       NaN  0.000267
# 1999.Clinton.txt    0.0       NaN        NaN       NaN  0.000066  0.000065
# 2000.Clinton.txt    0.0       NaN        NaN       NaN  0.000067  0.000132
# 2001.Bush.txt       0.0       NaN        NaN       NaN  0.000231  0.000057
# 2002.Bush.txt       0.0       NaN        NaN       NaN       NaN       NaN
# 2003.Bush.txt       0.0       NaN        NaN       NaN  0.000093  0.000046
# 2004.Bush.txt       0.0       NaN        NaN       NaN       NaN  0.000142
# 2005.Bush.txt       0.0  0.000517        NaN       NaN       NaN  0.000291
# 2006.Bush.txt       0.0  0.000247        NaN       NaN       NaN  0.000046
# 2007.Bush.txt       0.0  0.000235   0.000302       NaN       NaN       NaN
# 2008.Bush.txt       0.0  0.000228        NaN       NaN  0.000349       NaN
# 2009.Obama.txt      0.0       NaN        NaN       NaN  0.000251  0.000164
# 2010.Obama.txt      0.0       NaN        NaN       NaN  0.000070  0.000034
# 2011.Obama.txt      0.0  0.000186        NaN       NaN       NaN  0.000139
# 2012.Obama.txt      0.0       NaN        NaN       NaN       NaN  0.000103
# 2013.Obama.txt      0.0       NaN        NaN       NaN  0.000230       NaN
# 2014.Obama.txt      0.0       NaN        NaN       NaN       NaN  0.000035
# 2015.Obama.txt      0.0  0.000190        NaN       NaN       NaN  0.000036
# 2016.Obama.txt      0.0       NaN        NaN       NaN       NaN  0.000044
# 2017.Trump.txt      0.0       NaN        NaN       NaN  0.000099  0.000195
# 2018.Trump.txt      0.0       NaN        NaN       NaN       NaN  0.000096
# 2019.Trump.txt      0.0       NaN        NaN  0.000306       NaN  0.000131
#
#                     abolished  abolition  abortion     about  ...     yield  \
# filepath                                                      ...
# 1900.McKinley.txt         NaN        NaN       NaN  0.000056  ...       NaN
# 1901.Roosevelt.txt   0.000109        NaN       NaN  0.000020  ...       NaN
# 1902.Roosevelt.txt        NaN        NaN       NaN  0.000049  ...       NaN
# 1903.Roosevelt.txt        NaN        NaN       NaN  0.000052  ...       NaN
# 1904.Roosevelt.txt   0.000122   0.000131       NaN  0.000039  ...       NaN
# 1905.Roosevelt.txt   0.000341        NaN       NaN  0.000043  ...       NaN
# 1906.Roosevelt.txt   0.000091   0.000194       NaN  0.000037  ...       NaN
# 1907.Roosevelt.txt   0.000156        NaN       NaN  0.000046  ...  0.000057
# 1908.Roosevelt.txt        NaN   0.000236       NaN  0.000060  ...       NaN
# 1909.Taft.txt             NaN   0.000166       NaN  0.000049  ...       NaN
# 1910.Taft.txt        0.000334        NaN       NaN  0.000015  ...       NaN
# 1911.Taft.txt             NaN   0.000195       NaN  0.000049  ...  0.000066
# 1912.Taft.txt        0.000085        NaN       NaN  0.000035  ...  0.000062
# 1913.Wilson.txt           NaN        NaN       NaN  0.000082  ...       NaN
# 1914.Wilson.txt           NaN        NaN       NaN  0.000021  ...  0.000343
# 1915.Wilson.txt           NaN        NaN       NaN  0.000088  ...  0.000607
# 1916.Wilson.txt           NaN        NaN       NaN       NaN  ...       NaN
# 1917.Wilson.txt           NaN        NaN       NaN  0.000099  ...       NaN
# 1918.Wilson.txt           NaN        NaN       NaN  0.000071  ...       NaN
# 1919.Wilson.txt           NaN        NaN       NaN  0.000183  ...  0.000327
# 1920.Wilson.txt           NaN        NaN       NaN       NaN  ...       NaN
# 1921.Harding.txt     0.000381        NaN       NaN  0.000173  ...       NaN
# 1922.Harding.txt     0.000371   0.000398       NaN  0.000067  ...       NaN
# 1923.Coolidge.txt         NaN   0.000685       NaN  0.000101  ...  0.000466
# 1924.Coolidge.txt         NaN        NaN       NaN  0.000126  ...  0.000449
# 1925.Coolidge.txt         NaN        NaN       NaN  0.000117  ...  0.000144
# 1926.Coolidge.txt         NaN   0.000224       NaN  0.000142  ...       NaN
# 1927.Coolidge.txt         NaN        NaN       NaN  0.000189  ...       NaN
# 1928.Coolidge.txt         NaN        NaN       NaN  0.000085  ...       NaN
# 1929.Hoover.txt      0.000196   0.000211       NaN  0.000267  ...       NaN
# ...                       ...        ...       ...       ...  ...       ...
# 1990.Bush.txt             NaN        NaN       NaN  0.000226  ...       NaN
# 1991.Bush.txt             NaN        NaN       NaN  0.000151  ...       NaN
# 1992.Bush.txt             NaN        NaN       NaN  0.000141  ...       NaN
# 1993.Clinton.txt          NaN        NaN       NaN  0.000151  ...       NaN
# 1994.Clinton.txt          NaN        NaN       NaN  0.000142  ...  0.000208
# 1995.Clinton.txt          NaN        NaN       NaN  0.000228  ...       NaN
# 1996.Clinton.txt          NaN        NaN       NaN  0.000183  ...       NaN
# 1997.Clinton.txt          NaN        NaN       NaN  0.000114  ...       NaN
# 1998.Clinton.txt          NaN        NaN       NaN  0.000066  ...       NaN
# 1999.Clinton.txt          NaN        NaN       NaN  0.000064  ...       NaN
# 2000.Clinton.txt          NaN        NaN       NaN  0.000065  ...       NaN
# 2001.Bush.txt             NaN        NaN       NaN  0.000045  ...       NaN
# 2002.Bush.txt             NaN        NaN       NaN  0.000126  ...       NaN
# 2003.Bush.txt             NaN        NaN  0.000589  0.000090  ...       NaN
# 2004.Bush.txt             NaN        NaN       NaN  0.000093  ...       NaN
# 2005.Bush.txt             NaN   0.000452       NaN  0.000057  ...       NaN
# 2006.Bush.txt             NaN        NaN       NaN  0.000237  ...       NaN
# 2007.Bush.txt             NaN        NaN       NaN  0.000035  ...       NaN
# 2008.Bush.txt             NaN        NaN       NaN  0.000101  ...       NaN
# 2009.Obama.txt            NaN        NaN       NaN  0.000194  ...  0.000260
# 2010.Obama.txt            NaN        NaN       NaN  0.000242  ...       NaN
# 2011.Obama.txt            NaN        NaN       NaN  0.000247  ...       NaN
# 2012.Obama.txt            NaN        NaN       NaN  0.000203  ...       NaN
# 2013.Obama.txt            NaN        NaN       NaN  0.000089  ...       NaN
# 2014.Obama.txt            NaN        NaN       NaN  0.000111  ...       NaN
# 2015.Obama.txt            NaN        NaN       NaN  0.000098  ...       NaN
# 2016.Obama.txt            NaN        NaN       NaN  0.000190  ...       NaN
# 2017.Trump.txt            NaN        NaN       NaN  0.000038  ...       NaN
# 2018.Trump.txt            NaN        NaN       NaN  0.000094  ...       NaN
# 2019.Trump.txt            NaN        NaN  0.000560       NaN  ...  0.000275
#
#                         york       you     young   younger      your  \
# filepath
# 1900.McKinley.txt        NaN  0.000040       NaN       NaN  0.000195
# 1901.Roosevelt.txt       NaN  0.000007       NaN  0.000105  0.000050
# 1902.Roosevelt.txt       NaN  0.000007  0.000162       NaN  0.000075
# 1903.Roosevelt.txt  0.000300  0.000009  0.000036       NaN  0.000050
# 1904.Roosevelt.txt  0.000169  0.000016  0.000091       NaN  0.000084
# 1905.Roosevelt.txt  0.000118  0.000008  0.000021       NaN  0.000108
# 1906.Roosevelt.txt  0.000377  0.000027  0.000202       NaN  0.000125
# 1907.Roosevelt.txt  0.000325  0.000003  0.000019       NaN  0.000090
# 1908.Roosevelt.txt  0.000076  0.000004       NaN       NaN  0.000038
# 1909.Taft.txt       0.000107  0.000005  0.000115  0.000149  0.000089
# 1910.Taft.txt       0.000232  0.000011  0.000083       NaN       NaN
# 1911.Taft.txt       0.000126  0.000053  0.000045       NaN  0.000073
# 1912.Taft.txt            NaN  0.000003  0.000021       NaN  0.000039
# 1913.Wilson.txt          NaN  0.000195       NaN       NaN  0.000277
# 1914.Wilson.txt          NaN  0.000076  0.000350       NaN  0.000108
# 1915.Wilson.txt          NaN  0.000172  0.000069  0.000537  0.000288
# 1916.Wilson.txt          NaN  0.000262       NaN       NaN  0.000232
# 1917.Wilson.txt          NaN  0.000124       NaN       NaN  0.000063
# 1918.Wilson.txt          NaN  0.000114       NaN       NaN  0.000315
# 1919.Wilson.txt          NaN  0.000073       NaN       NaN  0.000207
# 1920.Wilson.txt          NaN  0.000129       NaN       NaN  0.000456
# 1921.Harding.txt         NaN  0.000161       NaN       NaN  0.000351
# 1922.Harding.txt         NaN  0.000060       NaN       NaN  0.000257
# 1923.Coolidge.txt   0.000222  0.000010  0.000079       NaN  0.000074
# 1924.Coolidge.txt        NaN       NaN  0.000076       NaN       NaN
# 1925.Coolidge.txt        NaN  0.000013       NaN       NaN  0.000023
# 1926.Coolidge.txt        NaN  0.000014       NaN       NaN  0.000048
# 1927.Coolidge.txt   0.000170  0.000008       NaN       NaN       NaN
# 1928.Coolidge.txt        NaN  0.000009  0.000066       NaN  0.000031
# 1929.Hoover.txt          NaN       NaN       NaN  0.000190  0.000023
# ...                      ...       ...       ...       ...       ...
# 1990.Bush.txt            NaN  0.000325  0.000275       NaN  0.000384
# 1991.Bush.txt            NaN  0.000162       NaN       NaN  0.000064
# 1992.Bush.txt            NaN  0.000722       NaN       NaN  0.000409
# 1993.Clinton.txt         NaN  0.000484  0.000226       NaN  0.000280
# 1994.Clinton.txt    0.000197  0.000611  0.000494       NaN  0.000393
# 1995.Clinton.txt         NaN  0.000513  0.000283       NaN  0.000184
# 1996.Clinton.txt    0.000233  0.000394  0.000334       NaN  0.000466
# 1997.Clinton.txt         NaN  0.000317  0.000389       NaN  0.000253
# 1998.Clinton.txt         NaN  0.000499  0.000215       NaN  0.000233
# 1999.Clinton.txt         NaN  0.000552  0.000210       NaN  0.000261
# 2000.Clinton.txt         NaN  0.000260  0.000567       NaN  0.000198
# 2001.Bush.txt            NaN  0.000432       NaN  0.000953  0.000340
# 2002.Bush.txt       0.000768  0.000216       NaN  0.000536  0.000255
# 2003.Bush.txt       0.000276  0.000349       NaN  0.000385  0.000367
# 2004.Bush.txt            NaN  0.000629  0.000306  0.000399  0.000285
# 2005.Bush.txt            NaN  0.000356  0.000627  0.001632  0.000631
# 2006.Bush.txt            NaN  0.000170  0.000199       NaN  0.000278
# 2007.Bush.txt            NaN  0.000287       NaN       NaN  0.000088
# 2008.Bush.txt            NaN  0.000315  0.000185       NaN  0.000600
# 2009.Obama.txt           NaN  0.000360  0.000177       NaN  0.000616
# 2010.Obama.txt           NaN  0.000222  0.000147       NaN  0.000034
# 2011.Obama.txt           NaN  0.000344  0.000225       NaN  0.000244
# 2012.Obama.txt           NaN  0.000495  0.000222       NaN  0.000275
# 2013.Obama.txt      0.000678  0.000170  0.000485       NaN  0.000188
# 2014.Obama.txt      0.000212  0.000249  0.000683       NaN  0.000176
# 2015.Obama.txt      0.000430  0.000333  0.000615  0.000300  0.000357
# 2016.Obama.txt      0.000264  0.000297  0.000284       NaN  0.000132
# 2017.Trump.txt           NaN  0.000330  0.000314       NaN  0.000243
# 2018.Trump.txt      0.000288  0.000325  0.000413       NaN  0.000192
# 2019.Trump.txt      0.000524  0.000553  0.000468       NaN  0.000087
#
#                        yours     youth      zone     zones
# filepath
# 1900.McKinley.txt        NaN       NaN       NaN  0.000106
# 1901.Roosevelt.txt       NaN       NaN       NaN       NaN
# 1902.Roosevelt.txt       NaN       NaN       NaN       NaN
# 1903.Roosevelt.txt       NaN       NaN  0.000405       NaN
# 1904.Roosevelt.txt       NaN  0.000081  0.000229       NaN
# 1905.Roosevelt.txt       NaN       NaN  0.000080       NaN
# 1906.Roosevelt.txt  0.000088       NaN  0.000085       NaN
# 1907.Roosevelt.txt       NaN       NaN       NaN       NaN
# 1908.Roosevelt.txt       NaN       NaN       NaN       NaN
# 1909.Taft.txt            NaN       NaN  0.000290       NaN
# 1910.Taft.txt            NaN       NaN       NaN       NaN
# 1911.Taft.txt            NaN       NaN  0.000682       NaN
# 1912.Taft.txt            NaN       NaN  0.000480       NaN
# 1913.Wilson.txt          NaN       NaN       NaN       NaN
# 1914.Wilson.txt          NaN       NaN       NaN       NaN
# 1915.Wilson.txt          NaN       NaN       NaN       NaN
# 1916.Wilson.txt          NaN       NaN       NaN       NaN
# 1917.Wilson.txt          NaN       NaN       NaN       NaN
# 1918.Wilson.txt          NaN       NaN       NaN       NaN
# 1919.Wilson.txt          NaN       NaN       NaN       NaN
# 1920.Wilson.txt          NaN       NaN       NaN       NaN
# 1921.Harding.txt         NaN       NaN       NaN       NaN
# 1922.Harding.txt         NaN  0.000245       NaN       NaN
# 1923.Coolidge.txt        NaN       NaN       NaN       NaN
# 1924.Coolidge.txt        NaN       NaN       NaN       NaN
# 1925.Coolidge.txt        NaN       NaN       NaN       NaN
# 1926.Coolidge.txt        NaN       NaN       NaN       NaN
# 1927.Coolidge.txt        NaN       NaN       NaN       NaN
# 1928.Coolidge.txt        NaN       NaN  0.000251       NaN
# 1929.Hoover.txt          NaN  0.000130  0.000184  0.000184
# ...                      ...       ...       ...       ...
# 1990.Bush.txt       0.001074       NaN       NaN  0.000521
# 1991.Bush.txt            NaN       NaN  0.000519  0.000519
# 1992.Bush.txt       0.000430       NaN  0.000416       NaN
# 1993.Clinton.txt         NaN  0.000200       NaN  0.000285
# 1994.Clinton.txt         NaN       NaN       NaN  0.000267
# 1995.Clinton.txt         NaN       NaN       NaN       NaN
# 1996.Clinton.txt         NaN  0.000222       NaN  0.000316
# 1997.Clinton.txt         NaN       NaN       NaN  0.000295
# 1998.Clinton.txt         NaN       NaN       NaN  0.000271
# 1999.Clinton.txt         NaN       NaN       NaN  0.000265
# 2000.Clinton.txt         NaN  0.000189       NaN  0.000268
# 2001.Bush.txt       0.000477       NaN       NaN       NaN
# 2002.Bush.txt            NaN       NaN       NaN       NaN
# 2003.Bush.txt            NaN       NaN       NaN       NaN
# 2004.Bush.txt            NaN       NaN       NaN       NaN
# 2005.Bush.txt       0.000408  0.000278       NaN       NaN
# 2006.Bush.txt       0.000389  0.000796       NaN       NaN
# 2007.Bush.txt            NaN       NaN       NaN       NaN
# 2008.Bush.txt            NaN       NaN       NaN       NaN
# 2009.Obama.txt           NaN       NaN       NaN       NaN
# 2010.Obama.txt      0.000287       NaN       NaN       NaN
# 2011.Obama.txt           NaN       NaN       NaN       NaN
# 2012.Obama.txt           NaN       NaN       NaN       NaN
# 2013.Obama.txt           NaN       NaN       NaN       NaN
# 2014.Obama.txt           NaN       NaN       NaN       NaN
# 2015.Obama.txt           NaN       NaN       NaN       NaN
# 2016.Obama.txt           NaN       NaN       NaN       NaN
# 2017.Trump.txt           NaN  0.000557       NaN       NaN
# 2018.Trump.txt           NaN  0.000274       NaN       NaN
# 2019.Trump.txt           NaN       NaN       NaN       NaN
#
# [119 rows x 4844 columns]

# %% [markdown]
# High-frequency words like `a` are not distinctive of particular texts because they are used at comparable rates. Other numbers with higher values distinguish particular texts because they

# %% [markdown]
# We could use this dataframe for a couple of things. We could look at which documents are associated with which words.
#
# `.nlargest()` gives us the largest results

# %%
sotu_tfidf['jobs'].nlargest(10) # our function is working:
# Out:
# filepath
# 2013.Obama.txt      0.002642
# 2012.Obama.txt      0.002576
# 2011.Obama.txt      0.001978
# 1993.Clinton.txt    0.001906
# 2014.Obama.txt      0.001841
# 2010.Obama.txt      0.001784
# 2002.Bush.txt       0.001594
# 1994.Clinton.txt    0.001489
# 2015.Obama.txt      0.001459
# 2009.Obama.txt      0.001306
# Name: jobs, dtype: float64

# %%
sotu_tfidf['vietnam'].nlargest(10) # would expect this to be during the US war in Vietnam
# Out:
# filepath
# 1966.Johnson.txt    0.011771
# 1967.Johnson.txt    0.005730
# 1969.Johnson.txt    0.003804
# 1973.Nixon.txt      0.002325
# 1968.Johnson.txt    0.001592
# 1970.Nixon.txt      0.001311
# 1985.Reagan.txt     0.000904
# 1977.Ford.txt       0.000837
# 1996.Clinton.txt    0.000612
# 1987.Reagan.txt     0.000501
# Name: vietnam, dtype: float64

# %%
sotu_tfidf['war'].nlargest(10) # who talks the most about war
# Out:
# filepath
# 1944.Roosevelt.txt    0.000676
# 1943.Roosevelt.txt    0.000508
# 1945.Roosevelt.txt    0.000479
# 1942.Roosevelt.txt    0.000459
# 1917.Wilson.txt       0.000407
# 1946.Truman.txt       0.000381
# 1953.Truman.txt       0.000298
# 1941.Roosevelt.txt    0.000249
# 1918.Wilson.txt       0.000227
# 1920.Wilson.txt       0.000210
# Name: war, dtype: float64

# %%
sotu_tfidf['taxes'].nlargest(10) # who talks the most about taxes?
# Out:
# filepath
# 1973.Nixon.txt     0.001005
# 1975.Ford.txt      0.000826
# 2004.Bush.txt      0.000583
# 1982.Reagan.txt    0.000577
# 2001.Bush.txt      0.000542
# 1920.Wilson.txt    0.000498
# 1984.Reagan.txt    0.000468
# 1972.Nixon.txt     0.000422
# 2012.Obama.txt     0.000375
# 2010.Obama.txt     0.000373
# Name: taxes, dtype: float64

# %% [markdown]
# We could also use it in the opposite way, to show which words are most closely associated with each document. Our dataframe's `index` gives us each of the files:

# %%
sotu_tfidf.index[:3]
# Out:
# Index(['1900.McKinley.txt', '1901.Roosevelt.txt', '1902.Roosevelt.txt'], dtype='object', name='filepath')

# %% [markdown]
# And if we take any given document, and sort its *row* from high to low, we get the words that are most associated with that document:

# %%
sotu_tfidf.index[0]
# Out:
# '1900.McKinley.txt'

# %%
test = sotu_tfidf.index[0]

# %% [markdown]
# We can get all of the values for the row with `loc`:

# %%
sotu_tfidf.loc[test].nlargest(10) # these are the words that most distinguish McKinley's 1900 speech from all others
# Out:
# islands       0.004154
# imperial      0.002139
# convention    0.002084
# chinese       0.001943
# spain         0.001569
# philippine    0.001551
# island        0.001438
# governor      0.001286
# acres         0.001283
# commission    0.001244
# Name: 1900.McKinley.txt, dtype: float64

# %% [markdown]
# Then, we can use a few of the formatting tricks we've learned to see what we get:

# %%
n_words = 5
for index in sotu_tfidf.index:
    # get row for this index
    row=sotu_tfidf.loc[index]
    
    # get the lagest words
    top_words_series=row.nlargest(n_words)
    top_words_list=list(top_words_series.index)
    top_words_str=', '.join(top_words_list)
    
    # print
    print(index)
    print(top_words_str)
    print('-'*80)
# Out:
# 1900.McKinley.txt
# islands, imperial, convention, chinese, spain
# --------------------------------------------------------------------------------
# 1901.Roosevelt.txt
# ships, navy, forest, arid, streams
# --------------------------------------------------------------------------------
# 1902.Roosevelt.txt
# cable, tariff, corporations, navy, therein
# --------------------------------------------------------------------------------
# 1903.Roosevelt.txt
# isthmus, panama, colombia, canal, treaty
# --------------------------------------------------------------------------------
# 1904.Roosevelt.txt
# naturalization, forest, islands, indian, reserves
# --------------------------------------------------------------------------------
# 1905.Roosevelt.txt
# islands, supervision, railroad, chinese, interstate
# --------------------------------------------------------------------------------
# 1906.Roosevelt.txt
# colored, judge, japanese, conference, islands
# --------------------------------------------------------------------------------
# 1907.Roosevelt.txt
# interstate, navy, army, combinations, corporations
# --------------------------------------------------------------------------------
# 1908.Roosevelt.txt
# judges, mountains, corporations, fisheries, interstate
# --------------------------------------------------------------------------------
# 1909.Taft.txt
# tariff, department, convention, courts, court
# --------------------------------------------------------------------------------
# 1910.Taft.txt
# estimates, commercial, diplomatic, convention, tariff
# --------------------------------------------------------------------------------
# 1911.Taft.txt
# wool, statute, tobacco, canal, mexican
# --------------------------------------------------------------------------------
# 1912.Taft.txt
# canal, panama, department, currency, consular
# --------------------------------------------------------------------------------
# 1913.Wilson.txt
# nominees, debatable, beg, mexico, ought
# --------------------------------------------------------------------------------
# 1914.Wilson.txt
# tasks, domain, profitable, ships, conceived
# --------------------------------------------------------------------------------
# 1915.Wilson.txt
# cruisers, submarines, battleships, fifteen, destroyers
# --------------------------------------------------------------------------------
# 1916.Wilson.txt
# interstate, suggestions, adoption, concerted, organic
# --------------------------------------------------------------------------------
# 1917.Wilson.txt
# german, masters, wrongs, austria, hungary
# --------------------------------------------------------------------------------
# 1918.Wilson.txt
# empires, railways, quick, roads, knew
# --------------------------------------------------------------------------------
# 1919.Wilson.txt
# unrest, storage, shipment, statesmen, workman
# --------------------------------------------------------------------------------
# 1920.Wilson.txt
# floating, respectfully, serviceable, storage, sentence
# --------------------------------------------------------------------------------
# 1921.Harding.txt
# bushels, tariff, reclamation, insistent, acres
# --------------------------------------------------------------------------------
# 1922.Harding.txt
# railway, motor, managers, tribunal, freight
# --------------------------------------------------------------------------------
# 1923.Coolidge.txt
# ought, court, method, favor, consolidations
# --------------------------------------------------------------------------------
# 1924.Coolidge.txt
# court, railways, claims, taxation, conference
# --------------------------------------------------------------------------------
# 1925.Coolidge.txt
# court, ought, league, judges, investigation
# --------------------------------------------------------------------------------
# 1926.Coolidge.txt
# ought, tariff, cotton, imports, islands
# --------------------------------------------------------------------------------
# 1927.Coolidge.txt
# farmer, property, navigation, agriculture, flood
# --------------------------------------------------------------------------------
# 1928.Coolidge.txt
# cent, negro, agriculture, commerce, department
# --------------------------------------------------------------------------------
# 1929.Hoover.txt
# contracts, tariff, mail, cent, per
# --------------------------------------------------------------------------------
# 1930.Hoover.txt
# depression, cent, affected, construction, distress
# --------------------------------------------------------------------------------
# 1931.Hoover.txt
# banks, emergencies, securities, banking, hoarding
# --------------------------------------------------------------------------------
# 1932.Hoover.txt
# banking, banks, reconstruction, failures, corporation
# --------------------------------------------------------------------------------
# 1934.Roosevelt.txt
# exploitation, restoration, violations, seed, impulse
# --------------------------------------------------------------------------------
# 1935.Roosevelt.txt
# destitution, livelihood, relief, unemployed, dictates
# --------------------------------------------------------------------------------
# 1936.Roosevelt.txt
# autocracy, rulers, neighbor, popular, americas
# --------------------------------------------------------------------------------
# 1937.Roosevelt.txt
# democracy, fluctuations, interpretation, speculation, continuously
# --------------------------------------------------------------------------------
# 1938.Roosevelt.txt
# purchasing, abuses, trend, farming, inherent
# --------------------------------------------------------------------------------
# 1939.Roosevelt.txt
# eighty, religion, idle, democracy, learned
# --------------------------------------------------------------------------------
# 1940.Roosevelt.txt
# defeatism, dictatorships, phrase, wars, compelled
# --------------------------------------------------------------------------------
# 1941.Roosevelt.txt
# dictators, impressive, dictator, schedule, expression
# --------------------------------------------------------------------------------
# 1942.Roosevelt.txt
# hitler, japanese, conquest, nazis, planes
# --------------------------------------------------------------------------------
# 1943.Roosevelt.txt
# axis, japanese, planes, british, produced
# --------------------------------------------------------------------------------
# 1944.Roosevelt.txt
# sailors, moscow, stabilization, soldiers, accepted
# --------------------------------------------------------------------------------
# 1945.Roosevelt.txt
# nurses, japanese, german, french, france
# --------------------------------------------------------------------------------
# 1946.Truman.txt
# expenditures, authorizations, fiscal, dollars, estimated
# --------------------------------------------------------------------------------
# 1947.Truman.txt
# jurisdictional, collective, bargaining, management, atomic
# --------------------------------------------------------------------------------
# 1948.Truman.txt
# p, earners, output, inflation, loss
# --------------------------------------------------------------------------------
# 1949.Truman.txt
# boom, democratic, rent, units, authorize
# --------------------------------------------------------------------------------
# 1950.Truman.txt
# democratic, achieved, transmit, enjoyment, businessmen
# --------------------------------------------------------------------------------
# 1951.Truman.txt
# soviet, b, kremlin, planes, aggression
# --------------------------------------------------------------------------------
# 1952.Truman.txt
# communist, korea, bushels, curtain, luxuries
# --------------------------------------------------------------------------------
# 1953.Truman.txt
# communist, atomic, rulers, communists, soviet
# --------------------------------------------------------------------------------
# 1954.Eisenhower.txt
# shall, mobilization, communist, highway, recommendations
# --------------------------------------------------------------------------------
# 1955.Eisenhower.txt
# survivors, shall, rd, servicemen, communist
# --------------------------------------------------------------------------------
# 1956.Eisenhower.txt
# atomic, communist, highway, objectives, surpluses
# --------------------------------------------------------------------------------
# 1957.Eisenhower.txt
# atomic, interdependence, scene, forefathers, agency
# --------------------------------------------------------------------------------
# 1958.Eisenhower.txt
# missiles, soviets, ballistic, disarmament, missile
# --------------------------------------------------------------------------------
# 1959.Eisenhower.txt
# missile, requesting, thrift, committee, ballistic
# --------------------------------------------------------------------------------
# 1960.Eisenhower.txt
# steel, emerging, newly, space, exploration
# --------------------------------------------------------------------------------
# 1961.Eisenhower.txt
# communist, eight, veterans, strengthened, wheat
# --------------------------------------------------------------------------------
# 1962.Kennedy.txt
# un, atlantic, sixties, tests, import
# --------------------------------------------------------------------------------
# 1963.Kennedy.txt
# alliance, nam, viet, communist, nuclear
# --------------------------------------------------------------------------------
# 1964.Johnson.txt
# libraries, hopes, session, poverty, color
# --------------------------------------------------------------------------------
# 1965.Johnson.txt
# beauty, enrich, hill, propose, centers
# --------------------------------------------------------------------------------
# 1966.Johnson.txt
# vietnam, tonight, south, propose, master
# --------------------------------------------------------------------------------
# 1967.Johnson.txt
# vietnam, tonight, try, rose, percent
# --------------------------------------------------------------------------------
# 1968.Johnson.txt
# billion, consumer, abundance, tonight, travel
# --------------------------------------------------------------------------------
# 1969.Johnson.txt
# vietnam, commitments, tonight, think, quest
# --------------------------------------------------------------------------------
# 1970.Nixon.txt
# seventies, sixties, clean, spaces, blame
# --------------------------------------------------------------------------------
# 1971.Nixon.txt
# door, localities, responsive, peacetime, chance
# --------------------------------------------------------------------------------
# 1972.Nixon.txt
# seventies, property, technological, sixties, tie
# --------------------------------------------------------------------------------
# 1973.Nixon.txt
# messages, outline, credibility, lesson, notion
# --------------------------------------------------------------------------------
# 1974.Nixon.txt
# privacy, colleagues, initiatives, confrontation, outrage
# --------------------------------------------------------------------------------
# 1975.Ford.txt
# oil, barrels, crude, petroleum, energy
# --------------------------------------------------------------------------------
# 1976.Ford.txt
# bicentennial, favors, adversaries, convicted, crimes
# --------------------------------------------------------------------------------
# 1977.Ford.txt
# strategic, energy, deter, capabilities, significant
# --------------------------------------------------------------------------------
# 1978.Carter.txt
# ve, inflation, canal, ll, tonight
# --------------------------------------------------------------------------------
# 1979.Carter.txt
# salt, ve, inflation, nuclear, foundation
# --------------------------------------------------------------------------------
# 1980.Carter.txt
# soviet, oil, afghanistan, ve, persian
# --------------------------------------------------------------------------------
# 1981.Carter.txt
# u, soviet, administration, oil, solar
# --------------------------------------------------------------------------------
# 1982.Reagan.txt
# ve, re, programs, needy, deficits
# --------------------------------------------------------------------------------
# 1983.Reagan.txt
# realism, deficits, recovery, spending, m
# --------------------------------------------------------------------------------
# 1984.Reagan.txt
# re, space, lebanon, frontier, excellence
# --------------------------------------------------------------------------------
# 1985.Reagan.txt
# re, ve, spreading, abortion, dreams
# --------------------------------------------------------------------------------
# 1986.Reagan.txt
# music, hollings, tonight, gramm, rudman
# --------------------------------------------------------------------------------
# 1987.Reagan.txt
# t, sun, franklin, ve, soviet
# --------------------------------------------------------------------------------
# 1988.Reagan.txt
# tonight, consensus, fighters, re, ve
# --------------------------------------------------------------------------------
# 1989.Bush.txt
# tonight, ve, drugs, m, re
# --------------------------------------------------------------------------------
# 1990.Bush.txt
# kids, ve, tonight, idea, poland
# --------------------------------------------------------------------------------
# 1991.Bush.txt
# saddam, gulf, persian, iraq, thinks
# --------------------------------------------------------------------------------
# 1992.Bush.txt
# t, missiles, someone, tell, desert
# --------------------------------------------------------------------------------
# 1993.Clinton.txt
# re, ll, t, jobs, cuts
# --------------------------------------------------------------------------------
# 1994.Clinton.txt
# t, re, kids, brady, richard
# --------------------------------------------------------------------------------
# 1995.Clinton.txt
# covenant, t, re, ve, lot
# --------------------------------------------------------------------------------
# 1996.Clinton.txt
# challenge, richard, gangs, parents, adults
# --------------------------------------------------------------------------------
# 1997.Clinton.txt
# internet, parents, tonight, college, ban
# --------------------------------------------------------------------------------
# 1998.Clinton.txt
# bosnia, re, college, millennium, tonight
# --------------------------------------------------------------------------------
# 1999.Clinton.txt
# tonight, medicare, century, st, millennium
# --------------------------------------------------------------------------------
# 2000.Clinton.txt
# gun, college, internet, parents, affordable
# --------------------------------------------------------------------------------
# 2001.Bush.txt
# mayor, medicare, reading, americas, pays
# --------------------------------------------------------------------------------
# 2002.Bush.txt
# terrorist, afghanistan, terror, terrorists, camps
# --------------------------------------------------------------------------------
# 2003.Bush.txt
# hussein, saddam, inspectors, qaida, iraq
# --------------------------------------------------------------------------------
# 2004.Bush.txt
# iraq, marriage, seniors, terrorists, saddam
# --------------------------------------------------------------------------------
# 2005.Bush.txt
# iraq, terror, iraqis, terrorists, iraqi
# --------------------------------------------------------------------------------
# 2006.Bush.txt
# iraqi, retreat, iraqis, terrorist, offensive
# --------------------------------------------------------------------------------
# 2007.Bush.txt
# iraq, qaeda, iraqi, terrorists, al
# --------------------------------------------------------------------------------
# 2008.Bush.txt
# iraq, iraqi, empower, al, qaeda
# --------------------------------------------------------------------------------
# 2009.Obama.txt
# t, lending, re, don, banks
# --------------------------------------------------------------------------------
# 2010.Obama.txt
# t, businesses, why, lobbyists, ve
# --------------------------------------------------------------------------------
# 2011.Obama.txt
# re, t, ve, innovation, ll
# --------------------------------------------------------------------------------
# 2012.Obama.txt
# t, ve, re, jobs, m
# --------------------------------------------------------------------------------
# 2013.Obama.txt
# t, jobs, tonight, she, m
# --------------------------------------------------------------------------------
# 2014.Obama.txt
# t, she, re, workforce, kids
# --------------------------------------------------------------------------------
# 2015.Obama.txt
# ve, t, re, doesn, economics
# --------------------------------------------------------------------------------
# 2016.Obama.txt
# isil, t, ve, voices, doesn
# --------------------------------------------------------------------------------
# 2017.Trump.txt
# megan, ryan, ve, infrastructure, tonight
# --------------------------------------------------------------------------------
# 2018.Trump.txt
# isis, tonight, ryan, heroes, gang
# --------------------------------------------------------------------------------
# 2019.Trump.txt
# applause, usa, thank, audience, border
# --------------------------------------------------------------------------------

# %% [markdown]
# # How much more likely is a group to use a given word?
# tf`*`idf tells us a lot about which words are in which documents, but not much about the groups as a whole.
#
# Earlier, we used difference of means to compare groups on average. However, text documents vary in length. We might want an approach that takes all of the instances into account.

# %% [markdown]
# ## Fisher's exact test
# [Fisher's Exact Test](https://en.wikipedia.org/wiki/Fisher%27s_exact_test) allows us to calculate the odds (and the p-value) that a given word would be used by a given group. It is based on contingency tables (aka cross tabluations) which look like this:
#
# |            | Guess milk | Guess tea |   |
# |------------|------------|-----------|---|
# | Milk first | 4          | 0         |   |
# | Tea first  | 0          | 4         |   |
# |   Total    | 4          | 4         | 8 |

# %% [markdown]
# To make a comparable contingency matrix, we need the following categories for data about words:
#
# |         | Number of target word | All words except target word |   |
# |---------|-----------------------|------------------------------|---|
# | Group A | w                     | x                            |   |
# | Group B | y                     | z                            |   |
# |  Total  |                       |                              | n |

# %% [markdown]
# ## Fisher's exact requires raw counts, not scaled:
# To start, we need a dtm containing raw counts:

# %%
sotus = '/Users/e/code/literarytextmining/corpora/sotu_1900-2019/texts'

# %%
df = make_dtm(sotus, scaled = False, drop_below=50)

# %%
df.head()
# Out:
#                       a  ability  able  about  above  abroad  absolutely  \
# filepath
# 1900.McKinley.txt   253      4.0   3.0   11.0    2.0     4.0         NaN
# 1901.Roosevelt.txt  275      5.0  11.0    4.0    6.0     7.0         4.0
# 1902.Roosevelt.txt  181      2.0   1.0    5.0    8.0     4.0         1.0
# 1903.Roosevelt.txt  215      2.0   NaN    8.0    9.0     NaN         NaN
# 1904.Roosevelt.txt  247      1.0   6.0    7.0    7.0     7.0         3.0
#
#                     abuse  abuses  accept  ...  worthy  would  wrong  year  \
# filepath                                   ...
# 1900.McKinley.txt     NaN     NaN     NaN  ...     2.0   13.0    NaN  48.0
# 1901.Roosevelt.txt    NaN     3.0     1.0  ...     NaN   47.0    3.0   9.0
# 1902.Roosevelt.txt    NaN     NaN     NaN  ...     1.0   36.0    2.0   7.0
# 1903.Roosevelt.txt    NaN     NaN     NaN  ...     1.0   26.0    1.0  39.0
# 1904.Roosevelt.txt    NaN     5.0     4.0  ...     3.0   43.0   10.0  12.0
#
#                     years  yes   yet   you  young  your
# filepath
# 1900.McKinley.txt     8.0  NaN   4.0  11.0    NaN  15.0
# 1901.Roosevelt.txt   26.0  NaN  10.0   2.0    NaN   4.0
# 1902.Roosevelt.txt    5.0  NaN   6.0   1.0    3.0   3.0
# 1903.Roosevelt.txt   19.0  NaN   9.0   2.0    1.0   3.0
# 1904.Roosevelt.txt   13.0  NaN  14.0   4.0    3.0   6.0
#
# [5 rows x 1834 columns]

# %% [markdown]
# Let's re-add our metadata:

# %%
meta.head()
# Out:
#    president  year            filepath       party
# 0   McKinley  1900   1900.McKinley.txt  Republican
# 1  Roosevelt  1901  1901.Roosevelt.txt  Republican
# 2  Roosevelt  1902  1902.Roosevelt.txt  Republican
# 3  Roosevelt  1903  1903.Roosevelt.txt  Republican
# 4  Roosevelt  1904  1904.Roosevelt.txt  Republican

# %%
df = pd.merge(df,meta,on='filepath')

# %%
df.set_index('filepath', inplace=True)

# %% [markdown]
# Note that once again we get the extra metadata columns at the end:

# %%
df.head()
# Out:
#                       a  ability  able  about  above  abroad  absolutely  \
# filepath
# 1900.McKinley.txt   253      4.0   3.0   11.0    2.0     4.0         NaN
# 1901.Roosevelt.txt  275      5.0  11.0    4.0    6.0     7.0         4.0
# 1902.Roosevelt.txt  181      2.0   1.0    5.0    8.0     4.0         1.0
# 1903.Roosevelt.txt  215      2.0   NaN    8.0    9.0     NaN         NaN
# 1904.Roosevelt.txt  247      1.0   6.0    7.0    7.0     7.0         3.0
#
#                     abuse  abuses  accept  ...  year_x  years  yes   yet  \
# filepath                                   ...
# 1900.McKinley.txt     NaN     NaN     NaN  ...    48.0    8.0  NaN   4.0
# 1901.Roosevelt.txt    NaN     3.0     1.0  ...     9.0   26.0  NaN  10.0
# 1902.Roosevelt.txt    NaN     NaN     NaN  ...     7.0    5.0  NaN   6.0
# 1903.Roosevelt.txt    NaN     NaN     NaN  ...    39.0   19.0  NaN   9.0
# 1904.Roosevelt.txt    NaN     5.0     4.0  ...    12.0   13.0  NaN  14.0
#
#                      you  young  your  president_y  year_y     party_y
# filepath
# 1900.McKinley.txt   11.0    NaN  15.0     McKinley    1900  Republican
# 1901.Roosevelt.txt   2.0    NaN   4.0    Roosevelt    1901  Republican
# 1902.Roosevelt.txt   1.0    3.0   3.0    Roosevelt    1902  Republican
# 1903.Roosevelt.txt   2.0    1.0   3.0    Roosevelt    1903  Republican
# 1904.Roosevelt.txt   4.0    3.0   6.0    Roosevelt    1904  Republican
#
# [5 rows x 1837 columns]

# %%
words = df.columns[:-3] # just get our words to avoid calculating on the metadata

# %%
words[:3], words[-3:]
# Out:
# (Index(['a', 'ability', 'able'], dtype='object'),
#  Index(['you', 'young', 'your'], dtype='object'))

# %% [markdown]
# From skimming the tf`*`idf results above, we know that George W. Bush was most likely to talk about `iraq`. Let's see if that holds true for the Republican party as a whole:

# %%
Rs=df[df['party_y'] == 'Republican'][words]
Ds= df[df['party_y'] == 'Democrat'][words]
Rs.head()
# Out:
#                       a  ability  able  about  above  abroad  absolutely  \
# filepath
# 1900.McKinley.txt   253      4.0   3.0   11.0    2.0     4.0         NaN
# 1901.Roosevelt.txt  275      5.0  11.0    4.0    6.0     7.0         4.0
# 1902.Roosevelt.txt  181      2.0   1.0    5.0    8.0     4.0         1.0
# 1903.Roosevelt.txt  215      2.0   NaN    8.0    9.0     NaN         NaN
# 1904.Roosevelt.txt  247      1.0   6.0    7.0    7.0     7.0         3.0
#
#                     abuse  abuses  accept  ...  worthy  would  wrong  year_x  \
# filepath                                   ...
# 1900.McKinley.txt     NaN     NaN     NaN  ...     2.0   13.0    NaN    48.0
# 1901.Roosevelt.txt    NaN     3.0     1.0  ...     NaN   47.0    3.0     9.0
# 1902.Roosevelt.txt    NaN     NaN     NaN  ...     1.0   36.0    2.0     7.0
# 1903.Roosevelt.txt    NaN     NaN     NaN  ...     1.0   26.0    1.0    39.0
# 1904.Roosevelt.txt    NaN     5.0     4.0  ...     3.0   43.0   10.0    12.0
#
#                     years  yes   yet   you  young  your
# filepath
# 1900.McKinley.txt     8.0  NaN   4.0  11.0    NaN  15.0
# 1901.Roosevelt.txt   26.0  NaN  10.0   2.0    NaN   4.0
# 1902.Roosevelt.txt    5.0  NaN   6.0   1.0    3.0   3.0
# 1903.Roosevelt.txt   19.0  NaN   9.0   2.0    1.0   3.0
# 1904.Roosevelt.txt   13.0  NaN  14.0   4.0    3.0   6.0
#
# [5 rows x 1834 columns]

# %% [markdown]
# ## First column: frequencies of target word by group

# %%
word='iraq'
sum_word_Rs = Rs[word].sum()
sum_word_Ds = Ds[word].sum()

print(sum_word_Rs,sum_word_Ds) # these are our frequencies for each group. they will be column 1 in our contingency table
# Out:
# 105.0 31.0

# %% [markdown]
# ## Second column: sum of all words minus our target words
# We can get the sum of all of our words by calling `sum` twice. This adds every column, and then adds every row in the resulting series:

# %%
Rs.sum().sum()
# Out:
# 448709.0

# %%
sum_allword_Rs=Rs.sum().sum()
sum_allword_Rs
# Out:
# 448709.0

# %%
sum_allword_Ds=Ds.sum().sum()
sum_allword_Ds
# Out:
# 305467.0

# %%
sum_notword_Rs = sum_allword_Rs - sum_word_Rs
sum_notword_Rs
# Out:
# 448604.0

# %%
sum_notword_Ds = sum_allword_Ds - sum_word_Ds
sum_notword_Ds
# Out:
# 305436.0

# %% [markdown]
# ## Make the table:

# %%
contingency_table = [
    [sum_word_Rs, sum_notword_Rs],
    [sum_word_Ds, sum_notword_Ds]
]

# %%
contingency_table
# Out:
# [[105.0, 448604.0], [31.0, 305436.0]]

# %% [markdown]
# To return to our data from above with our example, `contingency_table` now has:
#
# |            | Number of "iraq" | Sum of all words except "Iraq" |         |
# |------------|------------------|--------------------------------|---------|
# | Republican | 105              | 448604                         |         |
# | Democrat   | 31               | 305436                         |         |
# | Total      | 136              | 754040                         |  754176 |

# %% [markdown]
# It's clear that Republicans use `iraq` more, but they also use more words in total, too. Fisher's test will tell us the *odds* of either party using it.
#
# Now that we have this, we can use the Fisher's exact test to see what the odds of one party using this more than the other

# %%
from scipy.stats import fisher_exact

oddsratio, pvalue = fisher_exact(contingency_table)
oddsratio, pvalue
# Out:
# (2.3061347877472795, 1.5757521308192708e-05)

# %% [markdown]
# ## Interpreting results
# So, Republicans are 2.3X more likely to talk about `iraq` than Democrats. We know that value is significant because the p-value is much lower than the standard `0.05` used to reject the null-hypothesis.

# %% [markdown]
# # Fisher's exact every word in our data frame
# When we check all of our words, which ones are significantly more likely to be used by one group rather than another?
#
# We can write a function to test this:

# %%
def fish(group_a, group_a_name, group_b, group_b_name):
    results = []
    if (group_a.columns == group_b.columns).all(): # test the columns for equivalence; don't run if the columns don't match
        for word in group_a.columns:
            # 1. calculate frequencies of each word
            sum_word_a = group_a[word].sum()
            sum_word_b = group_b[word].sum()

            # 2. calculate total number of words
            sum_allword_a = group_a.sum().sum()
            sum_allword_b = group_b.sum().sum()

            # 3. calculate total number of words minus the target word
            sum_notword_a = sum_allword_a - sum_word_a
            sum_notword_b = sum_allword_b - sum_word_b

            # 4. make contingency table
            contingency_table = [[sum_word_a, sum_notword_a], [sum_word_b, sum_notword_b]]

            # 5. run fisher's exact
            odds,pvalue = fisher_exact(contingency_table)

            # 6. capture results in dictionary
            d = {}
            d['word'] = word
            d['odds'] = odds
            d['pvalue'] = pvalue
            d['group_a']= group_a_name
            d['group_b'] = group_b_name

            results.append(d)
    
    return results

# %% [markdown]
# This may take a minute to run!

# %%
test = fish(Rs, 'Republicans', Ds, 'Democrats')
# this takes about a minute to run on my computer

# %%
import pandas as pd
df_fish = pd.DataFrame(test)

# %%
df_fish.head()
# Out:
#        group_a    group_b      odds    pvalue     word
# 0  Republicans  Democrats  1.073176  0.000039        a
# 1  Republicans  Democrats  0.943339  0.752629  ability
# 2  Republicans  Democrats  0.748276  0.012898     able
# 3  Republicans  Democrats  0.789779  0.000961    about
# 4  Republicans  Democrats  1.317702  0.082408    above

# %% [markdown]
# The values with the highest odds are more likely to appear in group A; the values with the lowest odds are more likely to appear in group B.
#
# Let's first filter for values that are less than than the standard significance threshold of `0.05`:

# %%
df_fish = df_fish[df_fish['pvalue'] < 0.05]

# %%
df_fish.sort_values(by='odds')
# Out:
#           group_a    group_b       odds        pvalue           word
# 1751  Republicans  Democrats   0.117974  6.635271e-18        vietnam
# 292   Republicans  Democrats   0.118821  4.320487e-29        college
# 489   Republicans  Democrats   0.151229  1.171550e-25            don
# 1613  Republicans  Democrats   0.188356  2.997954e-72              t
# 222   Republicans  Democrats   0.191555  1.001661e-23     businesses
# 1712  Republicans  Democrats   0.201861  4.123396e-20              u
# 725   Republicans  Democrats   0.202565  1.376399e-14         global
# 290   Republicans  Democrats   0.207166  1.667630e-08           cold
# 916   Republicans  Democrats   0.209439  2.553747e-09           kids
# 1394  Republicans  Democrats   0.213546  4.577548e-09    republicans
# 434   Republicans  Democrats   0.222264  1.486360e-08      democrats
# 352   Republicans  Democrats   0.226899  3.205969e-07      consumers
# 1327  Republicans  Democrats   0.231696  9.555787e-15          raise
# 735   Republicans  Democrats   0.239497  1.131001e-08            got
# 251   Republicans  Democrats   0.247062  2.719019e-22      challenge
# 1466  Republicans  Democrats   0.248711  3.331685e-08         sector
# 1573  Republicans  Democrats   0.250786  2.798474e-06        streets
# 399   Republicans  Democrats   0.260490  1.200966e-11           cuts
# 1799  Republicans  Democrats   0.266285  3.168755e-21            why
# 1047  Republicans  Democrats   0.267120  3.131264e-52        million
# 1311  Republicans  Democrats   0.268700  7.315869e-06     purchasing
# 985   Republicans  Democrats   0.272278  9.442348e-07            lot
# 1618  Republicans  Democrats   0.272281  3.669273e-06           talk
# 1621  Republicans  Democrats   0.275522  3.210240e-06          tasks
# 804   Republicans  Democrats   0.277408  5.995520e-20        housing
# 622   Republicans  Democrats   0.279264  6.277559e-06          faced
# 49    Republicans  Democrats   0.283630  2.027923e-05     affordable
# 1626  Republicans  Democrats   0.284456  5.688220e-09       teachers
# 982   Republicans  Democrats   0.285889  6.136261e-07           lose
# 876   Republicans  Democrats   0.286601  7.923035e-08         invest
# ...           ...        ...        ...           ...            ...
# 1125  Republicans  Democrats   7.262425  4.759442e-09        offices
# 1231  Republicans  Democrats   7.319474  4.929132e-12         postal
# 884   Republicans  Democrats   7.625435  2.434883e-08     irrigation
# 184   Republicans  Democrats   8.169990  2.237781e-07     beneficial
# 596   Republicans  Democrats   8.169990  2.237781e-07      exercised
# 877   Republicans  Democrats   8.255888  5.371092e-14  investigation
# 1325  Republicans  Democrats   8.442559  1.923108e-09        railway
# 1451  Republicans  Democrats   8.462428  7.350387e-13   satisfactory
# 1094  Republicans  Democrats   8.850902  2.793354e-08      nicaragua
# 1123  Republicans  Democrats   8.850902  2.793354e-08        officer
# 279   Republicans  Democrats   8.851584  1.720228e-13         claims
# 379   Republicans  Democrats   9.471761  9.170311e-23         courts
# 860   Republicans  Democrats   9.531825  6.055462e-09       instance
# 1698  Republicans  Democrats   9.531825  6.055462e-09       tribunal
# 397   Republicans  Democrats   9.702058  3.524891e-09        customs
# 1469  Republicans  Democrats  10.213069  6.907278e-12       securing
# 296   Republicans  Democrats  10.893356  2.949975e-08   combinations
# 1267  Republicans  Democrats  10.893709  1.544841e-10      procedure
# 1619  Republicans  Democrats  12.011043  5.910464e-31         tariff
# 245   Republicans  Democrats  12.409287  1.927786e-26           cent
# 220   Republicans  Democrats  13.618747  3.694597e-20         bureau
# 395   Republicans  Democrats  14.751979  9.557351e-12       currency
# 909   Republicans  Democrats  15.205953  5.779534e-12   jurisdiction
# 890   Republicans  Democrats  19.744712  3.678758e-11        isthmus
# 993   Republicans  Democrats  20.766130  7.157169e-12           mail
# 1600  Republicans  Democrats  21.789043  3.280503e-18    supervision
# 904   Republicans  Democrats  26.894919  9.712575e-16         judges
# 378   Republicans  Democrats  28.039859  5.144281e-47          court
# 105   Republicans  Democrats  36.770114  6.892732e-22       applause
# 759   Republicans  Democrats        inf  8.436439e-13          hague
#
# [1058 rows x 5 columns]
