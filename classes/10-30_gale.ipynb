# %% [markdown]
# # A couple of quick things from HW05
#
# When you set a variable name as `True` or `False` in a function declaration, that allows your user to decide *how* they want the function to run. It can be used to determine which parts of the function get run in a particular case.
#
# For example:

# %%
def weird_print(my_string, reverse_it = False):
    if reverse_it is True:
        print(my_string[::-1]) # this reverses each character in the string
    else:
        print(my_string)

# %%
weird_print('check it out')
# Out:
# check it out

# %%
weird_print('check it out', reverse_it=True)
# Out:
# tuo ti kcehc

# %% [markdown]
# # Correlator
# We're going to use our document-term matrix to create a version of "Correlator" from Heuser and Le-Khac's pamphlet.
#
# First, we need to load up our DTM:

# %%
import os

def absolute_paths(directory, txt_only = True):
    files = os.listdir(directory)
    absolute_paths = []
    
    for file in files:
        path = os.path.join(directory, file)
        absolute_paths.append(path)
    
    if txt_only is True:
        txts = []
        for x in absolute_paths:
            if str('.txt') in str(x):
                txts.append(x)
        return txts
    
    else:        
        return absolute_paths

# %%
import string
import re

def tokenize(text, keep_punct = False):
    if keep_punct is True:
        for punct in string.punctuation:
            text = text.replace(punct, ' ' + punct + ' ')
    else:
        for punct in string.punctuation:
            text = text.replace(punct, ' ')
    
    # this replaces *any* amount of whitespace with a single space using regular expressions
    text = re.sub('\s+', ' ', text)
    
    result = []
    
    for x in text.lower().split(' '):
        if x.isalpha():
            result.append(x)
    
    return result

# %%
def count_words(word_list):
    d = {}
    
    for word in word_list:
        if word not in d:
            d[word] = 1
        else:
            d[word] += 1
    
    return d

# %%
import pandas as pd

def make_dtm(directory, scaled = False):
    files = absolute_paths(directory)
    
    result = [] # empty list where I will append the dictionaries of word counts
    
    for file in files: # looping over the results
        text = open(file).read() # read in text file
        tokens = tokenize(text) # make tokens list
        d = count_words(tokens) # use count_words to create a dictionary
        
        if scaled is True:
            total_words = sum(list(d.values()))
            for key,value in d.items():
                d[key] = d[key] / total_words
        
        # os.path.split() returns the base path and the filename as a pair:
        d['_filename'] = os.path.split(file)[-1] # include the _ before filename in case the text contains "filename"
        result.append(d) # append the unscaled result
    
    return pd.DataFrame(result).set_index('_filename').sort_index()

# %%
hp_dir = '/Users/e/code/literarytextmining/corpora/harry_potter/texts'
df = make_dtm(hp_dir, scaled = True)

# %%
df
# Out:
#                                    a  aaaaaaaaargh  aaaaaaaarrrrrgh  \
# _filename
# 1 Sorcerers Stone.txt       0.025712           NaN              NaN
# 2 Chamber of Secrets.txt    0.022353           NaN              NaN
# 3 Prisoner of Azkaban.txt   0.021197           NaN              NaN
# 4 Goblet of Fire.txt        0.019706           NaN         0.000005
# 5 Order of the Phoenix.txt  0.020075      0.000004              NaN
# 6 Half-Blood Prince.txt     0.020399           NaN              NaN
# 7 Deathly Hallows.txt       0.019155           NaN              NaN
#
#                             aaaaaaand  aaaaaand  aaaaahed  aaaaargh     aaaah  \
# _filename
# 1 Sorcerers Stone.txt             NaN       NaN       NaN       NaN       NaN
# 2 Chamber of Secrets.txt          NaN       NaN       NaN       NaN       NaN
# 3 Prisoner of Azkaban.txt         NaN       NaN       NaN       NaN       NaN
# 4 Goblet of Fire.txt         0.000005  0.000005  0.000005       NaN       NaN
# 5 Order of the Phoenix.txt        NaN       NaN       NaN  0.000004  0.000004
# 6 Half-Blood Prince.txt           NaN       NaN       NaN  0.000006  0.000006
# 7 Deathly Hallows.txt             NaN       NaN       NaN       NaN       NaN
#
#                                 aaah     aargh  ...    zograf    zombie  \
# _filename                                       ...
# 1 Sorcerers Stone.txt            NaN       NaN  ...       NaN  0.000048
# 2 Chamber of Secrets.txt         NaN       NaN  ...       NaN       NaN
# 3 Prisoner of Azkaban.txt        NaN       NaN  ...       NaN  0.000010
# 4 Goblet of Fire.txt        0.000005       NaN  ...  0.000005       NaN
# 5 Order of the Phoenix.txt       NaN  0.000008  ...       NaN       NaN
# 6 Half-Blood Prince.txt          NaN       NaN  ...       NaN       NaN
# 7 Deathly Hallows.txt            NaN  0.000005  ...       NaN       NaN
#
#                                 zone    zonko       zoo  zoological      zoom  \
# _filename
# 1 Sorcerers Stone.txt            NaN      NaN  0.000169         NaN  0.000024
# 2 Chamber of Secrets.txt         NaN      NaN  0.000024         NaN       NaN
# 3 Prisoner of Azkaban.txt        NaN  0.00001       NaN         NaN       NaN
# 4 Goblet of Fire.txt             NaN      NaN       NaN    0.000005  0.000021
# 5 Order of the Phoenix.txt  0.000004      NaN       NaN         NaN  0.000008
# 6 Half-Blood Prince.txt          NaN      NaN       NaN         NaN       NaN
# 7 Deathly Hallows.txt            NaN      NaN       NaN         NaN  0.000005
#
#                               zoomed   zooming   éclairs
# _filename
# 1 Sorcerers Stone.txt       0.000024  0.000048  0.000024
# 2 Chamber of Secrets.txt    0.000024       NaN       NaN
# 3 Prisoner of Azkaban.txt   0.000086  0.000029       NaN
# 4 Goblet of Fire.txt        0.000048  0.000064       NaN
# 5 Order of the Phoenix.txt  0.000093  0.000028       NaN
# 6 Half-Blood Prince.txt     0.000043  0.000012  0.000006
# 7 Deathly Hallows.txt       0.000032  0.000027       NaN
#
# [7 rows x 19910 columns]

# %% [markdown]
# Let's cut it down to size for words for which we have data:

# %%
words_in_each_book = df.sum(min_count = 7)

# %%
my_columns = words_in_each_book[words_in_each_book.notnull()].index

# %%
my_columns
# Out:
# Index(['a', 'able', 'about', 'above', 'absurd', 'accept', 'accepted',
#        'accidentally', 'accidents', 'according',
#        ...
#        'yesterday', 'yet', 'you', 'young', 'younger', 'youngest', 'your',
#        'yours', 'yourself', 'zoomed'],
#       dtype='object', length=2494)

# %%
df = df[my_columns]

# %%
df
# Out:
#                                    a      able     about     above    absurd  \
# _filename
# 1 Sorcerers Stone.txt       0.025712  0.000241  0.003184  0.000121  0.000024
# 2 Chamber of Secrets.txt    0.022353  0.000428  0.002332  0.000250  0.000012
# 3 Prisoner of Azkaban.txt   0.021197  0.000343  0.002471  0.000200  0.000010
# 4 Goblet of Fire.txt        0.019706  0.000278  0.002811  0.000246  0.000005
# 5 Order of the Phoenix.txt  0.020075  0.000388  0.002425  0.000243  0.000008
# 6 Half-Blood Prince.txt     0.020399  0.000503  0.002302  0.000153  0.000012
# 7 Deathly Hallows.txt       0.019155  0.000388  0.001956  0.000223  0.000005
#
#                               accept  accepted  accidentally  accidents  \
# _filename
# 1 Sorcerers Stone.txt       0.000024  0.000048      0.000024   0.000024
# 2 Chamber of Secrets.txt    0.000012  0.000012      0.000059   0.000012
# 3 Prisoner of Azkaban.txt   0.000019  0.000010      0.000057   0.000010
# 4 Goblet of Fire.txt        0.000043  0.000011      0.000037   0.000011
# 5 Order of the Phoenix.txt  0.000028  0.000012      0.000032   0.000032
# 6 Half-Blood Prince.txt     0.000055  0.000012      0.000012   0.000012
# 7 Deathly Hallows.txt       0.000069  0.000032      0.000016   0.000016
#
#                             according  ...  yesterday       yet       you  \
# _filename                              ...
# 1 Sorcerers Stone.txt        0.000024  ...   0.000121  0.000507  0.009913
# 2 Chamber of Secrets.txt     0.000024  ...   0.000059  0.000345  0.009815
# 3 Prisoner of Azkaban.txt    0.000019  ...   0.000038  0.000487  0.010551
# 4 Goblet of Fire.txt         0.000037  ...   0.000043  0.000386  0.009398
# 5 Order of the Phoenix.txt   0.000040  ...   0.000036  0.000505  0.011127
# 6 Half-Blood Prince.txt      0.000049  ...   0.000018  0.000430  0.012455
# 7 Deathly Hallows.txt        0.000058  ...   0.000027  0.000489  0.010412
#
#                                young   younger  youngest      your     yours  \
# _filename
# 1 Sorcerers Stone.txt       0.000169  0.000048  0.000096  0.002002  0.000145
# 2 Chamber of Secrets.txt    0.000095  0.000024  0.000024  0.001761  0.000048
# 3 Prisoner of Azkaban.txt   0.000086  0.000019  0.000019  0.001965  0.000076
# 4 Goblet of Fire.txt        0.000155  0.000043  0.000016  0.001826  0.000037
# 5 Order of the Phoenix.txt  0.000137  0.000008  0.000008  0.002183  0.000069
# 6 Half-Blood Prince.txt     0.000209  0.000074  0.000006  0.002314  0.000061
# 7 Deathly Hallows.txt       0.000234  0.000096  0.000027  0.001844  0.000117
#
#                             yourself    zoomed
# _filename
# 1 Sorcerers Stone.txt       0.000193  0.000024
# 2 Chamber of Secrets.txt    0.000095  0.000024
# 3 Prisoner of Azkaban.txt   0.000219  0.000086
# 4 Goblet of Fire.txt        0.000171  0.000048
# 5 Order of the Phoenix.txt  0.000146  0.000093
# 6 Half-Blood Prince.txt     0.000172  0.000043
# 7 Deathly Hallows.txt       0.000117  0.000032
#
# [7 rows x 2494 columns]

# %% [markdown]
# # Writing correlator
#
# Heuser and Le-Khac describe their correlator like so:
#
# > To do so, we made use of a feature of the novelistic database Matthew Jockers had designed: a data-table of the number of occurrences of each word in our corpus. From this, we selected the words that appeared at least once in each decade of the nineteenth century, creating a new data-table of the se- lected words’ frequencies of appearance.3 We used normalized frequencies—the number of occurrences of a given word in a given decade, divided by the total number of word- occurrences in that decade—to correct for the over-representation of late century texts in our corpus. Then, we built a script to loop through each unique word-to-word comparison, calculate the degree of correlation between the two words’ decade-by-decade frequen- cies, and store this information in a new data-table. As a measure of correlation, we used the Pearson product-moment correlation coefficient, a simple and widely-used statistical measure of the covariance of two numerical series, converted into standard deviations so that differences in scale were ignored4. (This scale-invariance was important, as we hoped to find words that behaved similarly despite differences in their overall frequencies.)
#
# Now that we have this document-term matrix, we can easily make one of our own.
#
# Remember, correlation is not causation, but it can show us whether and how words "move together."

# %% [markdown]
# With Pandas, we can easily correlate all of the columns of a DataFrame with each other, giving us a new correlation matrix:

# %%
corrs = df.corr()

# %%
corrs
# Out:
#                      a      able     about     above    absurd    accept  \
# a             1.000000 -0.452957  0.714343 -0.634130  0.954499 -0.596491
# able         -0.452957  1.000000 -0.775012  0.147052 -0.310355  0.268301
# about         0.714343 -0.775012  1.000000 -0.458758  0.665811 -0.462024
# above        -0.634130  0.147052 -0.458758  1.000000 -0.806128 -0.062758
# absurd        0.954499 -0.310355  0.665811 -0.806128  1.000000 -0.414568
# accept       -0.596491  0.268301 -0.462024 -0.062758 -0.414568  1.000000
# accepted      0.617015 -0.498790  0.390882 -0.615364  0.655769  0.150697
# accidentally  0.142322 -0.143118  0.081576  0.484011 -0.111351 -0.802943
# accidents     0.214967 -0.181401  0.216598 -0.099691  0.276006 -0.116636
# according    -0.671289  0.432767 -0.587046  0.112292 -0.486530  0.933934
# across       -0.552382 -0.265038 -0.116899  0.577503 -0.695188 -0.053018
# act          -0.662117  0.813264 -0.960479  0.240533 -0.545417  0.520958
# acted        -0.251538 -0.062139 -0.378312 -0.175906 -0.222906  0.590020
# acting        0.533479 -0.278411  0.454088  0.183690  0.315024 -0.854837
# actually     -0.692442  0.534389 -0.555138  0.123316 -0.478285  0.765938
# add           0.125887  0.119132 -0.006221  0.477706 -0.046812 -0.411606
# added        -0.171159  0.626700 -0.251129  0.052422 -0.001507  0.126801
# addressed     0.646876 -0.462065  0.342753 -0.579841  0.666874 -0.086132
# advice        0.242461 -0.449005  0.540792  0.183334  0.188703 -0.267116
# affect        0.439141 -0.481876  0.346403 -0.310393  0.318288 -0.501335
# afford        0.809664 -0.719388  0.732209 -0.649630  0.748104 -0.443968
# afraid       -0.197236  0.058514 -0.088603 -0.403333 -0.024281  0.286317
# after        -0.726172  0.511491 -0.734824  0.099944 -0.600459  0.582169
# afternoon     0.829511 -0.662478  0.943509 -0.530512  0.800119 -0.583255
# afterward    -0.131770 -0.519693  0.502316  0.449237 -0.251828 -0.209310
# again        -0.729902  0.180594 -0.403272  0.416516 -0.701111  0.189040
# against      -0.705164  0.653840 -0.744638  0.418831 -0.678687  0.121479
# age          -0.222855 -0.177828  0.175876 -0.124756 -0.075149  0.683180
# ages          0.685388 -0.697200  0.826639 -0.403479  0.576151 -0.687289
# ago          -0.485088  0.581934 -0.525894  0.564754 -0.437161  0.262136
# ...                ...       ...       ...       ...       ...       ...
# wrenched      0.113045  0.651629 -0.418825 -0.159731  0.251819  0.072113
# wrinkled      0.894763 -0.558155  0.612115 -0.540693  0.831839 -0.313048
# wrist         0.849124 -0.631548  0.645602 -0.679029  0.841478 -0.211452
# write         0.125608  0.164012  0.048849  0.454626 -0.037383 -0.830639
# wrist         0.856261  0.266439 -0.414517
# write        -0.623966 -0.140271  0.327682
# writing      -0.465841 -0.635579 -0.163106
# written       0.433796 -0.323577 -0.388422
# wrong         0.587324  0.152226 -0.368118
# wrote        -0.644115 -0.553358 -0.226661
# yawned        0.178484  0.771787  0.358988
# yawning      -0.225926 -0.684684 -0.178414
# yeah         -0.220972 -0.231798  0.509051
# year         -0.662347  0.212431  0.139012
# years         0.728265  0.298679 -0.404612
# yeh           0.683771  0.516292 -0.216634
# yell         -0.232119  0.009866  0.243273
# yelled        0.088330  0.383252  0.304470
# yellow        0.303495  0.750683 -0.136469
# yellowish     0.613246  0.396600 -0.456418
# yer           0.710297  0.326318 -0.420760
# yes           0.517253  0.299222 -0.333169
# yesterday     0.568194  0.198420 -0.415976
# yet           0.732915  0.445219  0.412634
# you          -0.066317  0.127718  0.296602
# young         0.410506 -0.160617 -0.409661
# younger       0.391898 -0.171954 -0.590048
# youngest      0.791678  0.243010 -0.495887
# your          0.035382  0.369070  0.398908
# yours         1.000000  0.188667 -0.289385
# yourself      0.188667  1.000000  0.411189
# zoomed       -0.289385  0.411189  1.000000
#
# [2494 rows x 2494 columns]

# %% [markdown]
# Now, we can write a little function to show the correlations for any word in the list:

# %%
def my_correlator(word, corrs, n_corrs = 15):
    values = corrs[word]
    highs = values.sort_values(ascending = False)[:n_corrs] # this puts the most positive number at the top
    lows = values.sort_values(ascending = True)[:n_corrs] # this puts the most negative number at the top
    print('-'*50)
    print('Most strongly positive correlations with \"{}\": '.format(word))
    print(highs)
    print('-'*50)
    print('Most strongly negative correlations with \"{}\": '.format(word))
    print(lows)
    print('-'*50)

# %%
my_correlator('hagrid', corrs)
# Out:
# --------------------------------------------------
# Most strongly positive correlations with "hagrid":
# hagrid      1.000000
# knows       0.993978
# owl         0.991770
# uncle       0.987799
# nervous     0.986590
# station     0.986559
# nine        0.983492
# ordinary    0.983129
# barked      0.982662
# allowed     0.982459
# balls       0.981992
# vernon      0.980256
# lock        0.980218
# everyone    0.979804
# privet      0.979674
# Name: hagrid, dtype: float64
# --------------------------------------------------
# Most strongly negative correlations with "hagrid":
# split       -0.966914
# closed      -0.959544
# longer      -0.939648
# of          -0.939006
# to          -0.932863
# clear       -0.926546
# is          -0.913224
# invisible   -0.900331
# folded      -0.899863
# bellowed    -0.899033
# free        -0.898842
# return      -0.898589
# lifted      -0.895958
# anymore     -0.895881
# below       -0.881991
# Name: hagrid, dtype: float64
# --------------------------------------------------

# %% [markdown]
# What do these results tell us? First, the positive correlates: They show that when 'hagrid' increases, 'knows' changes in a *proportionally similar* way each time.
#
# That is, when 'hagrid' goes up, 'knows' goes up. When 'hagrid' goes down, 'knows' also goes down:

# %%
df[['hagrid', 'knows']]
# Out:
#                               hagrid     knows
# _filename
# 1 Sorcerers Stone.txt       0.004390  0.000338
# 2 Chamber of Secrets.txt    0.001606  0.000202
# 3 Prisoner of Azkaban.txt   0.001917  0.000200
# 4 Goblet of Fire.txt        0.001665  0.000193
# 5 Order of the Phoenix.txt  0.001495  0.000190
# 6 Half-Blood Prince.txt     0.001056  0.000160
# 7 Deathly Hallows.txt       0.000702  0.000133

# %% [markdown]
# Strongly negative correlates show an inverse relationship: When 'hagrid' goes down, 'split' goes up:

# %%
df[['hagrid', 'split']]
# Out:
#                               hagrid     split
# _filename
# 1 Sorcerers Stone.txt       0.004390  0.000024
# 2 Chamber of Secrets.txt    0.001606  0.000095
# 3 Prisoner of Azkaban.txt   0.001917  0.000076
# 4 Goblet of Fire.txt        0.001665  0.000080
# 5 Order of the Phoenix.txt  0.001495  0.000085
# 6 Half-Blood Prince.txt     0.001056  0.000117
# 7 Deathly Hallows.txt       0.000702  0.000117

# %% [markdown]
# As you can already see, one of the problems here is that we sometimes compare relatively common words to relatively rare ones. We can improve on this by cutting our DataFrame again to words with a certain total frequency.
#
# Below, we recalculate our dataframe and only retain words that have 10 or more instances *in each book*.

# %%
df = make_dtm(hp_dir, scaled = False)

# %% [markdown]
# `.all()` allows us to check a dataframe (or a slice) to see if all of its cells in each column evaluate to `True`.

# %%
df['the']
# Out:
# _filename
# 1 Sorcerers Stone.txt          2073
# 2 Chamber of Secrets.txt       4275
# 3 Prisoner of Azkaban.txt      5368
# 4 Goblet of Fire.txt           9494
# 5 Order of the Phoenix.txt    11902
# 6 Half-Blood Prince.txt        7617
# 7 Deathly Hallows.txt         10341
# Name: the, dtype: int64

# %%
df['the'] > 10
# Out:
# _filename
# 1 Sorcerers Stone.txt         True
# 2 Chamber of Secrets.txt      True
# 3 Prisoner of Azkaban.txt     True
# 4 Goblet of Fire.txt          True
# 5 Order of the Phoenix.txt    True
# 6 Half-Blood Prince.txt       True
# 7 Deathly Hallows.txt         True
# Name: the, dtype: bool

# %%
(df['the'] > 10).all()
# Out:
# True

# %% [markdown]
# But in cases where only some books meet our criteria:

# %%
df['crumpet'] >= 1
# Out:
# _filename
# 1 Sorcerers Stone.txt         False
# 2 Chamber of Secrets.txt      False
# 3 Prisoner of Azkaban.txt      True
# 4 Goblet of Fire.txt          False
# 5 Order of the Phoenix.txt     True
# 6 Half-Blood Prince.txt       False
# 7 Deathly Hallows.txt         False
# Name: crumpet, dtype: bool

# %%
(df['crumpet'] > 10).all()
# Out:
# False

# %% [markdown]
# So, if we create a new dataframe with all of our results, we can make another filter for our data:

# %%
gt10 = df > 10

# %%
gt10.all()[:5]
# Out:
# a                   True
# aaaaaaaaargh       False
# aaaaaaaarrrrrgh    False
# aaaaaaand          False
# aaaaaand           False
# dtype: bool

# %%
df.sum()[gt10.all()]
# Out:
# a            20741.0
# about         2455.0
# across         548.0
# after         1143.0
# again         1932.0
# against        640.0
# air            525.0
# all           4116.0
# almost         390.0
# along          491.0
# already        463.0
# always         396.0
# an            2246.0
# and          26557.0
# another        688.0
# any            886.0
# anyone         366.0
# anything       696.0
# are           1830.0
# arms           287.0
# around        2225.0
# arrived        202.0
# as            7477.0
# ask            335.0
# asked         1090.0
# at            8575.0
# aunt           364.0
# away          1109.0
# back          3155.0
# bad            224.0
#               ...
# went           655.0
# were          4198.0
# what          3243.0
# when          2222.0
# where         1176.0
# which         1428.0
# while          678.0
# whispered      428.0
# who           2925.0
# whole          350.0
# why            718.0
# will          1317.0
# window         428.0
# with          6454.0
# without        568.0
# wizard         479.0
# wizards        347.0
# words          334.0
# work           353.0
# world          261.0
# would         2253.0
# wrong          244.0
# year           533.0
# years          528.0
# yeh            286.0
# yelled         259.0
# yes            337.0
# yet            460.0
# you          10838.0
# your          2042.0
# Length: 457, dtype: float64

# %% [markdown]
# This gives us just 457 words of our original 19,911 that meet our criteria for analysis. Again, those criteria are: each word must appear in every single *Harry Potter* book, and in each of its appearances, it must appear 10 or more times.

# %% [markdown]
# Let's use this to further cut down our dataframe for correlation:

# %%
my_cols = df.sum()[gt10.all()].index # calling index at the end gets the words that meet our criteria

# %%
my_cols
# Out:
# Index(['a', 'about', 'across', 'after', 'again', 'against', 'air', 'all',
#        'almost', 'along',
#        ...
#        'would', 'wrong', 'year', 'years', 'yeh', 'yelled', 'yes', 'yet', 'you',
#        'your'],
#       dtype='object', length=457)

# %% [markdown]
# Now, I'm going to recreate my dataframe as a scaled version so that our correlation isn't messed up by the different lengths of the books:

# %%
df = make_dtm(hp_dir, scaled = True)

# %% [markdown]
# We're going to run the correlation *only on the columns that meet our criteria*, i.e. `my_cols`:

# %%
new_corr = df[my_cols].corr()

# %%
new_corr
# Out:
#                   a     about    across     after     again   against  \
# a          1.000000  0.714343 -0.552382 -0.726172 -0.729902 -0.705164
# about      0.714343  1.000000 -0.116899 -0.734824 -0.403272 -0.744638
# across    -0.552382 -0.116899  1.000000  0.389497  0.744860  0.513963
# after     -0.726172 -0.734824  0.389497  1.000000  0.730875  0.809722
# again     -0.729902 -0.403272  0.744860  0.730875  1.000000  0.753237
# against   -0.705164 -0.744638  0.513963  0.809722  0.753237  1.000000
# air        0.131147  0.236365 -0.018243 -0.061339 -0.101307 -0.552792
# all        0.867714  0.862675 -0.513688 -0.899050 -0.704302 -0.911428
# almost     0.810412  0.832297 -0.538109 -0.840304 -0.678470 -0.717889
# along     -0.623688 -0.487316  0.808975  0.466760  0.794891  0.734865
# already   -0.017131 -0.163437 -0.454970  0.475823  0.109862  0.184282
# always     0.898219  0.711499 -0.617396 -0.787282 -0.650837 -0.820479
# an        -0.632958 -0.515621  0.073007  0.530258  0.404601  0.683320
# and        0.064532 -0.067189  0.075167 -0.092749 -0.304436 -0.367698
# another    0.548542  0.184214 -0.118519 -0.499169 -0.516582 -0.465186
# any       -0.630307 -0.289393  0.080458  0.159513  0.061391  0.177441
# anyone     0.457742  0.099152 -0.002076 -0.192586 -0.442482  0.007737
# anything   0.828019  0.858876 -0.346029 -0.621347 -0.506732 -0.548166
# are       -0.451743 -0.226295 -0.036109  0.517463  0.512610  0.138278
# arms      -0.293009 -0.266182 -0.235420  0.320168 -0.050988 -0.228416
# around    -0.568345 -0.052166  0.859511  0.112823  0.563011  0.420188
# across    -0.282798 -0.292703
# after      0.607782  0.342802
# again      0.350159  0.316998
# against    0.511674  0.225336
# air       -0.377740 -0.228968
# all       -0.415762 -0.067095
# almost    -0.179687  0.128519
# along     -0.070194 -0.198272
# already    0.903134  0.875575
# always    -0.263810  0.046534
# an         0.710417  0.506102
# and       -0.669131 -0.768915
# another   -0.740530 -0.740521
# any        0.131830 -0.017159
# anyone    -0.339379 -0.490394
# anything  -0.092827  0.210659
# are        0.592930  0.666921
# arms       0.122660  0.041542
# around    -0.325324 -0.320895
# arrived   -0.234258  0.201598
# as         0.184563  0.181020
# ask       -0.233307 -0.036108
# asked      0.609360  0.563005
# at        -0.362263  0.034713
# aunt      -0.384995 -0.086455
# away      -0.080768 -0.399725
# back      -0.702341 -0.513469
# bad       -0.339743 -0.011131
# ...             ...       ...
# went      -0.670574 -0.496458
# were      -0.813087 -0.640057
# what       0.546251  0.690734
# when       0.000663  0.404516
# where     -0.240806 -0.348530
# which      0.352813  0.285057
# while     -0.089123  0.147621
# whispered -0.035029 -0.245061
# who        0.789050  0.554895
# whole     -0.303630 -0.357365
# why        0.604511  0.453875
# will       0.171653 -0.061353
# window    -0.330895 -0.221685
# with       0.797743  0.866537
# without    0.699730  0.785814
# wizard    -0.462713 -0.431841
# wizards   -0.689715 -0.580317
# words      0.362051  0.174629
# work      -0.141385  0.183136
# world     -0.699789 -0.406712
# would      0.625983  0.394107
# wrong      0.318403  0.215841
# year      -0.052959 -0.014673
# years     -0.111079  0.149516
# yeh       -0.222063  0.127909
# yelled    -0.416405 -0.470367
# yes        0.246817  0.529827
# yet        0.262848  0.422712
# you        1.000000  0.889981
# your       0.889981  1.000000
#
# [457 rows x 457 columns]

# %%
my_correlator('bad', new_corr)
# Out:
# --------------------------------------------------
# Most strongly positive correlations with "bad":
# bad           1.000000
# seamus        0.968107
# pair          0.964503
# five          0.961552
# start         0.956068
# on            0.952860
# snapped       0.948121
# ten           0.942005
# knows         0.935258
# got           0.933499
# mcgonagall    0.924770
# something     0.923745
# week          0.917303
# getting       0.910475
# a             0.903803
# Name: bad, dtype: float64
# --------------------------------------------------
# Most strongly negative correlations with "bad":
# light      -0.911939
# own        -0.898202
# is         -0.891130
# to         -0.876991
# of         -0.862705
# felt       -0.861041
# would      -0.849656
# moment     -0.833288
# both       -0.823459
# still      -0.813622
# after      -0.799030
# did        -0.776998
# hermione   -0.773693
# who        -0.766327
# done       -0.762777
# Name: bad, dtype: float64
# --------------------------------------------------

# %% [markdown]
# You will find that, as the size of your corpus increases, your correlation values will get smaller.
#
# Heuser and Le-Khac express surprise that some words they expected to more together did not. We can easily check to see whether and how words move together by slightly altering our function to take a list of words:

# %%
def do_they_correlate(words, corrs):
    for word in words:
        values = corrs[word] # get correlation data for each word
        words_copy = words.copy() # to not mess up the original word list
        words_copy.remove(word) # no need to test against itself
        
        for test in words_copy:
            result = round(values[test],2)
            output = "{} and {} correlation:".format(test, word)
            spaces = (40 - len(output)) * ' '
            print('{}{}{}'.format(output,spaces,result))
            print('-'*50)

# %%
do_they_correlate(['wizard', 'hermione', 'harry', 'ron', 'malfoy', 'dumbledore'], new_corr)
# Out:
# hermione and wizard correlation:        -0.66
# --------------------------------------------------
# harry and wizard correlation:           0.19
# --------------------------------------------------
# ron and wizard correlation:             0.0
# --------------------------------------------------
# malfoy and wizard correlation:          0.22
# --------------------------------------------------
# dumbledore and wizard correlation:      -0.44
# --------------------------------------------------
# wizard and hermione correlation:        -0.66
# --------------------------------------------------
# harry and hermione correlation:         -0.11
# --------------------------------------------------
# ron and hermione correlation:           0.35
# --------------------------------------------------
# malfoy and hermione correlation:        -0.41
# --------------------------------------------------
# dumbledore and hermione correlation:    0.03
# --------------------------------------------------
# wizard and harry correlation:           0.19
# --------------------------------------------------
# hermione and harry correlation:         -0.11
# --------------------------------------------------
# ron and harry correlation:              0.83
# --------------------------------------------------
# malfoy and harry correlation:           0.75
# --------------------------------------------------
# dumbledore and harry correlation:       -0.36
# --------------------------------------------------
# wizard and ron correlation:             0.0
# --------------------------------------------------
# hermione and ron correlation:           0.35
# --------------------------------------------------
# harry and ron correlation:              0.83
# --------------------------------------------------
# malfoy and ron correlation:             0.45
# --------------------------------------------------
# dumbledore and ron correlation:         -0.35
# --------------------------------------------------
# wizard and malfoy correlation:          0.22
# --------------------------------------------------
# hermione and malfoy correlation:        -0.41
# --------------------------------------------------
# harry and malfoy correlation:           0.75
# --------------------------------------------------
# ron and malfoy correlation:             0.45
# --------------------------------------------------
# dumbledore and malfoy correlation:      0.14
# --------------------------------------------------
# wizard and dumbledore correlation:      -0.44
# --------------------------------------------------
# hermione and dumbledore correlation:    0.03
# --------------------------------------------------
# harry and dumbledore correlation:       -0.36
# --------------------------------------------------
# ron and dumbledore correlation:         -0.35
# --------------------------------------------------
# malfoy and dumbledore correlation:      0.14
# --------------------------------------------------

# %% [markdown]
# # Creating cohorts
#
# Now we're going to extend to the next part of Heuser and Le-Khac's analysis, where we propose cohorts ourselves:

# %%
def word_to_cohort(word, cor_matrix = gale_corr, threshold = 0.5):
    '''
    cohort base represents the user-proposed word to create a cohort.
    population begins with the total number of words in the corpus.
    '''
    
    population = list(cor_matrix.columns)
    population.remove(word) # drop processed word from list of candidates 
    
    values = cor_matrix[word][population]

    if (values < threshold).any(): # not taking absolute values; interested in positively correlated words
        # drop weak links
        dropped = list(values[values < threshold].index)
        for drop in dropped:
            population.remove(drop)

    if len(population) == 0:
        print('No viable cohort for {}'.format(word))
        return

    # using that baseline, test the correlations of each of the other population elements
    # add the one that correlates above the threshold with the greatest number of other elements to the list
    results = {}
    
    for candidate in population:
        values = cor_matrix[candidate][population]
        results[candidate] = len(values[values > threshold])
    
    cohort_words = []
    for k,v in results.items():
        if v == max(results.values()):
            cohort_words.append(k)
    
    print('cohort is: {}'.format(l))
    
    return cohort_words

# %% [markdown]
# `average` and `intuition` share a ton of correlates.

# %%
def corr_cohort(cohort, scaled_freqs):
    # ^ this is always going to start with a full copy of the original scaled freqs
    combined_vector = scaled_freqs[cohort].sum(axis = 'columns') # sum across the columns to get a new vector
    for x in cohort: # can't drop all of them because some will be repeats in the loop
        try:
            scaled_freqs = scaled_freqs.drop(x, axis = 'columns')
        except:
            continue
            
    scaled_freqs['my_cohort'] = combined_vector
    return scaled_freqs.corr()

# %%
words_to_cohort(cohort, gale_copy.corr())
# Out:
# cohort is: ['intuition', 'average', 'my_cohort', 'san', 'twinkle']
# ['intuition', 'average', 'my_cohort', 'san', 'twinkle']

# %%
def words_to_cohort(my_cohort, cor_matrix, threshold = 0.9):
    population = list(cor_matrix.columns)
    
    for word in my_cohort: # on the off-chance words weren't succesffully removed previously
        try:
            population.remove(word)
        except:
            continue
            
    population.remove('my_cohort') # make sure this is not in the column names
    
    values = cor_matrix['my_cohort'][population] # column name always fixed as it is always overwritten

    if (values < threshold).any(): # not taking absolute values; interested in positively correlated words
        # drop weak links
        dropped = list(values[values < threshold].index)
        for drop in dropped:
            population.remove(drop)

    if len(population) == 0:
        print('No viable additional cohort members')
        return 

    # using that baseline, test the correlations of each of the other population elements
    # add the one that correlates above the threshold with the greatest number of other elements to the list
    results = {}

    for candidate in population:
        values = cor_matrix[candidate][population]
        results[candidate] = len(values[values > threshold])

    for k,v in results.items():
        if v == max(results.values()):
            return k

# %%
test_scaled_freqs = gale.copy()
test_scaled_freqs.set_index('decade', inplace = True)

# %%
test_scaled_freqs = pd.read_csv('/Users/e/Desktop/gale_5years_scaled.csv')
test_scaled_freqs.set_index('fives', inplace = True)
# this only retains 1820-1915
test_scaled_freqs = test_scaled_freqs.iloc[7:-1]

# %%
cohort = ['idle', 'cares', 'sober', 'yielding', 'patient', 'kind', 'lithe', 'spotless', 'indifferent', 'offered',
          'enjoying', 'charitable', 'joyful', 'impetuous']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['god', 'jesus', 'divine', 'holy', 'sacred'] # very sturdy
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['average', 'ordinary', 'normal', 'middle', 'class', 'people']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['average', 'american'] # lol first result is "fools"
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['citizen'] # excellent results
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['person', 'people'] # very good results
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['average', 'normal', 'straight', 'queer', 'type'] # very good results
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['average', 'normal', 'straight', 'queer', 'type'] # very good results
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['type', 'person', 'generally', 'expect', 'opinion', 'formed', 'contrary', 'expectation', 'every',
          'probable', 'particular']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['every', 'most', 'numerous', 'opinion', 'highly', 'calculated', 'native',
         'sufficient', 'particulars', 'peculiarly']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['liberty', 'freedom', 'equally'] # this outputs results pertaining to the restriction of freedom!
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['female', 'domestic', 'graces', 'appear', 'appears', 'sensible']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['government', 'constitution', 'liberal', 'governed', 'equally']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['rural', 'city', 'country']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['middle', 'class', 'people']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['foreign', 'compared', 'anticipate']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
# the word most strongly *negatively* correlated with average is 'heaven'
# which says something about the secularization hypothesis...
cohort = ['average', 'nowadays']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
# strongest correlate of photograph telegram and telegraph is average
# obviously it's sensitive to history
cohort = ['photograph', 'telegram', 'telegraph']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['love']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['fear', 'pity', 'joy', 'love', 'hate']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['slave'] # third correlate is "freely..."
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['america', 'american', 'united', 'states'] # extremely good results
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['average', 'human']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['intuition', 'guess', 'suspicion']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['negro']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['average', 'american'] # lol first result is "fools"
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['united', 'states'] # lol first result is "fools"
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['type','average','citizen'] # not thinking about the discourse correctly; need to go back to texts
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['civil','civilized']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['character','characters']

# %%
cohort = ['hard']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
cohort = ['anyone']
test_m = corr_cohort(cohort, test_scaled_freqs)

# %%
while len(cohort) <= 15:
    cohort.append(words_to_cohort(cohort, test_m))
    print('{}'.format(cohort[-1]))
    test_m = corr_cohort(cohort, test_scaled_freqs)
# Out:
# personality
# facing
# faced
# behind

# %% [markdown]
# Now, the above list becomes the basis for the next loop, which requires that you sum the values in the source matrix, generate a new correlation table, and repeat the process.

# %%
def correlator(cohort, corrs = gale_corr):#scaled_dtm):
    # 1. Propose a cohort of words in the variable corrs
    # 2. Check the correlation of the cohort against itself
    
    
    # 3. If each of the elements in the cohort correlates
    # 4. Sum their vectors in the scaled dtm
    # 5. Drop the columns for scaled dtm 
    # 6. Calculate new correlations for the summed vectors against the remaining dtm
    # 7. Return the top correlates from the new DTM

# %%
cohort = ['average', 'ordinary', 'normal']

# %%
values = gale_corr['ordinary'][cohort]

# %%
values.abs().sort_values().index[0]
# Out:
# 'normal'

# %%
(values.abs() < 0.1).any()
# Out:
# True

# %%
correlator(['average', 'ordinary'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-15feeccdef96> in <module>
# ----> 1 correlator(['average', 'ordinary'])
#
# <ipython-input-38-7b1c679a14d1> in correlator(cohort, corrs)
#       4     corrs = []
#       5     for word in cohort:
# ----> 6         corrs.extend(corrs[word][cohort])
#       7     return corrs
#       8
#
# TypeError: list indices must be integers or slices, not str

# %%
def correlator2(start_word, corrs, scaled_dtm):
    # 1. starting with one word of interest
    # 2. automatically select words that correlate closely with it
    # 3. create a new vector
    # 4. check for words that correlate with the new vector
    # 5. if none cross the threshold, drop the one with the weakest correlation with the rest of the group
    # 6. recalculate the vector with the new terms
    # 7. choose the highest correlate relative to those
    # 8. see if you can successfully add a new element to the cohort
    # 9. repeat until you have a strongly-grouped cohort of ... 20?

# %%
gale = '/Users/e/Desktop/gale_decades_scaled.csv'
gale = pd.read_csv(gale)

# %%
gale.set_index('decade', inplace=True)

# %%
gale_corr = gale.corr()

# %%
my_correlator('normal', gale_corr)
# Out:
# --------------------------------------------------
# Most strongly positive correlations with "normal":
# normal          1.000000
# grimly          0.998200
# straightened    0.996595
# downstairs      0.996095
# anyway          0.995453
# worry           0.995070
# worried         0.994241
# upstairs        0.994029
# doesn           0.993871
# problems        0.993016
# funny           0.992052
# anyhow          0.990398
# big             0.989432
# tucked          0.988951
# stared          0.988773
# Name: normal, dtype: float64
# --------------------------------------------------
# Most strongly negative correlations with "normal":
# complexion      -0.961367
# and             -0.952962
# bear            -0.945628
# shall           -0.941061
# miserable       -0.940240
# gaining         -0.935714
# possession      -0.935382
# remain          -0.933881
# bade            -0.928094
# should          -0.921118
# comprehend      -0.918889
# circumstances   -0.918222
# whose           -0.907437
# kindred         -0.905886
# strive          -0.904338
# Name: normal, dtype: float64
# --------------------------------------------------
